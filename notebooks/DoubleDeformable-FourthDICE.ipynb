# %%
import parent
import networks
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
from collections import OrderedDict
import torch.nn.functional as F
from mermaidlite import compute_warped_image_multiNC, identity_map_multiN
import torch
import random
import inverseConsistentNet
import networks
import network_wrappers
import data
import numpy as np
import matplotlib.pyplot as plt

# %%
r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#batched_ds = list(zip(*[r_ds[i::4] for i in range(2)]))

# %%
2
# Out:
# 2

# %%
batched_ds = list(zip(*[r_ds[i::2] for i in range(2)]))

# %%
phi = network_wrappers.FunctionFromVectorField(
    networks.tallUNet(unet=networks.UNet2ChunkyMiddle, dimension=3)
)
psi = network_wrappers.FunctionFromVectorField(networks.tallUNet2(dimension=3))

pretrained_lowres_net = network_wrappers.DoubleNet(phi, psi)

hires_net = network_wrappers.DoubleNet(
        network_wrappers.DownsampleNet(pretrained_lowres_net, dimension=3),
        network_wrappers.FunctionFromVectorField(networks.tallUNet2(dimension=3)),
    )

fourth_net = inverseConsistentNet.InverseConsistentNet(
    network_wrappers.DoubleNet(
        hires_net, 
        network_wrappers.FunctionFromVectorField(networks.tallUNet2(dimension=3)),
    ),  
    lambda x, y: (x - y) **2,
    3600,
)

BATCH_SIZE = 3
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [BATCH_SIZE, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

network_wrappers.assignIdentityMap(fourth_net, input_shape)
trained_weights = torch.load("../../masked_similarity_InvCon/results/fourth_net_frozen/knee_aligner_resi_net97800")
fourth_net.load_state_dict(trained_weights)
# Out:
# /playpen-raid1/tgreer/InverseConsistency/networks.py:483: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   np.array([[2, 16, 32, 64, 256, 512], [16, 32, 64, 128, 256]]),
# <All keys matched successfully>

# %%
net = fourth_net

# %%
BATCH_SIZE = 2
network_wrappers.adjust_batch_size(net, BATCH_SIZE)
net.cuda()
net.eval()
0
# Out:
# 0

# %%
def flips(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True)
    return torch.sum(dV < 0)# / BATCH_SIZE
with torch.no_grad():
    dices = []
    folds_list = []
    
    filteredDV_list = []
    
    
    for x in batched_ds[:]:
        x = list(zip(*x))
        x = [torch.cat(r, 0).cuda().float() for r in x]
        fixed_image, fixed_cartilage = x[0], x[2]
        moving_image, moving_cartilage = x[1], x[3]

        net(moving_image, fixed_image)
        phi_AB_vectorfield = net.phi_AB(net.identityMap)
        fat_phi = torch.nn.Upsample(size=moving_cartilage.size()[2:], mode="trilinear")(phi_AB_vectorfield[:, :3])
        sz = np.array(fat_phi.size())
        spacing = 1./(sz[2::]-1) 
        warped_moving_cartilage = compute_warped_image_multiNC(moving_cartilage.float(), fat_phi, spacing, 1)
        wmb = warped_moving_cartilage > .5
        fb = fixed_cartilage > .5
        intersection = wmb * fb
        d = 2 * torch.sum(intersection, [1,2,3,4]).float() / (torch.sum(wmb, [1,2,3,4]) + torch.sum(fb, [1,2,3,4]))
        print(d)
        dices.append(d)
        f = flips(phi_AB_vectorfield[:1])
        print(f)
        folds_list.append(f.item())
        f = flips(phi_AB_vectorfield[1:])
        print(f)
        folds_list.append(f.item())
        
        dV = flips2(phi_AB_vectorfield)
        
        dV = np.array(dV).flatten()
        dV = dV[dV < 0]
        filteredDV_list.append(dV)
        
    dd = torch.mean(torch.cat(dices).cpu())
    print(dd)
    ff = np.mean(folds_list)
    print(ff)
# Out:
# tensor([0.7047, 0.7471], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(539, device='cuda:0')
# tensor([0.7260, 0.6133], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(259, device='cuda:0')
# tensor([0.6460, 0.6251], device='cuda:0')
# tensor(70, device='cuda:0')
# tensor(65, device='cuda:0')
# tensor([0.7589, 0.6890], device='cuda:0')
# tensor(72, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7070, 0.7573], device='cuda:0')
# tensor(10, device='cuda:0')
# tensor(9, device='cuda:0')
# tensor([0.6779, 0.7758], device='cuda:0')
# tensor(14, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.7399, 0.6042], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(14, device='cuda:0')
# tensor([0.6561, 0.7411], device='cuda:0')
# tensor(49, device='cuda:0')
# tensor(56, device='cuda:0')
# tensor([0.6437, 0.7065], device='cuda:0')
# tensor(156, device='cuda:0')
# tensor(76, device='cuda:0')
# tensor([0.5618, 0.6706], device='cuda:0')
# tensor(31, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.6770, 0.7442], device='cuda:0')
# tensor(88, device='cuda:0')
# tensor(58, device='cuda:0')
# tensor([0.5230, 0.4784], device='cuda:0')
# tensor(81, device='cuda:0')
# tensor(260, device='cuda:0')
# tensor([0.6467, 0.7032], device='cuda:0')
# tensor(93, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.7011, 0.7145], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.6945, 0.6727], device='cuda:0')
# tensor(453, device='cuda:0')
# tensor(158, device='cuda:0')
# tensor([0.6087, 0.7801], device='cuda:0')
# tensor(103, device='cuda:0')
# tensor(19, device='cuda:0')
# tensor([0.7430, 0.7248], device='cuda:0')
# tensor(77, device='cuda:0')
# tensor(245, device='cuda:0')
# tensor([0.5102, 0.6479], device='cuda:0')
# tensor(75, device='cuda:0')
# tensor(72, device='cuda:0')
# tensor([0.7306, 0.5618], device='cuda:0')
# tensor(51, device='cuda:0')
# tensor(84, device='cuda:0')
# tensor([0.7477, 0.7637], device='cuda:0')
# tensor(66, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.7025, 0.7207], device='cuda:0')
# tensor(142, device='cuda:0')
# tensor(93, device='cuda:0')
# tensor([0.5636, 0.6823], device='cuda:0')
# tensor(299, device='cuda:0')
# tensor(20, device='cuda:0')
# tensor([0.6677, 0.6177], device='cuda:0')
# tensor(49, device='cuda:0')
# tensor(30, device='cuda:0')
# tensor([0.7281, 0.7237], device='cuda:0')
# tensor(37, device='cuda:0')
# tensor(142, device='cuda:0')
# tensor([0.7285, 0.6164], device='cuda:0')
# tensor(117, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.5776, 0.6794], device='cuda:0')
# tensor(92, device='cuda:0')
# tensor(63, device='cuda:0')
# tensor([0.6865, 0.6623], device='cuda:0')
# tensor(44, device='cuda:0')
# tensor(67, device='cuda:0')
# tensor([0.6059, 0.6396], device='cuda:0')
# tensor(63, device='cuda:0')
# tensor(6, device='cuda:0')
# tensor([0.6550, 0.7077], device='cuda:0')
# tensor(43, device='cuda:0')
# tensor(19, device='cuda:0')
# tensor([0.6930, 0.6498], device='cuda:0')
# tensor(68, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7894, 0.6844], device='cuda:0')
# tensor(124, device='cuda:0')
# tensor(15, device='cuda:0')
# tensor([0.7149, 0.6296], device='cuda:0')
# tensor(32, device='cuda:0')
# tensor(236, device='cuda:0')
# tensor([0.7985, 0.7178], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(103, device='cuda:0')
# tensor([0.7082, 0.7202], device='cuda:0')
# tensor(205, device='cuda:0')
# tensor(39, device='cuda:0')
# tensor([0.6768, 0.7077], device='cuda:0')
# tensor(11, device='cuda:0')
# tensor(16, device='cuda:0')
# tensor([0.7229, 0.7264], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(9, device='cuda:0')
# tensor([0.7283, 0.6810], device='cuda:0')
# tensor(1203, device='cuda:0')
# tensor(150, device='cuda:0')
# tensor([0.6808, 0.7141], device='cuda:0')
# tensor(38, device='cuda:0')
# tensor(266, device='cuda:0')
# tensor([0.7283, 0.6941], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(680, device='cuda:0')
# tensor([0.7576, 0.6660], device='cuda:0')
# tensor(27, device='cuda:0')
# tensor(144, device='cuda:0')
# tensor([0.7017, 0.6483], device='cuda:0')
# tensor(526, device='cuda:0')
# tensor(8, device='cuda:0')
# tensor([0.6008, 0.6045], device='cuda:0')
# tensor(17, device='cuda:0')
# tensor(15, device='cuda:0')
# tensor([0.6334, 0.6402], device='cuda:0')
# tensor(54, device='cuda:0')
# tensor(65, device='cuda:0')
# tensor([0.6595, 0.7028], device='cuda:0')
# tensor(50, device='cuda:0')
# tensor(14, device='cuda:0')
# tensor([0.7027, 0.6672], device='cuda:0')
# tensor(239, device='cuda:0')
# tensor(131, device='cuda:0')
# tensor([0.7384, 0.6852], device='cuda:0')
# tensor(28, device='cuda:0')
# tensor(68, device='cuda:0')
# tensor([0.7387, 0.7111], device='cuda:0')
# tensor(29, device='cuda:0')
# tensor(80, device='cuda:0')
# tensor([0.6474, 0.6936], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(50, device='cuda:0')
# tensor([0.6173, 0.7456], device='cuda:0')
# tensor(40, device='cuda:0')
# tensor(22, device='cuda:0')
# tensor([0.6344, 0.6907], device='cuda:0')
# tensor(219, device='cuda:0')
# tensor(473, device='cuda:0')
# tensor([0.7123, 0.7615], device='cuda:0')
# tensor(158, device='cuda:0')
# tensor(92, device='cuda:0')
# tensor([0.6983, 0.7011], device='cuda:0')
# tensor(43, device='cuda:0')
# tensor(37, device='cuda:0')
# tensor([0.6912, 0.7316], device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(45, device='cuda:0')
# tensor([0.6557, 0.7250], device='cuda:0')
# tensor(95, device='cuda:0')
# tensor(102, device='cuda:0')
# tensor([0.5564, 0.6615], device='cuda:0')
# tensor(1650, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.7274, 0.6672], device='cuda:0')
# tensor(93, device='cuda:0')
# tensor(131, device='cuda:0')
# tensor([0.6268, 0.6962], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(165, device='cuda:0')
# tensor([0.7109, 0.6591], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(355, device='cuda:0')
# tensor([0.6388, 0.5888], device='cuda:0')
# tensor(90, device='cuda:0')
# tensor(551, device='cuda:0')
# tensor([0.7404, 0.6767], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.6594, 0.7274], device='cuda:0')
# tensor(26, device='cuda:0')
# tensor(138, device='cuda:0')
# tensor([0.6086, 0.6061], device='cuda:0')
# tensor(1061, device='cuda:0')
# tensor(395, device='cuda:0')
# tensor([0.6769, 0.7050], device='cuda:0')
# tensor(21, device='cuda:0')
# tensor(177, device='cuda:0')
# tensor([0.4874, 0.6904], device='cuda:0')
# tensor(546, device='cuda:0')
# tensor(63, device='cuda:0')
# tensor([0.6495, 0.6429], device='cuda:0')
# tensor(47, device='cuda:0')
# tensor(40, device='cuda:0')
# tensor([0.6703, 0.6328], device='cuda:0')
# tensor(127, device='cuda:0')
# tensor(146, device='cuda:0')
# tensor([0.6828, 0.7155], device='cuda:0')
# tensor(44, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.7214, 0.7083], device='cuda:0')
# tensor(64, device='cuda:0')
# tensor(1308, device='cuda:0')
# tensor([0.7196, 0.6960], device='cuda:0')
# tensor(768, device='cuda:0')
# tensor(21, device='cuda:0')
# tensor([0.6476, 0.6846], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(61, device='cuda:0')
# tensor([0.6986, 0.7282], device='cuda:0')
# tensor(196, device='cuda:0')
# tensor(32, device='cuda:0')
# tensor([0.6784, 0.7643], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(33, device='cuda:0')
# tensor([0.6691, 0.6664], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(287, device='cuda:0')
# tensor([0.6877, 0.7062], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(101, device='cuda:0')
# tensor([0.7115, 0.6981], device='cuda:0')
# tensor(38, device='cuda:0')
# tensor(38, device='cuda:0')
# tensor([0.6918, 0.6649], device='cuda:0')
# tensor(572, device='cuda:0')
# tensor(27, device='cuda:0')
# tensor([0.6307, 0.7261], device='cuda:0')
# tensor(22, device='cuda:0')
# tensor(6, device='cuda:0')
# tensor([0.5865, 0.7220], device='cuda:0')
# tensor(141, device='cuda:0')
# tensor(59, device='cuda:0')
# tensor([0.7435, 0.6936], device='cuda:0')
# tensor(93, device='cuda:0')
# tensor(75, device='cuda:0')
# tensor([0.6972, 0.6508], device='cuda:0')
# tensor(22, device='cuda:0')
# tensor(11, device='cuda:0')
# tensor([0.5479, 0.5873], device='cuda:0')
# tensor(112, device='cuda:0')
# tensor(90, device='cuda:0')
# tensor([0.7391, 0.7526], device='cuda:0')
# tensor(71, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7156, 0.6805], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(33, device='cuda:0')
# tensor([0.6470, 0.5969], device='cuda:0')
# tensor(116, device='cuda:0')
# tensor(512, device='cuda:0')
# tensor([0.6939, 0.6771], device='cuda:0')
# tensor(247, device='cuda:0')
# tensor(80, device='cuda:0')
# tensor([0.7308, 0.7408], device='cuda:0')
# tensor(25, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7214, 0.7343], device='cuda:0')
# tensor(74, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.5612, 0.6876], device='cuda:0')
# tensor(120, device='cuda:0')
# tensor(27, device='cuda:0')
# tensor([0.6599, 0.7248], device='cuda:0')
# tensor(491, device='cuda:0')
# tensor(245, device='cuda:0')
# tensor([0.6995, 0.7367], device='cuda:0')
# tensor(582, device='cuda:0')
# tensor(23, device='cuda:0')
# tensor([0.7250, 0.6913], device='cuda:0')
# tensor(165, device='cuda:0')
# tensor(111, device='cuda:0')
# tensor([0.6280, 0.6865], device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(608, device='cuda:0')
# tensor([0.5271, 0.7437], device='cuda:0')
# tensor(10, device='cuda:0')
# tensor(145, device='cuda:0')
# tensor([0.5424, 0.7161], device='cuda:0')
# tensor(24, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.7074, 0.5749], device='cuda:0')
# tensor(333, device='cuda:0')
# tensor(207, device='cuda:0')
# tensor([0.6358, 0.6878], device='cuda:0')
# tensor(156, device='cuda:0')
# tensor(38, device='cuda:0')
# tensor([0.7558, 0.5905], device='cuda:0')
# tensor(163, device='cuda:0')
# tensor(190, device='cuda:0')
# tensor([0.6248, 0.6794], device='cuda:0')
# tensor(237, device='cuda:0')
# tensor(222, device='cuda:0')
# tensor([0.6611, 0.7357], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(33, device='cuda:0')
# tensor([0.7360, 0.6320], device='cuda:0')
# tensor(54, device='cuda:0')
# tensor(114, device='cuda:0')
# tensor([0.7085, 0.6609], device='cuda:0')
# tensor(62, device='cuda:0')
# tensor(98, device='cuda:0')
# tensor([0.6850, 0.5999], device='cuda:0')
# tensor(1035, device='cuda:0')
# tensor(45, device='cuda:0')
# tensor([0.8473, 0.7601], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.5880, 0.7522], device='cuda:0')
# tensor(99, device='cuda:0')
# tensor(86, device='cuda:0')
# tensor([0.6629, 0.7400], device='cuda:0')
# tensor(65, device='cuda:0')
# tensor(117, device='cuda:0')
# tensor([0.7962, 0.6927], device='cuda:0')
# tensor(11, device='cuda:0')
# tensor(65, device='cuda:0')
# tensor([0.6096, 0.8530], device='cuda:0')
# tensor(102, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7423, 0.5411], device='cuda:0')
# tensor(223, device='cuda:0')
# tensor(242, device='cuda:0')
# tensor([0.6849, 0.6149], device='cuda:0')
# tensor(115, device='cuda:0')
# tensor(224, device='cuda:0')
# tensor([0.6145, 0.7038], device='cuda:0')
# tensor(42, device='cuda:0')
# tensor(48, device='cuda:0')
# tensor([0.7223, 0.7379], device='cuda:0')
# tensor(75, device='cuda:0')
# tensor(78, device='cuda:0')
# tensor([0.6535, 0.7501], device='cuda:0')
# tensor(183, device='cuda:0')
# tensor(31, device='cuda:0')
# tensor([0.7023, 0.6982], device='cuda:0')
# tensor(38, device='cuda:0')
# tensor(107, device='cuda:0')
# tensor([0.6803, 0.7029], device='cuda:0')
# tensor(11, device='cuda:0')
# tensor(277, device='cuda:0')
# tensor([0.5601, 0.7420], device='cuda:0')
# tensor(209, device='cuda:0')
# tensor(20, device='cuda:0')
# tensor([0.6711, 0.6516], device='cuda:0')
# tensor(59, device='cuda:0')
# tensor(34, device='cuda:0')
# tensor([0.6994, 0.6991], device='cuda:0')
# tensor(85, device='cuda:0')
# tensor(31, device='cuda:0')
# tensor([0.6144, 0.7187], device='cuda:0')
# tensor(12, device='cuda:0')
# tensor(6, device='cuda:0')
# tensor([0.6497, 0.7302], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.6430, 0.6575], device='cuda:0')
# tensor(6, device='cuda:0')
# tensor(19, device='cuda:0')
# tensor([0.7268, 0.6958], device='cuda:0')
# tensor(164, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor([0.6194, 0.6282], device='cuda:0')
# tensor(24, device='cuda:0')
# tensor(129, device='cuda:0')
# tensor([0.6466, 0.7243], device='cuda:0')
# tensor(45, device='cuda:0')
# tensor(460, device='cuda:0')
# tensor([0.6608, 0.7076], device='cuda:0')
# tensor(51, device='cuda:0')
# tensor(145, device='cuda:0')
# tensor([0.9687, 0.7496], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(111, device='cuda:0')
# tensor([0.7346, 0.6797], device='cuda:0')
# tensor(74, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor([0.6933, 0.6205], device='cuda:0')
# tensor(10, device='cuda:0')
# tensor(40, device='cuda:0')
# tensor([0.6657, 0.7362], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(430, device='cuda:0')
# tensor([0.7064, 0.6730], device='cuda:0')
# tensor(99, device='cuda:0')
# tensor(323, device='cuda:0')
# tensor([0.6933, 0.7199], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(38, device='cuda:0')
# tensor([0.6580, 0.5823], device='cuda:0')
# tensor(23, device='cuda:0')
# tensor(66, device='cuda:0')
# tensor([0.7121, 0.6258], device='cuda:0')
# tensor(34, device='cuda:0')
# tensor(37, device='cuda:0')
# tensor([0.7609, 0.7827], device='cuda:0')
# tensor(199, device='cuda:0')
# tensor(26, device='cuda:0')
# tensor([0.6318, 0.6295], device='cuda:0')
# tensor(44, device='cuda:0')
# tensor(278, device='cuda:0')
# tensor([0.6669, 0.7071], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(26, device='cuda:0')
# tensor([0.6481, 0.7047], device='cuda:0')
# tensor(28, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7241, 0.7152], device='cuda:0')
# tensor(95, device='cuda:0')
# tensor(16, device='cuda:0')
# tensor([0.7079, 0.5794], device='cuda:0')
# tensor(363, device='cuda:0')
# tensor(22, device='cuda:0')
# tensor([0.6954, 0.6979], device='cuda:0')
# tensor(33, device='cuda:0')
# tensor(165, device='cuda:0')
# tensor([0.6819, 0.6270], device='cuda:0')
# tensor(11, device='cuda:0')
# tensor(30, device='cuda:0')
# tensor([0.6982, 0.7130], device='cuda:0')
# tensor(20, device='cuda:0')
# tensor(133, device='cuda:0')
# tensor([0.7378, 0.7237], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(30, device='cuda:0')
# tensor([0.6696, 0.7303], device='cuda:0')
# tensor(135, device='cuda:0')
# tensor(65, device='cuda:0')
# tensor([0.7013, 0.6362], device='cuda:0')
# tensor(175, device='cuda:0')
# tensor(92, device='cuda:0')
# tensor([0.7786, 0.6960], device='cuda:0')
# tensor(35, device='cuda:0')
# tensor(86, device='cuda:0')
# tensor([0.6761, 0.7121], device='cuda:0')
# tensor(138, device='cuda:0')
# tensor(34, device='cuda:0')
# tensor([0.7848, 0.6027], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(141, device='cuda:0')
# tensor([0.6750, 0.7072], device='cuda:0')
# tensor(60, device='cuda:0')
# tensor(35, device='cuda:0')
# tensor([0.7216, 0.6039], device='cuda:0')
# tensor(112, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.6323, 0.6903], device='cuda:0')
# tensor(112, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(0.6829)
# 118.35

# %%
dicesa = np.array(torch.cat(dices).cpu())
plt.hist(dicesa, 20)
plt.xlabel("DICE")
print(np.mean(dicesa))
ff = np.mean(folds_list)
print(ff)
# Out:
# 0.6828595
# 118.35

# %%
if not("N" in locals()):
    N = 0
#N += 1
N %= 2
#N = 3
#plt.imshow(fixed_image[N, 0, 10].cpu() - net.warped_image_A[N, 0, 10].cpu().detach())
#plt.show()
plt.rcParams["figure.figsize"] = (5, 5)
def imshow(x):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
slice_ = 20
imshow(fixed_image[N, 0, slice_])
plt.show()
imshow(net.warped_image_A[N, 0, slice_])
plt.show()

plt.imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach() - moving_image[N, 0, slice_ ].cpu().detach())
plt.show()
#plt.imshow(net.regis_net.x_comp_phi[N, 0, slice_].cpu().detach() - moving_image[N, 0, slice_].cpu().detach())
#plt.show()
plt.imshow((fixed_image - moving_image)[N, 0, slice_].cpu().detach())
plt.show()

imshow(moving_image[N, 0, slice_].cpu().detach())
plt.show()

# %%
import matplotlib.pyplot as plt
plt.imshow(moving_image[0, 0, :, 10].cpu())
plt.show()
plt.imshow(fixed_image[0, 0, :, 10].cpu())
plt.show()
plt.imshow(net.warped_image_A[0, 0, :, 10].cpu().detach())
plt.show()
plt.imshow(net.warped_image_B[0, 0, :, 10].cpu().detach())
plt.show()

plt.imshow(net.warped_image_B[0, 0, :, 10].cpu().detach() - moving_image[0, 0, :, 10].cpu())

# %%
S = 40
plt.imshow(moving_cartilage[N, 0, :, S * 4].cpu())
plt.show() 
plt.imshow(warped_moving_cartilage[N, 0, :, S * 4].detach().cpu())
plt.show()

plt.imshow(fixed_cartilage[N, 0, :, S * 4].cpu())
plt.show()

plt.imshow((warped_moving_cartilage[N, 0, :, S * 4].detach().cpu() - fixed_cartilage[N, 0, :, S * 4].cpu()))
plt.show()

# %%
import visualize
N = (N + 1)% 2
#N = 1
plt.rcParams["figure.figsize"] = 10, 10
visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
plt.show()
visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 20])

# %%
phi = net.phi_AB.__closure__[1]
some_vectorfield = phi.cell_contents.__closure__[1].cell_contents + net.identityMap
visualize.show_as_grid(some_vectorfield[N, [1, 2], 20])

# %%
net.phi_AB.__closure__[0].cell_contents
# Out:
# <function network_wrappers.DoubleNet.forward.<locals>.<lambda>(input_)>

# %%
N = (N + 1) % 4
visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identityMap))[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-32cf513bbe99> in <module>
#       1 N = (N + 1) % 4
# ----> 2 visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identityMap))[N, [1, 2], 20])
#
# IndexError: index 2 is out of bounds for dimension 0 with size 2

# %%
import visualize
mp = hires_Net.phi_AB(hires_Net.regis_net.net.identityMap[:, :] + torch.tensor([[[[[0]]], [[[0]]], [[[0]]]]]).cuda())
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
import mermaidlite

# %%
import visualize
mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
import visualize
mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
mermaidlite.compute_warped_image_multiNC?

# %%
torch.nn.functional.avg_pool3d?

# %%
# Out:
# tensor([[[[[ 8.9085e-03,  9.2434e-03,  9.5800e-03,  ...,  8.9751e-03,
#              9.2738e-03,  9.5502e-03],
#            [ 9.2282e-03,  9.6274e-03,  1.0028e-02,  ...,  9.9777e-03,
#              1.0269e-02,  1.0568e-02],
#            [ 9.5437e-03,  1.0007e-02,  1.0471e-02,  ...,  1.0989e-02,
#              1.1275e-02,  1.1593e-02],
#            ...,
#            [ 1.4196e-02,  1.4902e-02,  1.5630e-02,  ...,  3.1676e-02,
#              3.1930e-02,  3.2242e-02],
#            [ 1.4148e-02,  1.4913e-02,  1.5682e-02,  ...,  3.1702e-02,
#              3.2031e-02,  3.2408e-02],
#            [ 1.4288e-02,  1.5008e-02,  1.5746e-02,  ...,  3.1845e-02,
#              3.2131e-02,  3.2459e-02]],
#
#           [[ 2.1678e-02,  2.2050e-02,  2.2422e-02,  ...,  2.1415e-02,
#              2.1756e-02,  2.2022e-02],
#            [ 2.1997e-02,  2.2410e-02,  2.2823e-02,  ...,  2.2525e-02,
#              2.2892e-02,  2.3150e-02],
#            [ 2.2312e-02,  2.2766e-02,  2.3220e-02,  ...,  2.3641e-02,
#              2.4040e-02,  2.4288e-02],
#            ...,
#            [ 2.7640e-02,  2.8251e-02,  2.8864e-02,  ...,  4.4912e-02,
#              4.5217e-02,  4.5610e-02],
#            [ 2.7640e-02,  2.8307e-02,  2.8969e-02,  ...,  4.4966e-02,
#              4.5303e-02,  4.5724e-02],
#            [ 2.7744e-02,  2.8370e-02,  2.8991e-02,  ...,  4.5022e-02,
#              4.5351e-02,  4.5750e-02]],
#
#           [[ 3.4450e-02,  3.4858e-02,  3.5267e-02,  ...,  3.3839e-02,
#              3.4214e-02,  3.4476e-02],
#            [ 3.4766e-02,  3.5193e-02,  3.5620e-02,  ...,  3.5061e-02,
#              3.5492e-02,  3.5716e-02],
#            [ 3.5081e-02,  3.5526e-02,  3.5971e-02,  ...,  3.6286e-02,
#              3.6785e-02,  3.6968e-02],
#            ...,
#            [ 4.1098e-02,  4.1591e-02,  4.2086e-02,  ...,  5.8144e-02,
#              5.8507e-02,  5.8980e-02],
#            [ 4.1136e-02,  4.1694e-02,  4.2247e-02,  ...,  5.8229e-02,
#              5.8583e-02,  5.9049e-02],
#            [ 4.1216e-02,  4.1723e-02,  4.2225e-02,  ...,  5.8198e-02,
#              5.8573e-02,  5.9043e-02]],
#
#           ...,
#
#           [[ 9.6420e-01,  9.6397e-01,  9.6375e-01,  ...,  9.2702e-01,
#              9.2740e-01,  9.2774e-01],
#            [ 9.6432e-01,  9.6425e-01,  9.6418e-01,  ...,  9.2637e-01,
#              9.2675e-01,  9.2704e-01],
#            [ 9.6449e-01,  9.6457e-01,  9.6465e-01,  ...,  9.2572e-01,
#              9.2609e-01,  9.2633e-01],
#            ...,
#            [ 9.6549e-01,  9.6500e-01,  9.6452e-01,  ...,  9.4150e-01,
#              9.4128e-01,  9.4164e-01],
#            [ 9.6572e-01,  9.6518e-01,  9.6464e-01,  ...,  9.4131e-01,
#              9.4101e-01,  9.4141e-01],
#            [ 9.6583e-01,  9.6536e-01,  9.6488e-01,  ...,  9.4163e-01,
#              9.4132e-01,  9.4160e-01]],
#
#           [[ 9.7541e-01,  9.7513e-01,  9.7485e-01,  ...,  9.3754e-01,
#              9.3789e-01,  9.3821e-01],
#            [ 9.7543e-01,  9.7530e-01,  9.7519e-01,  ...,  9.3682e-01,
#              9.3715e-01,  9.3742e-01],
#            [ 9.7548e-01,  9.7552e-01,  9.7556e-01,  ...,  9.3611e-01,
#              9.3641e-01,  9.3663e-01],
#            ...,
#            [ 9.7615e-01,  9.7555e-01,  9.7495e-01,  ...,  9.5366e-01,
#              9.5338e-01,  9.5373e-01],
#            [ 9.7637e-01,  9.7571e-01,  9.7506e-01,  ...,  9.5331e-01,
#              9.5299e-01,  9.5338e-01],
#            [ 9.7649e-01,  9.7589e-01,  9.7529e-01,  ...,  9.5368e-01,
#              9.5334e-01,  9.5359e-01]],
#
#           [[ 9.8709e-01,  9.8675e-01,  9.8642e-01,  ...,  9.4816e-01,
#              9.4851e-01,  9.4884e-01],
#            [ 9.8704e-01,  9.8687e-01,  9.8671e-01,  ...,  9.4737e-01,
#              9.4771e-01,  9.4798e-01],
#            [ 9.8704e-01,  9.8704e-01,  9.8704e-01,  ...,  9.4659e-01,
#              9.4690e-01,  9.4711e-01],
#            ...,
#            [ 9.8625e-01,  9.8569e-01,  9.8514e-01,  ...,  9.6656e-01,
#              9.6630e-01,  9.6658e-01],
#            [ 9.8647e-01,  9.8588e-01,  9.8529e-01,  ...,  9.6626e-01,
#              9.6592e-01,  9.6626e-01],
#            [ 9.8660e-01,  9.8607e-01,  9.8552e-01,  ...,  9.6652e-01,
#              9.6619e-01,  9.6640e-01]]],
#
#
#          [[[ 2.4773e-03,  2.6162e-03,  2.7566e-03,  ...,  3.8191e-03,
#              3.9793e-03,  3.9547e-03],
#            [ 7.6841e-03,  7.8276e-03,  7.9721e-03,  ...,  9.9636e-03,
#              1.0089e-02,  1.0118e-02],
#            [ 1.2888e-02,  1.3036e-02,  1.3184e-02,  ...,  1.6111e-02,
#              1.6197e-02,  1.6279e-02],
#            ...,
#            [ 9.9178e-01,  9.9208e-01,  9.9238e-01,  ...,  1.0550e+00,
#              1.0551e+00,  1.0553e+00],
#            [ 9.9705e-01,  9.9733e-01,  9.9761e-01,  ...,  1.0603e+00,
#              1.0604e+00,  1.0606e+00],
#            [ 1.0022e+00,  1.0025e+00,  1.0028e+00,  ...,  1.0658e+00,
#              1.0659e+00,  1.0660e+00]],
#
#           [[ 2.4419e-03,  2.5246e-03,  2.6078e-03,  ...,  3.5532e-03,
#              3.6338e-03,  3.7136e-03],
#            [ 7.6628e-03,  7.7712e-03,  7.8799e-03,  ...,  9.8037e-03,
#              9.8615e-03,  9.9694e-03],
#            [ 1.2880e-02,  1.3014e-02,  1.3148e-02,  ...,  1.6056e-02,
#              1.6089e-02,  1.6224e-02],
#            ...,
#            [ 9.9165e-01,  9.9196e-01,  9.9226e-01,  ...,  1.0561e+00,
#              1.0562e+00,  1.0564e+00],
#            [ 9.9686e-01,  9.9715e-01,  9.9744e-01,  ...,  1.0615e+00,
#              1.0616e+00,  1.0617e+00],
#            [ 1.0020e+00,  1.0023e+00,  1.0026e+00,  ...,  1.0669e+00,
#              1.0670e+00,  1.0671e+00]],
#
#           [[ 2.4055e-03,  2.4310e-03,  2.4559e-03,  ...,  3.2816e-03,
#              3.2905e-03,  3.4766e-03],
#            [ 7.6403e-03,  7.7130e-03,  7.7851e-03,  ...,  9.6394e-03,
#              9.6358e-03,  9.8243e-03],
#            [ 1.2871e-02,  1.2990e-02,  1.3109e-02,  ...,  1.5999e-02,
#              1.5982e-02,  1.6172e-02],
#            ...,
#            [ 9.9152e-01,  9.9184e-01,  9.9216e-01,  ...,  1.0573e+00,
#              1.0574e+00,  1.0575e+00],
#            [ 9.9666e-01,  9.9697e-01,  9.9728e-01,  ...,  1.0627e+00,
#              1.0628e+00,  1.0629e+00],
#            [ 1.0018e+00,  1.0022e+00,  1.0025e+00,  ...,  1.0680e+00,
#              1.0681e+00,  1.0682e+00]],
#
#           ...,
#
#           [[ 3.6902e-03,  3.7198e-03,  3.7495e-03,  ..., -1.1800e-03,
#             -9.3055e-04, -8.9048e-04],
#            [ 1.0577e-02,  1.0845e-02,  1.1117e-02,  ...,  4.5188e-03,
#              4.7537e-03,  4.7767e-03],
#            [ 1.7499e-02,  1.8004e-02,  1.8518e-02,  ...,  1.0204e-02,
#              1.0449e-02,  1.0454e-02],
#            ...,
#            [ 9.8944e-01,  9.8991e-01,  9.9038e-01,  ...,  1.0622e+00,
#              1.0623e+00,  1.0620e+00],
#            [ 9.9449e-01,  9.9496e-01,  9.9546e-01,  ...,  1.0671e+00,
#              1.0672e+00,  1.0668e+00],
#            [ 9.9960e-01,  1.0000e+00,  1.0004e+00,  ...,  1.0717e+00,
#              1.0718e+00,  1.0714e+00]],
#
#           [[ 3.8048e-03,  3.7887e-03,  3.7739e-03,  ..., -1.2035e-03,
#             -9.5352e-04, -8.8291e-04],
#            [ 1.0734e-02,  1.0956e-02,  1.1183e-02,  ...,  4.5002e-03,
#              4.7515e-03,  4.8053e-03],
#            [ 1.7702e-02,  1.8160e-02,  1.8626e-02,  ...,  1.0188e-02,
#              1.0470e-02,  1.0507e-02],
#            ...,
#            [ 9.8958e-01,  9.9004e-01,  9.9050e-01,  ...,  1.0624e+00,
#              1.0625e+00,  1.0621e+00],
#            [ 9.9458e-01,  9.9506e-01,  9.9556e-01,  ...,  1.0674e+00,
#              1.0675e+00,  1.0670e+00],
#            [ 9.9974e-01,  1.0001e+00,  1.0005e+00,  ...,  1.0719e+00,
#              1.0720e+00,  1.0716e+00]],
#
#           [[ 3.7294e-03,  3.7902e-03,  3.8536e-03,  ..., -1.0057e-03,
#             -7.7459e-04, -8.0907e-04],
#            [ 1.0747e-02,  1.1025e-02,  1.1309e-02,  ...,  4.7058e-03,
#              4.9146e-03,  4.8605e-03],
#            [ 1.7801e-02,  1.8296e-02,  1.8799e-02,  ...,  1.0406e-02,
#              1.0614e-02,  1.0540e-02],
#            ...,
#            [ 9.8976e-01,  9.9018e-01,  9.9060e-01,  ...,  1.0620e+00,
#              1.0620e+00,  1.0616e+00],
#            [ 9.9477e-01,  9.9520e-01,  9.9565e-01,  ...,  1.0670e+00,
#              1.0669e+00,  1.0665e+00],
#            [ 9.9992e-01,  1.0003e+00,  1.0006e+00,  ...,  1.0715e+00,
#              1.0715e+00,  1.0711e+00]]],
#
#
#          [[[ 2.1556e-03,  7.6071e-03,  1.3061e-02,  ...,  1.0238e+00,
#              1.0286e+00,  1.0339e+00],
#            [ 1.7598e-03,  7.2558e-03,  1.2754e-02,  ...,  1.0259e+00,
#              1.0308e+00,  1.0359e+00],
#            [ 1.3577e-03,  6.8976e-03,  1.2438e-02,  ...,  1.0280e+00,
#              1.0329e+00,  1.0380e+00],
#            ...,
#            [-2.1729e-03,  3.0558e-03,  8.2983e-03,  ...,  1.0367e+00,
#              1.0419e+00,  1.0470e+00],
#            [-2.2424e-03,  3.0132e-03,  8.2690e-03,  ...,  1.0370e+00,
#              1.0421e+00,  1.0473e+00],
#            [-2.1638e-03,  3.0745e-03,  8.3226e-03,  ...,  1.0373e+00,
#              1.0424e+00,  1.0476e+00]],
#
#           [[ 1.9429e-03,  7.4685e-03,  1.2995e-02,  ...,  1.0250e+00,
#              1.0298e+00,  1.0350e+00],
#            [ 1.5461e-03,  7.0940e-03,  1.2642e-02,  ...,  1.0270e+00,
#              1.0318e+00,  1.0370e+00],
#            [ 1.1450e-03,  6.7147e-03,  1.2284e-02,  ...,  1.0290e+00,
#              1.0338e+00,  1.0389e+00],
#            ...,
#            [-2.1397e-03,  3.1266e-03,  8.3924e-03,  ...,  1.0360e+00,
#              1.0412e+00,  1.0464e+00],
#            [-2.1599e-03,  3.1082e-03,  8.3734e-03,  ...,  1.0364e+00,
#              1.0415e+00,  1.0466e+00],
#            [-2.1465e-03,  3.1320e-03,  8.4081e-03,  ...,  1.0366e+00,
#              1.0418e+00,  1.0469e+00]],
#
#           [[ 1.7315e-03,  7.3327e-03,  1.2934e-02,  ...,  1.0262e+00,
#              1.0311e+00,  1.0362e+00],
#            [ 1.3325e-03,  6.9337e-03,  1.2535e-02,  ...,  1.0281e+00,
#              1.0329e+00,  1.0380e+00],
#            [ 9.3129e-04,  6.5321e-03,  1.2133e-02,  ...,  1.0299e+00,
#              1.0348e+00,  1.0398e+00],
#            ...,
#            [-2.1009e-03,  3.1876e-03,  8.4746e-03,  ...,  1.0353e+00,
#              1.0406e+00,  1.0457e+00],
#            [-2.0763e-03,  3.1954e-03,  8.4668e-03,  ...,  1.0357e+00,
#              1.0409e+00,  1.0459e+00],
#            [-2.1187e-03,  3.1835e-03,  8.4855e-03,  ...,  1.0359e+00,
#              1.0411e+00,  1.0462e+00]],
#
#           ...,
#
#           [[ 2.2078e-02,  3.0383e-02,  3.8692e-02,  ...,  9.9890e-01,
#              1.0038e+00,  1.0086e+00],
#            [ 2.4040e-02,  3.2591e-02,  4.1155e-02,  ...,  9.9940e-01,
#              1.0043e+00,  1.0091e+00],
#            [ 2.6086e-02,  3.4879e-02,  4.3694e-02,  ...,  9.9991e-01,
#              1.0048e+00,  1.0096e+00],
#            ...,
#            [ 6.9197e-03,  1.6692e-02,  2.6485e-02,  ...,  1.0137e+00,
#              1.0191e+00,  1.0246e+00],
#            [ 6.4719e-03,  1.6014e-02,  2.5570e-02,  ...,  1.0141e+00,
#              1.0195e+00,  1.0249e+00],
#            [ 6.0248e-03,  1.5416e-02,  2.4813e-02,  ...,  1.0146e+00,
#              1.0198e+00,  1.0251e+00]],
#
#           [[ 2.2373e-02,  3.0758e-02,  3.9144e-02,  ...,  9.9896e-01,
#              1.0039e+00,  1.0087e+00],
#            [ 2.4498e-02,  3.3117e-02,  4.1744e-02,  ...,  9.9947e-01,
#              1.0044e+00,  1.0092e+00],
#            [ 2.6710e-02,  3.5559e-02,  4.4424e-02,  ...,  9.9995e-01,
#              1.0049e+00,  1.0097e+00],
#            ...,
#            [ 7.4399e-03,  1.7217e-02,  2.7021e-02,  ...,  1.0144e+00,
#              1.0201e+00,  1.0255e+00],
#            [ 7.0273e-03,  1.6535e-02,  2.6058e-02,  ...,  1.0149e+00,
#              1.0205e+00,  1.0258e+00],
#            [ 6.5454e-03,  1.5937e-02,  2.5329e-02,  ...,  1.0153e+00,
#              1.0206e+00,  1.0258e+00]],
#
#           [[ 2.3130e-02,  3.1504e-02,  3.9883e-02,  ...,  9.9894e-01,
#              1.0039e+00,  1.0087e+00],
#            [ 2.5239e-02,  3.3876e-02,  4.2528e-02,  ...,  9.9950e-01,
#              1.0044e+00,  1.0092e+00],
#            [ 2.7443e-02,  3.6341e-02,  4.5262e-02,  ...,  1.0001e+00,
#              1.0050e+00,  1.0098e+00],
#            ...,
#            [ 7.1615e-03,  1.6932e-02,  2.6721e-02,  ...,  1.0142e+00,
#              1.0199e+00,  1.0255e+00],
#            [ 6.6965e-03,  1.6242e-02,  2.5796e-02,  ...,  1.0146e+00,
#              1.0202e+00,  1.0257e+00],
#            [ 6.2344e-03,  1.5633e-02,  2.5036e-02,  ...,  1.0150e+00,
#              1.0204e+00,  1.0258e+00]]]],
#
#
#
#         [[[[ 4.1924e-03,  3.9256e-03,  3.6603e-03,  ..., -3.1695e-03,
#             -2.9700e-03, -2.6901e-03],
#            [ 4.0037e-03,  3.7395e-03,  3.4765e-03,  ..., -4.1292e-03,
#             -3.9407e-03, -3.6551e-03],
#            [ 3.8146e-03,  3.5527e-03,  3.2918e-03,  ..., -5.0788e-03,
#             -4.9030e-03, -4.6156e-03],
#            ...,
#            [-6.0870e-03, -6.9005e-03, -7.7127e-03,  ..., -7.5672e-03,
#             -7.2397e-03, -6.9282e-03],
#            [-6.2203e-03, -6.9861e-03, -7.7504e-03,  ..., -7.4964e-03,
#             -7.1298e-03, -6.8037e-03],
#            [-6.1250e-03, -6.9038e-03, -7.6835e-03,  ..., -7.5342e-03,
#             -7.1736e-03, -6.8302e-03]],
#
#           [[ 1.6943e-02,  1.6725e-02,  1.6504e-02,  ...,  1.0034e-02,
#              1.0287e-02,  1.0519e-02],
#            [ 1.6734e-02,  1.6491e-02,  1.6246e-02,  ...,  9.0688e-03,
#              9.3237e-03,  9.5677e-03],
#            [ 1.6526e-02,  1.6257e-02,  1.5989e-02,  ...,  8.1006e-03,
#              8.3573e-03,  8.6183e-03],
#            ...,
#            [ 6.6683e-03,  5.8340e-03,  5.0008e-03,  ...,  5.5446e-03,
#              5.9251e-03,  6.3499e-03],
#            [ 6.5994e-03,  5.8093e-03,  5.0203e-03,  ...,  5.6083e-03,
#              6.0134e-03,  6.4547e-03],
#            [ 6.6596e-03,  5.8540e-03,  5.0475e-03,  ...,  5.5978e-03,
#              6.0063e-03,  6.4634e-03]],
#
#           [[ 2.9707e-02,  2.9545e-02,  2.9380e-02,  ...,  2.3240e-02,
#              2.3542e-02,  2.3728e-02],
#            [ 2.9479e-02,  2.9263e-02,  2.9045e-02,  ...,  2.2269e-02,
#              2.2591e-02,  2.2789e-02],
#            [ 2.9252e-02,  2.8983e-02,  2.8712e-02,  ...,  2.1294e-02,
#              2.1632e-02,  2.1854e-02],
#            ...,
#            [ 1.9398e-02,  1.8540e-02,  1.7682e-02,  ...,  1.8683e-02,
#              1.9116e-02,  1.9650e-02],
#            [ 1.9395e-02,  1.8579e-02,  1.7763e-02,  ...,  1.8735e-02,
#              1.9179e-02,  1.9732e-02],
#            [ 1.9411e-02,  1.8574e-02,  1.7737e-02,  ...,  1.8753e-02,
#              1.9210e-02,  1.9777e-02]],
#
#           ...,
#
#           [[ 9.8325e-01,  9.8358e-01,  9.8420e-01,  ...,  9.6710e-01,
#              9.6753e-01,  9.6779e-01],
#            [ 9.8350e-01,  9.8375e-01,  9.8435e-01,  ...,  9.6696e-01,
#              9.6742e-01,  9.6765e-01],
#            [ 9.8376e-01,  9.8391e-01,  9.8451e-01,  ...,  9.6682e-01,
#              9.6731e-01,  9.6752e-01],
#            ...,
#            [ 9.9606e-01,  9.9636e-01,  9.9666e-01,  ...,  1.0027e+00,
#              1.0026e+00,  1.0027e+00],
#            [ 9.9589e-01,  9.9616e-01,  9.9644e-01,  ...,  1.0031e+00,
#              1.0031e+00,  1.0032e+00],
#            [ 9.9577e-01,  9.9602e-01,  9.9628e-01,  ...,  1.0031e+00,
#              1.0030e+00,  1.0031e+00]],
#
#           [[ 9.9563e-01,  9.9594e-01,  9.9657e-01,  ...,  9.7788e-01,
#              9.7834e-01,  9.7857e-01],
#            [ 9.9592e-01,  9.9615e-01,  9.9677e-01,  ...,  9.7768e-01,
#              9.7819e-01,  9.7838e-01],
#            [ 9.9620e-01,  9.9635e-01,  9.9696e-01,  ...,  9.7749e-01,
#              9.7804e-01,  9.7819e-01],
#            ...,
#            [ 1.0102e+00,  1.0105e+00,  1.0108e+00,  ...,  1.0168e+00,
#              1.0165e+00,  1.0164e+00],
#            [ 1.0101e+00,  1.0103e+00,  1.0105e+00,  ...,  1.0169e+00,
#              1.0167e+00,  1.0166e+00],
#            [ 1.0099e+00,  1.0101e+00,  1.0104e+00,  ...,  1.0168e+00,
#              1.0166e+00,  1.0165e+00]],
#
#           [[ 1.0088e+00,  1.0091e+00,  1.0097e+00,  ...,  9.8869e-01,
#              9.8912e-01,  9.8939e-01],
#            [ 1.0092e+00,  1.0094e+00,  1.0099e+00,  ...,  9.8845e-01,
#              9.8892e-01,  9.8915e-01],
#            [ 1.0095e+00,  1.0096e+00,  1.0102e+00,  ...,  9.8821e-01,
#              9.8873e-01,  9.8891e-01],
#            ...,
#            [ 1.0246e+00,  1.0250e+00,  1.0254e+00,  ...,  1.0307e+00,
#              1.0305e+00,  1.0302e+00],
#            [ 1.0244e+00,  1.0247e+00,  1.0251e+00,  ...,  1.0308e+00,
#              1.0306e+00,  1.0304e+00],
#            [ 1.0242e+00,  1.0246e+00,  1.0249e+00,  ...,  1.0305e+00,
#              1.0303e+00,  1.0301e+00]]],
#
#
#          [[[ 5.3267e-03,  5.8489e-03,  6.3744e-03,  ...,  9.8325e-03,
#              9.9527e-03,  1.0026e-02],
#            [ 1.0633e-02,  1.1143e-02,  1.1655e-02,  ...,  1.4491e-02,
#              1.4617e-02,  1.4722e-02],
#            [ 1.5939e-02,  1.6435e-02,  1.6934e-02,  ...,  1.9162e-02,
#              1.9290e-02,  1.9419e-02],
#            ...,
#            [ 9.9170e-01,  9.9173e-01,  9.9176e-01,  ...,  1.0548e+00,
#              1.0552e+00,  1.0557e+00],
#            [ 9.9704e-01,  9.9707e-01,  9.9709e-01,  ...,  1.0602e+00,
#              1.0607e+00,  1.0611e+00],
#            [ 1.0022e+00,  1.0022e+00,  1.0022e+00,  ...,  1.0655e+00,
#              1.0659e+00,  1.0664e+00]],
#
#           [[ 5.5550e-03,  6.0312e-03,  6.5101e-03,  ...,  1.0294e-02,
#              1.0350e-02,  1.0530e-02],
#            [ 1.0869e-02,  1.1354e-02,  1.1842e-02,  ...,  1.5019e-02,
#              1.5081e-02,  1.5263e-02],
#            [ 1.6181e-02,  1.6675e-02,  1.7172e-02,  ...,  1.9745e-02,
#              1.9813e-02,  1.9996e-02],
#            ...,
#            [ 9.9178e-01,  9.9179e-01,  9.9180e-01,  ...,  1.0553e+00,
#              1.0558e+00,  1.0563e+00],
#            [ 9.9707e-01,  9.9708e-01,  9.9709e-01,  ...,  1.0608e+00,
#              1.0613e+00,  1.0617e+00],
#            [ 1.0022e+00,  1.0023e+00,  1.0023e+00,  ...,  1.0660e+00,
#              1.0665e+00,  1.0670e+00]],
#
#           [[ 5.7925e-03,  6.2264e-03,  6.6628e-03,  ...,  1.0753e-02,
#              1.0749e-02,  1.1035e-02],
#            [ 1.1115e-02,  1.1582e-02,  1.2051e-02,  ...,  1.5543e-02,
#              1.5540e-02,  1.5805e-02],
#            [ 1.6436e-02,  1.6934e-02,  1.7435e-02,  ...,  2.0333e-02,
#              2.0338e-02,  2.0576e-02],
#            ...,
#            [ 9.9186e-01,  9.9185e-01,  9.9184e-01,  ...,  1.0559e+00,
#              1.0564e+00,  1.0569e+00],
#            [ 9.9708e-01,  9.9707e-01,  9.9707e-01,  ...,  1.0614e+00,
#              1.0619e+00,  1.0624e+00],
#            [ 1.0023e+00,  1.0023e+00,  1.0023e+00,  ...,  1.0666e+00,
#              1.0671e+00,  1.0676e+00]],
#
#           ...,
#
#           [[ 1.7487e-03,  1.9358e-03,  2.3317e-03,  ...,  3.3861e-03,
#              3.4617e-03,  3.3321e-03],
#            [ 5.6434e-03,  5.6982e-03,  6.0083e-03,  ...,  7.7271e-03,
#              7.7742e-03,  7.6546e-03],
#            [ 9.5380e-03,  9.4646e-03,  9.6892e-03,  ...,  1.2064e-02,
#              1.2084e-02,  1.1974e-02],
#            ...,
#            [ 1.0048e+00,  1.0053e+00,  1.0058e+00,  ...,  1.0655e+00,
#              1.0659e+00,  1.0663e+00],
#            [ 1.0104e+00,  1.0109e+00,  1.0114e+00,  ...,  1.0718e+00,
#              1.0720e+00,  1.0723e+00],
#            [ 1.0159e+00,  1.0164e+00,  1.0170e+00,  ...,  1.0783e+00,
#              1.0784e+00,  1.0786e+00]],
#
#           [[ 1.5835e-03,  1.7148e-03,  2.0849e-03,  ...,  3.1816e-03,
#              3.2176e-03,  3.1309e-03],
#            [ 5.4326e-03,  5.4362e-03,  5.7215e-03,  ...,  7.5500e-03,
#              7.5563e-03,  7.4813e-03],
#            [ 9.2816e-03,  9.1622e-03,  9.3628e-03,  ...,  1.1916e-02,
#              1.1895e-02,  1.1830e-02],
#            ...,
#            [ 1.0050e+00,  1.0055e+00,  1.0060e+00,  ...,  1.0667e+00,
#              1.0670e+00,  1.0674e+00],
#            [ 1.0105e+00,  1.0111e+00,  1.0116e+00,  ...,  1.0731e+00,
#              1.0733e+00,  1.0735e+00],
#            [ 1.0161e+00,  1.0166e+00,  1.0171e+00,  ...,  1.0797e+00,
#              1.0797e+00,  1.0799e+00]],
#
#           [[ 1.5052e-03,  1.6793e-03,  2.0911e-03,  ...,  3.0882e-03,
#              3.1710e-03,  3.0452e-03],
#            [ 5.3480e-03,  5.3881e-03,  5.7094e-03,  ...,  7.4547e-03,
#              7.5082e-03,  7.3932e-03],
#            [ 9.1910e-03,  9.1020e-03,  9.3329e-03,  ...,  1.1820e-02,
#              1.1845e-02,  1.1741e-02],
#            ...,
#            [ 1.0048e+00,  1.0053e+00,  1.0058e+00,  ...,  1.0665e+00,
#              1.0669e+00,  1.0673e+00],
#            [ 1.0104e+00,  1.0108e+00,  1.0113e+00,  ...,  1.0729e+00,
#              1.0731e+00,  1.0734e+00],
#            [ 1.0159e+00,  1.0164e+00,  1.0169e+00,  ...,  1.0795e+00,
#              1.0797e+00,  1.0799e+00]]],
#
#
#          [[[ 2.0227e-03,  7.2161e-03,  1.2415e-02,  ...,  9.9068e-01,
#              9.9570e-01,  1.0009e+00],
#            [ 1.8533e-03,  7.0463e-03,  1.2244e-02,  ...,  9.9049e-01,
#              9.9554e-01,  1.0007e+00],
#            [ 1.6823e-03,  6.8739e-03,  1.2070e-02,  ...,  9.9029e-01,
#              9.9539e-01,  1.0005e+00],
#            ...,
#            [ 5.9635e-03,  1.0750e-02,  1.5537e-02,  ...,  9.4649e-01,
#              9.5147e-01,  9.5676e-01],
#            [ 5.9874e-03,  1.0786e-02,  1.5585e-02,  ...,  9.4626e-01,
#              9.5120e-01,  9.5651e-01],
#            [ 5.9710e-03,  1.0806e-02,  1.5641e-02,  ...,  9.4621e-01,
#              9.5118e-01,  9.5647e-01]],
#
#           [[ 1.7513e-03,  7.0116e-03,  1.2273e-02,  ...,  9.9094e-01,
#              9.9597e-01,  1.0011e+00],
#            [ 1.6035e-03,  6.8422e-03,  1.2083e-02,  ...,  9.9076e-01,
#              9.9581e-01,  1.0009e+00],
#            [ 1.4537e-03,  6.6704e-03,  1.1890e-02,  ...,  9.9057e-01,
#              9.9565e-01,  1.0007e+00],
#            ...,
#            [ 6.0418e-03,  1.0830e-02,  1.5622e-02,  ...,  9.4769e-01,
#              9.5278e-01,  9.5809e-01],
#            [ 6.0682e-03,  1.0859e-02,  1.5656e-02,  ...,  9.4753e-01,
#              9.5261e-01,  9.5792e-01],
#            [ 6.0690e-03,  1.0904e-02,  1.5743e-02,  ...,  9.4746e-01,
#              9.5256e-01,  9.5786e-01]],
#
#           [[ 1.4686e-03,  6.7933e-03,  1.2118e-02,  ...,  9.9119e-01,
#              9.9623e-01,  1.0014e+00],
#            [ 1.3433e-03,  6.6252e-03,  1.1908e-02,  ...,  9.9102e-01,
#              9.9607e-01,  1.0012e+00],
#            [ 1.2167e-03,  6.4556e-03,  1.1695e-02,  ...,  9.9085e-01,
#              9.9591e-01,  1.0010e+00],
#            ...,
#            [ 6.1345e-03,  1.0910e-02,  1.5690e-02,  ...,  9.4896e-01,
#              9.5420e-01,  9.5950e-01],
#            [ 6.1919e-03,  1.0957e-02,  1.5728e-02,  ...,  9.4888e-01,
#              9.5411e-01,  9.5942e-01],
#            [ 6.1840e-03,  1.1004e-02,  1.5830e-02,  ...,  9.4878e-01,
#              9.5404e-01,  9.5933e-01]],
#
#           ...,
#
#           [[-5.0526e-03,  5.7807e-04,  6.4257e-03,  ...,  9.9383e-01,
#              9.9886e-01,  1.0039e+00],
#            [-5.8139e-03, -2.7211e-04,  5.5461e-03,  ...,  9.9363e-01,
#              9.9862e-01,  1.0037e+00],
#            [-6.5764e-03, -1.1238e-03,  4.6655e-03,  ...,  9.9343e-01,
#              9.9838e-01,  1.0035e+00],
#            ...,
#            [ 1.0175e-03,  5.4134e-03,  9.8108e-03,  ...,  1.0071e+00,
#              1.0120e+00,  1.0162e+00],
#            [ 1.2199e-03,  5.6372e-03,  1.0057e-02,  ...,  1.0079e+00,
#              1.0126e+00,  1.0166e+00],
#            [ 1.6347e-03,  6.0382e-03,  1.0444e-02,  ...,  1.0070e+00,
#              1.0116e+00,  1.0156e+00]],
#
#           [[-5.4057e-03,  2.7757e-04,  6.2103e-03,  ...,  9.9448e-01,
#              9.9956e-01,  1.0046e+00],
#            [-6.1103e-03, -5.3015e-04,  5.3499e-03,  ...,  9.9426e-01,
#              9.9928e-01,  1.0044e+00],
#            [-6.8157e-03, -1.3361e-03,  4.4918e-03,  ...,  9.9404e-01,
#              9.9900e-01,  1.0041e+00],
#            ...,
#            [ 1.0053e-03,  5.4016e-03,  9.7959e-03,  ...,  1.0077e+00,
#              1.0127e+00,  1.0168e+00],
#            [ 1.2050e-03,  5.6266e-03,  1.0048e-02,  ...,  1.0085e+00,
#              1.0132e+00,  1.0172e+00],
#            [ 1.6583e-03,  6.0726e-03,  1.0487e-02,  ...,  1.0073e+00,
#              1.0120e+00,  1.0160e+00]],
#
#           [[-5.4003e-03,  1.6781e-04,  5.9569e-03,  ...,  9.9522e-01,
#              1.0002e+00,  1.0053e+00],
#            [-6.1680e-03, -6.8369e-04,  5.0735e-03,  ...,  9.9507e-01,
#              1.0001e+00,  1.0052e+00],
#            [-6.9348e-03, -1.5346e-03,  4.1903e-03,  ...,  9.9492e-01,
#              9.9987e-01,  1.0050e+00],
#            ...,
#            [ 1.1724e-03,  5.5836e-03,  9.9938e-03,  ...,  1.0066e+00,
#              1.0116e+00,  1.0159e+00],
#            [ 1.4000e-03,  5.8290e-03,  1.0258e-02,  ...,  1.0073e+00,
#              1.0121e+00,  1.0163e+00],
#            [ 1.8346e-03,  6.2457e-03,  1.0657e-02,  ...,  1.0064e+00,
#              1.0111e+00,  1.0153e+00]]]],
#
#
#
#         [[[[ 4.2053e-03,  4.1653e-03,  4.2330e-03,  ..., -1.3955e-02,
#             -1.3934e-02, -1.3940e-02],
#            [ 4.5665e-03,  4.5629e-03,  4.7070e-03,  ..., -1.4682e-02,
#             -1.4666e-02, -1.4647e-02],
#            [ 4.9306e-03,  4.9630e-03,  5.1933e-03,  ..., -1.5464e-02,
#             -1.5473e-02, -1.5438e-02],
#            ...,
#            [ 1.4039e-03,  1.2103e-03,  1.1601e-03,  ..., -2.2135e-03,
#             -2.4425e-03, -2.7524e-03],
#            [ 1.3554e-03,  1.1659e-03,  1.1317e-03,  ..., -2.3656e-03,
#             -2.5475e-03, -2.8223e-03],
#            [ 1.3571e-03,  1.1747e-03,  1.1326e-03,  ..., -2.4345e-03,
#             -2.6509e-03, -2.9661e-03]],
#
#           [[ 1.6971e-02,  1.6984e-02,  1.7139e-02,  ..., -2.4062e-03,
#             -2.3654e-03, -2.3705e-03],
#            [ 1.7249e-02,  1.7271e-02,  1.7467e-02,  ..., -2.8980e-03,
#             -2.8446e-03, -2.8472e-03],
#            [ 1.7536e-02,  1.7570e-02,  1.7823e-02,  ..., -3.5051e-03,
#             -3.4482e-03, -3.4576e-03],
#            ...,
#            [ 1.4137e-02,  1.3941e-02,  1.3896e-02,  ...,  9.1466e-03,
#              8.8399e-03,  8.4856e-03],
#            [ 1.4120e-02,  1.3929e-02,  1.3903e-02,  ...,  9.0321e-03,
#              8.7496e-03,  8.4019e-03],
#            [ 1.4081e-02,  1.3896e-02,  1.3857e-02,  ...,  8.8558e-03,
#              8.5665e-03,  8.2049e-03]],
#
#           [[ 2.9736e-02,  2.9806e-02,  3.0051e-02,  ...,  9.1401e-03,
#              9.2030e-03,  9.1986e-03],
#            [ 2.9931e-02,  2.9981e-02,  3.0232e-02,  ...,  8.8519e-03,
#              8.9383e-03,  8.9203e-03],
#            [ 3.0141e-02,  3.0179e-02,  3.0456e-02,  ...,  8.4266e-03,
#              8.5351e-03,  8.4870e-03],
#            ...,
#            [ 2.6870e-02,  2.6673e-02,  2.6632e-02,  ...,  2.0510e-02,
#              2.0125e-02,  1.9727e-02],
#            [ 2.6884e-02,  2.6693e-02,  2.6675e-02,  ...,  2.0440e-02,
#              2.0056e-02,  1.9634e-02],
#            [ 2.6805e-02,  2.6618e-02,  2.6583e-02,  ...,  2.0152e-02,
#              1.9789e-02,  1.9380e-02]],
#
#           ...,
#
#           [[ 9.5800e-01,  9.5737e-01,  9.5673e-01,  ...,  9.2757e-01,
#              9.2770e-01,  9.2779e-01],
#            [ 9.5777e-01,  9.5716e-01,  9.5653e-01,  ...,  9.2747e-01,
#              9.2761e-01,  9.2764e-01],
#            [ 9.5737e-01,  9.5695e-01,  9.5650e-01,  ...,  9.2737e-01,
#              9.2752e-01,  9.2749e-01],
#            ...,
#            [ 9.5723e-01,  9.5701e-01,  9.5670e-01,  ...,  9.1006e-01,
#              9.0951e-01,  9.0883e-01],
#            [ 9.5729e-01,  9.5703e-01,  9.5668e-01,  ...,  9.1022e-01,
#              9.0971e-01,  9.0912e-01],
#            [ 9.5720e-01,  9.5697e-01,  9.5666e-01,  ...,  9.0979e-01,
#              9.0937e-01,  9.0897e-01]],
#
#           [[ 9.6940e-01,  9.6869e-01,  9.6799e-01,  ...,  9.3772e-01,
#              9.3787e-01,  9.3798e-01],
#            [ 9.6912e-01,  9.6844e-01,  9.6774e-01,  ...,  9.3759e-01,
#              9.3776e-01,  9.3780e-01],
#            [ 9.6859e-01,  9.6811e-01,  9.6760e-01,  ...,  9.3747e-01,
#              9.3765e-01,  9.3761e-01],
#            ...,
#            [ 9.6942e-01,  9.6916e-01,  9.6880e-01,  ...,  9.2209e-01,
#              9.2140e-01,  9.2055e-01],
#            [ 9.6948e-01,  9.6918e-01,  9.6879e-01,  ...,  9.2223e-01,
#              9.2163e-01,  9.2087e-01],
#            [ 9.6942e-01,  9.6915e-01,  9.6879e-01,  ...,  9.2166e-01,
#              9.2118e-01,  9.2062e-01]],
#
#           [[ 9.8075e-01,  9.7996e-01,  9.7917e-01,  ...,  9.4813e-01,
#              9.4826e-01,  9.4838e-01],
#            [ 9.8045e-01,  9.7971e-01,  9.7893e-01,  ...,  9.4792e-01,
#              9.4807e-01,  9.4812e-01],
#            [ 9.7985e-01,  9.7931e-01,  9.7874e-01,  ...,  9.4770e-01,
#              9.4786e-01,  9.4784e-01],
#            ...,
#            [ 9.8125e-01,  9.8103e-01,  9.8069e-01,  ...,  9.3220e-01,
#              9.3158e-01,  9.3092e-01],
#            [ 9.8133e-01,  9.8107e-01,  9.8071e-01,  ...,  9.3232e-01,
#              9.3165e-01,  9.3105e-01],
#            [ 9.8128e-01,  9.8104e-01,  9.8072e-01,  ...,  9.3182e-01,
#              9.3112e-01,  9.3066e-01]]],
#
#
#          [[[-1.2780e-03, -1.5533e-03, -1.8719e-03,  ..., -2.6464e-03,
#             -2.7513e-03, -2.9631e-03],
#            [ 4.2154e-03,  3.9257e-03,  3.6102e-03,  ...,  2.1973e-03,
#              2.0360e-03,  1.8036e-03],
#            [ 9.7224e-03,  9.4352e-03,  9.1459e-03,  ...,  7.0744e-03,
#              6.8567e-03,  6.6120e-03],
#            ...,
#            [ 9.9175e-01,  9.9195e-01,  9.9221e-01,  ...,  1.0425e+00,
#              1.0424e+00,  1.0424e+00],
#            [ 9.9700e-01,  9.9721e-01,  9.9747e-01,  ...,  1.0477e+00,
#              1.0476e+00,  1.0476e+00],
#            [ 1.0022e+00,  1.0024e+00,  1.0026e+00,  ...,  1.0531e+00,
#              1.0530e+00,  1.0529e+00]],
#
#           [[-1.6027e-03, -1.9454e-03, -2.3245e-03,  ..., -2.7783e-03,
#             -2.9140e-03, -3.0108e-03],
#            [ 3.8670e-03,  3.5141e-03,  3.1415e-03,  ...,  2.0317e-03,
#              1.8300e-03,  1.6881e-03],
#            [ 9.3754e-03,  9.0365e-03,  8.7040e-03,  ...,  6.9101e-03,
#              6.6445e-03,  6.4630e-03],
#            ...,
#            [ 9.9165e-01,  9.9182e-01,  9.9208e-01,  ...,  1.0425e+00,
#              1.0424e+00,  1.0423e+00],
#            [ 9.9682e-01,  9.9702e-01,  9.9729e-01,  ...,  1.0478e+00,
#              1.0477e+00,  1.0476e+00],
#            [ 1.0020e+00,  1.0022e+00,  1.0025e+00,  ...,  1.0531e+00,
#              1.0530e+00,  1.0529e+00]],
#
#           [[-1.9274e-03, -2.3368e-03, -2.7762e-03,  ..., -2.9239e-03,
#             -3.0625e-03, -3.0458e-03],
#            [ 3.5155e-03,  3.0993e-03,  2.6685e-03,  ...,  1.8623e-03,
#              1.6469e-03,  1.5974e-03],
#            [ 9.0252e-03,  8.6350e-03,  8.2584e-03,  ...,  6.7423e-03,
#              6.4528e-03,  6.3366e-03],
#            ...,
#            [ 9.9154e-01,  9.9170e-01,  9.9195e-01,  ...,  1.0425e+00,
#              1.0424e+00,  1.0423e+00],
#            [ 9.9665e-01,  9.9684e-01,  9.9710e-01,  ...,  1.0479e+00,
#              1.0477e+00,  1.0476e+00],
#            [ 1.0019e+00,  1.0021e+00,  1.0023e+00,  ...,  1.0531e+00,
#              1.0530e+00,  1.0529e+00]],
#
#           ...,
#
#           [[-3.2692e-03, -3.5534e-03, -3.8372e-03,  ..., -4.4821e-03,
#             -4.4844e-03, -4.6548e-03],
#            [ 2.6063e-03,  2.3421e-03,  2.0676e-03,  ...,  1.8401e-03,
#              1.7688e-03,  1.6182e-03],
#            [ 9.1005e-03,  8.9851e-03,  8.8615e-03,  ...,  8.2118e-03,
#              8.0774e-03,  7.9618e-03],
#            ...,
#            [ 9.9378e-01,  9.9396e-01,  9.9473e-01,  ...,  1.0493e+00,
#              1.0490e+00,  1.0491e+00],
#            [ 9.9874e-01,  9.9894e-01,  9.9969e-01,  ...,  1.0544e+00,
#              1.0540e+00,  1.0541e+00],
#            [ 1.0037e+00,  1.0039e+00,  1.0046e+00,  ...,  1.0593e+00,
#              1.0589e+00,  1.0590e+00]],
#
#           [[-3.3439e-03, -3.6689e-03, -3.9938e-03,  ..., -4.6082e-03,
#             -4.6421e-03, -4.7583e-03],
#            [ 2.5517e-03,  2.2451e-03,  1.9272e-03,  ...,  1.7457e-03,
#              1.6437e-03,  1.5466e-03],
#            [ 9.1103e-03,  8.9621e-03,  8.8048e-03,  ...,  8.1483e-03,
#              7.9867e-03,  7.9251e-03],
#            ...,
#            [ 9.9388e-01,  9.9408e-01,  9.9487e-01,  ...,  1.0499e+00,
#              1.0496e+00,  1.0497e+00],
#            [ 9.9880e-01,  9.9903e-01,  9.9982e-01,  ...,  1.0549e+00,
#              1.0545e+00,  1.0546e+00],
#            [ 1.0038e+00,  1.0040e+00,  1.0047e+00,  ...,  1.0596e+00,
#              1.0592e+00,  1.0593e+00]],
#
#           [[-3.2496e-03, -3.5439e-03, -3.8385e-03,  ..., -4.3906e-03,
#             -4.4060e-03, -4.5932e-03],
#            [ 2.6755e-03,  2.3978e-03,  2.1086e-03,  ...,  1.9921e-03,
#              1.9072e-03,  1.7345e-03],
#            [ 9.2528e-03,  9.1268e-03,  8.9910e-03,  ...,  8.4211e-03,
#              8.2745e-03,  8.1314e-03],
#            ...,
#            [ 9.9392e-01,  9.9416e-01,  9.9499e-01,  ...,  1.0512e+00,
#              1.0508e+00,  1.0509e+00],
#            [ 9.9887e-01,  9.9914e-01,  9.9998e-01,  ...,  1.0562e+00,
#              1.0558e+00,  1.0558e+00],
#            [ 1.0039e+00,  1.0041e+00,  1.0049e+00,  ...,  1.0608e+00,
#              1.0604e+00,  1.0604e+00]]],
#
#
#          [[[-3.9944e-03,  1.2424e-03,  6.4759e-03,  ...,  1.0287e+00,
#              1.0335e+00,  1.0388e+00],
#            [-4.3293e-03,  8.5108e-04,  6.0680e-03,  ...,  1.0307e+00,
#              1.0354e+00,  1.0406e+00],
#            [-4.6671e-03,  4.4400e-04,  5.6429e-03,  ...,  1.0328e+00,
#              1.0375e+00,  1.0426e+00],
#            ...,
#            [-1.0852e-02, -5.7906e-03, -7.1338e-04,  ...,  1.0141e+00,
#              1.0192e+00,  1.0242e+00],
#            [-1.0926e-02, -5.8727e-03, -7.8695e-04,  ...,  1.0142e+00,
#              1.0194e+00,  1.0243e+00],
#            [-1.0799e-02, -5.7104e-03, -6.0459e-04,  ...,  1.0145e+00,
#              1.0197e+00,  1.0247e+00]],
#
#           [[-4.2936e-03,  1.0345e-03,  6.3796e-03,  ...,  1.0306e+00,
#              1.0355e+00,  1.0407e+00],
#            [-4.5525e-03,  7.0677e-04,  6.0043e-03,  ...,  1.0322e+00,
#              1.0369e+00,  1.0420e+00],
#            [-4.8199e-03,  3.6230e-04,  5.6132e-03,  ...,  1.0342e+00,
#              1.0389e+00,  1.0439e+00],
#            ...,
#            [-1.1106e-02, -5.9800e-03, -8.6131e-04,  ...,  1.0137e+00,
#              1.0188e+00,  1.0239e+00],
#            [-1.1148e-02, -6.0282e-03, -9.0790e-04,  ...,  1.0139e+00,
#              1.0190e+00,  1.0241e+00],
#            [-1.1081e-02, -5.9311e-03, -7.8336e-04,  ...,  1.0140e+00,
#              1.0193e+00,  1.0243e+00]],
#
#           [[-4.5927e-03,  8.2877e-04,  6.2866e-03,  ...,  1.0325e+00,
#              1.0374e+00,  1.0425e+00],
#            [-4.7832e-03,  5.5539e-04,  5.9375e-03,  ...,  1.0337e+00,
#              1.0385e+00,  1.0435e+00],
#            [-4.9805e-03,  2.7107e-04,  5.5772e-03,  ...,  1.0356e+00,
#              1.0404e+00,  1.0453e+00],
#            ...,
#            [-1.1362e-02, -6.1725e-03, -1.0124e-03,  ...,  1.0133e+00,
#              1.0185e+00,  1.0236e+00],
#            [-1.1364e-02, -6.1790e-03, -1.0224e-03,  ...,  1.0135e+00,
#              1.0187e+00,  1.0238e+00],
#            [-1.1360e-02, -6.1479e-03, -9.5813e-04,  ...,  1.0135e+00,
#              1.0188e+00,  1.0240e+00]],
#
#           ...,
#
#           [[ 8.8222e-03,  1.6727e-02,  2.4631e-02,  ...,  9.9109e-01,
#              9.9575e-01,  1.0004e+00],
#            [ 9.1878e-03,  1.7039e-02,  2.4863e-02,  ...,  9.9099e-01,
#              9.9563e-01,  1.0003e+00],
#            [ 9.8080e-03,  1.7785e-02,  2.5739e-02,  ...,  9.9086e-01,
#              9.9548e-01,  1.0002e+00],
#            ...,
#            [-9.3721e-03, -3.5207e-03,  2.7897e-03,  ...,  1.0140e+00,
#              1.0191e+00,  1.0242e+00],
#            [-9.6199e-03, -3.8120e-03,  2.3752e-03,  ...,  1.0143e+00,
#              1.0194e+00,  1.0243e+00],
#            [-9.9150e-03, -4.1431e-03,  2.0069e-03,  ...,  1.0150e+00,
#              1.0200e+00,  1.0250e+00]],
#
#           [[ 9.1271e-03,  1.7132e-02,  2.5136e-02,  ...,  9.9084e-01,
#              9.9555e-01,  1.0002e+00],
#            [ 9.5491e-03,  1.7481e-02,  2.5386e-02,  ...,  9.9071e-01,
#              9.9539e-01,  1.0001e+00],
#            [ 1.0299e-02,  1.8338e-02,  2.6354e-02,  ...,  9.9055e-01,
#              9.9521e-01,  9.9995e-01],
#            ...,
#            [-8.9858e-03, -3.1403e-03,  3.2102e-03,  ...,  1.0144e+00,
#              1.0195e+00,  1.0245e+00],
#            [-9.1557e-03, -3.3609e-03,  2.8316e-03,  ...,  1.0147e+00,
#              1.0198e+00,  1.0247e+00],
#            [-9.5179e-03, -3.7579e-03,  2.4310e-03,  ...,  1.0153e+00,
#              1.0203e+00,  1.0252e+00]],
#
#           [[ 9.3858e-03,  1.7373e-02,  2.5360e-02,  ...,  9.9059e-01,
#              9.9528e-01,  9.9994e-01],
#            [ 9.7841e-03,  1.7709e-02,  2.5605e-02,  ...,  9.9051e-01,
#              9.9518e-01,  9.9986e-01],
#            [ 1.0454e-02,  1.8505e-02,  2.6532e-02,  ...,  9.9040e-01,
#              9.9506e-01,  9.9976e-01],
#            ...,
#            [-8.8505e-03, -2.9646e-03,  3.4943e-03,  ...,  1.0132e+00,
#              1.0181e+00,  1.0230e+00],
#            [-9.0682e-03, -3.2208e-03,  3.1058e-03,  ...,  1.0133e+00,
#              1.0182e+00,  1.0230e+00],
#            [-9.3648e-03, -3.5594e-03,  2.7246e-03,  ...,  1.0139e+00,
#              1.0187e+00,  1.0235e+00]]]],
#
#
#
#         [[[[ 1.7741e-02,  1.8460e-02,  1.9180e-02,  ...,  3.7889e-02,
#              3.8083e-02,  3.8201e-02],
#            [ 1.8506e-02,  1.9266e-02,  2.0027e-02,  ...,  4.0203e-02,
#              4.0371e-02,  4.0510e-02],
#            [ 1.9269e-02,  2.0069e-02,  2.0870e-02,  ...,  4.2516e-02,
#              4.2658e-02,  4.2817e-02],
#            ...,
#            [ 1.8206e-02,  1.8834e-02,  1.9463e-02,  ...,  2.4309e-02,
#              2.4365e-02,  2.4516e-02],
#            [ 1.8128e-02,  1.8797e-02,  1.9468e-02,  ...,  2.3962e-02,
#              2.4035e-02,  2.4197e-02],
#            [ 1.8240e-02,  1.8880e-02,  1.9518e-02,  ...,  2.3701e-02,
#              2.3774e-02,  2.3905e-02]],
#
#           [[ 3.1272e-02,  3.2026e-02,  3.2780e-02,  ...,  5.2190e-02,
#              5.2368e-02,  5.2449e-02],
#            [ 3.2023e-02,  3.2782e-02,  3.3541e-02,  ...,  5.4451e-02,
#              5.4630e-02,  5.4694e-02],
#            [ 3.2774e-02,  3.3538e-02,  3.4302e-02,  ...,  5.6709e-02,
#              5.6894e-02,  5.6938e-02],
#            ...,
#            [ 3.2115e-02,  3.2592e-02,  3.3071e-02,  ...,  3.7175e-02,
#              3.7172e-02,  3.7277e-02],
#            [ 3.2072e-02,  3.2600e-02,  3.3131e-02,  ...,  3.6796e-02,
#              3.6801e-02,  3.6910e-02],
#            [ 3.2147e-02,  3.2638e-02,  3.3125e-02,  ...,  3.6500e-02,
#              3.6501e-02,  3.6582e-02]],
#
#           [[ 4.4803e-02,  4.5593e-02,  4.6383e-02,  ...,  6.6495e-02,
#              6.6650e-02,  6.6701e-02],
#            [ 4.5540e-02,  4.6299e-02,  4.7058e-02,  ...,  6.8705e-02,
#              6.8884e-02,  6.8879e-02],
#            [ 4.6278e-02,  4.7007e-02,  4.7736e-02,  ...,  7.0912e-02,
#              7.1121e-02,  7.1056e-02],
#            ...,
#            [ 4.6019e-02,  4.6344e-02,  4.6672e-02,  ...,  5.0043e-02,
#              4.9982e-02,  5.0040e-02],
#            [ 4.6014e-02,  4.6399e-02,  4.6788e-02,  ...,  4.9630e-02,
#              4.9567e-02,  4.9624e-02],
#            [ 4.6052e-02,  4.6390e-02,  4.6726e-02,  ...,  4.9300e-02,
#              4.9228e-02,  4.9260e-02]],
#
#           ...,
#
#           [[ 9.8612e-01,  9.8686e-01,  9.8760e-01,  ...,  9.8844e-01,
#              9.8842e-01,  9.8839e-01],
#            [ 9.8730e-01,  9.8812e-01,  9.8895e-01,  ...,  9.8931e-01,
#              9.8931e-01,  9.8921e-01],
#            [ 9.8848e-01,  9.8939e-01,  9.9031e-01,  ...,  9.9018e-01,
#              9.9020e-01,  9.9003e-01],
#            ...,
#            [ 9.8605e-01,  9.8646e-01,  9.8686e-01,  ...,  9.7060e-01,
#              9.7063e-01,  9.7086e-01],
#            [ 9.8591e-01,  9.8625e-01,  9.8659e-01,  ...,  9.6973e-01,
#              9.6974e-01,  9.7011e-01],
#            [ 9.8585e-01,  9.8622e-01,  9.8658e-01,  ...,  9.6919e-01,
#              9.6916e-01,  9.6947e-01]],
#
#           [[ 9.9757e-01,  9.9825e-01,  9.9892e-01,  ...,  9.9969e-01,
#              9.9966e-01,  9.9962e-01],
#            [ 9.9869e-01,  9.9946e-01,  1.0002e+00,  ...,  1.0005e+00,
#              1.0005e+00,  1.0004e+00],
#            [ 9.9982e-01,  1.0007e+00,  1.0015e+00,  ...,  1.0014e+00,
#              1.0014e+00,  1.0012e+00],
#            ...,
#            [ 9.9645e-01,  9.9669e-01,  9.9695e-01,  ...,  9.8327e-01,
#              9.8323e-01,  9.8347e-01],
#            [ 9.9627e-01,  9.9646e-01,  9.9665e-01,  ...,  9.8236e-01,
#              9.8228e-01,  9.8270e-01],
#            [ 9.9623e-01,  9.9644e-01,  9.9664e-01,  ...,  9.8173e-01,
#              9.8160e-01,  9.8197e-01]],
#
#           [[ 1.0089e+00,  1.0095e+00,  1.0102e+00,  ...,  1.0111e+00,
#              1.0111e+00,  1.0110e+00],
#            [ 1.0099e+00,  1.0106e+00,  1.0114e+00,  ...,  1.0119e+00,
#              1.0118e+00,  1.0117e+00],
#            [ 1.0109e+00,  1.0117e+00,  1.0126e+00,  ...,  1.0126e+00,
#              1.0126e+00,  1.0124e+00],
#            ...,
#            [ 1.0062e+00,  1.0065e+00,  1.0068e+00,  ...,  9.9475e-01,
#              9.9468e-01,  9.9480e-01],
#            [ 1.0061e+00,  1.0063e+00,  1.0065e+00,  ...,  9.9396e-01,
#              9.9383e-01,  9.9411e-01],
#            [ 1.0061e+00,  1.0063e+00,  1.0065e+00,  ...,  9.9337e-01,
#              9.9321e-01,  9.9349e-01]]],
#
#
#          [[[ 2.3077e-04,  3.8217e-04,  5.3503e-04,  ...,  3.2062e-03,
#              3.3161e-03,  3.2623e-03],
#            [ 5.2829e-03,  5.4362e-03,  5.5905e-03,  ...,  9.0333e-03,
#              9.1530e-03,  9.1122e-03],
#            [ 1.0333e-02,  1.0488e-02,  1.0643e-02,  ...,  1.4861e-02,
#              1.4991e-02,  1.4962e-02],
#            ...,
#            [ 9.8122e-01,  9.8087e-01,  9.8052e-01,  ...,  9.5296e-01,
#              9.5292e-01,  9.5290e-01],
#            [ 9.8660e-01,  9.8624e-01,  9.8588e-01,  ...,  9.5806e-01,
#              9.5798e-01,  9.5795e-01],
#            [ 9.9179e-01,  9.9144e-01,  9.9109e-01,  ...,  9.6300e-01,
#              9.6293e-01,  9.6290e-01]],
#
#           [[ 1.3205e-04,  2.4474e-04,  3.5811e-04,  ...,  2.5514e-03,
#              2.6010e-03,  2.6462e-03],
#            [ 5.2030e-03,  5.3398e-03,  5.4769e-03,  ...,  8.4559e-03,
#              8.5175e-03,  8.5526e-03],
#            [ 1.0270e-02,  1.0431e-02,  1.0592e-02,  ...,  1.4361e-02,
#              1.4435e-02,  1.4459e-02],
#            ...,
#            [ 9.8058e-01,  9.8024e-01,  9.7990e-01,  ...,  9.5238e-01,
#              9.5238e-01,  9.5239e-01],
#            [ 9.8591e-01,  9.8556e-01,  9.8521e-01,  ...,  9.5747e-01,
#              9.5742e-01,  9.5744e-01],
#            [ 9.9111e-01,  9.9077e-01,  9.9043e-01,  ...,  9.6245e-01,
#              9.6238e-01,  9.6237e-01]],
#
#           [[ 3.2853e-05,  1.0576e-04,  1.7821e-04,  ...,  1.8895e-03,
#              1.8899e-03,  2.0348e-03],
#            [ 5.1222e-03,  5.2417e-03,  5.3607e-03,  ...,  7.8727e-03,
#              7.8853e-03,  7.9967e-03],
#            [ 1.0207e-02,  1.0373e-02,  1.0537e-02,  ...,  1.3856e-02,
#              1.3882e-02,  1.3959e-02],
#            ...,
#            [ 9.7995e-01,  9.7962e-01,  9.7928e-01,  ...,  9.5181e-01,
#              9.5183e-01,  9.5189e-01],
#            [ 9.8522e-01,  9.8488e-01,  9.8455e-01,  ...,  9.5687e-01,
#              9.5686e-01,  9.5692e-01],
#            [ 9.9043e-01,  9.9010e-01,  9.8978e-01,  ...,  9.6189e-01,
#              9.6184e-01,  9.6184e-01]],
#
#           ...,
#
#           [[ 1.4284e-03,  1.7674e-03,  2.1100e-03,  ..., -6.2881e-04,
#             -6.1263e-04, -6.4056e-04],
#            [ 7.6131e-03,  8.1327e-03,  8.6584e-03,  ...,  5.2105e-03,
#              5.1794e-03,  5.1538e-03],
#            [ 1.3805e-02,  1.4506e-02,  1.5216e-02,  ...,  1.1047e-02,
#              1.0974e-02,  1.0950e-02],
#            ...,
#            [ 9.6280e-01,  9.6092e-01,  9.5903e-01,  ...,  9.5960e-01,
#              9.5974e-01,  9.5967e-01],
#            [ 9.6805e-01,  9.6623e-01,  9.6438e-01,  ...,  9.6494e-01,
#              9.6509e-01,  9.6499e-01],
#            [ 9.7334e-01,  9.7148e-01,  9.6962e-01,  ...,  9.7020e-01,
#              9.7028e-01,  9.7017e-01]],
#
#           [[ 1.4554e-03,  1.8170e-03,  2.1833e-03,  ..., -7.6768e-04,
#             -7.6322e-04, -7.6640e-04],
#            [ 7.6559e-03,  8.2164e-03,  8.7844e-03,  ...,  5.1028e-03,
#              5.0580e-03,  5.0508e-03],
#            [ 1.3865e-02,  1.4625e-02,  1.5395e-02,  ...,  1.0971e-02,
#              1.0882e-02,  1.0870e-02],
#            ...,
#            [ 9.6262e-01,  9.6069e-01,  9.5875e-01,  ...,  9.5944e-01,
#              9.5960e-01,  9.5957e-01],
#            [ 9.6784e-01,  9.6597e-01,  9.6408e-01,  ...,  9.6482e-01,
#              9.6499e-01,  9.6494e-01],
#            [ 9.7316e-01,  9.7124e-01,  9.6933e-01,  ...,  9.7016e-01,
#              9.7025e-01,  9.7017e-01]],
#
#           [[ 1.4808e-03,  1.8757e-03,  2.2755e-03,  ..., -7.4738e-04,
#             -7.1739e-04, -7.4833e-04],
#            [ 7.7219e-03,  8.3078e-03,  8.9014e-03,  ...,  5.1043e-03,
#              5.0849e-03,  5.0426e-03],
#            [ 1.3971e-02,  1.4749e-02,  1.5537e-02,  ...,  1.0954e-02,
#              1.0889e-02,  1.0835e-02],
#            ...,
#            [ 9.6270e-01,  9.6070e-01,  9.5870e-01,  ...,  9.5934e-01,
#              9.5942e-01,  9.5936e-01],
#            [ 9.6793e-01,  9.6597e-01,  9.6400e-01,  ...,  9.6477e-01,
#              9.6486e-01,  9.6476e-01],
#            [ 9.7323e-01,  9.7124e-01,  9.6926e-01,  ...,  9.7007e-01,
#              9.7009e-01,  9.6998e-01]]],
#
#
#          [[[ 5.3176e-03,  1.1285e-02,  1.7256e-02,  ...,  9.9688e-01,
#              1.0019e+00,  1.0072e+00],
#            [ 5.0326e-03,  1.1078e-02,  1.7126e-02,  ...,  9.9711e-01,
#              1.0021e+00,  1.0074e+00],
#            [ 4.7390e-03,  1.0861e-02,  1.6985e-02,  ...,  9.9734e-01,
#              1.0024e+00,  1.0076e+00],
#            ...,
#            [ 6.1820e-04,  6.2291e-03,  1.1842e-02,  ...,  1.0228e+00,
#              1.0279e+00,  1.0327e+00],
#            [ 5.4852e-04,  6.1649e-03,  1.1783e-02,  ...,  1.0227e+00,
#              1.0276e+00,  1.0325e+00],
#            [ 5.3166e-04,  6.1542e-03,  1.1775e-02,  ...,  1.0226e+00,
#              1.0276e+00,  1.0324e+00]],
#
#           [[ 5.0983e-03,  1.1161e-02,  1.7224e-02,  ...,  9.9718e-01,
#              1.0022e+00,  1.0075e+00],
#            [ 4.7953e-03,  1.0907e-02,  1.7018e-02,  ...,  9.9733e-01,
#              1.0024e+00,  1.0076e+00],
#            [ 4.4853e-03,  1.0644e-02,  1.6803e-02,  ...,  9.9748e-01,
#              1.0026e+00,  1.0078e+00],
#            ...,
#            [ 7.5844e-04,  6.3823e-03,  1.2007e-02,  ...,  1.0217e+00,
#              1.0268e+00,  1.0317e+00],
#            [ 7.2927e-04,  6.3475e-03,  1.1967e-02,  ...,  1.0215e+00,
#              1.0266e+00,  1.0315e+00],
#            [ 6.8243e-04,  6.3187e-03,  1.1954e-02,  ...,  1.0215e+00,
#              1.0265e+00,  1.0314e+00]],
#
#           [[ 4.8806e-03,  1.1040e-02,  1.7198e-02,  ...,  9.9749e-01,
#              1.0026e+00,  1.0078e+00],
#            [ 4.5588e-03,  1.0737e-02,  1.6915e-02,  ...,  9.9757e-01,
#              1.0027e+00,  1.0078e+00],
#            [ 4.2316e-03,  1.0429e-02,  1.6626e-02,  ...,  9.9764e-01,
#              1.0028e+00,  1.0079e+00],
#            ...,
#            [ 8.9652e-04,  6.5324e-03,  1.2169e-02,  ...,  1.0206e+00,
#              1.0258e+00,  1.0307e+00],
#            [ 9.0677e-04,  6.5257e-03,  1.2145e-02,  ...,  1.0204e+00,
#              1.0256e+00,  1.0305e+00],
#            [ 8.3402e-04,  6.4824e-03,  1.2131e-02,  ...,  1.0203e+00,
#              1.0255e+00,  1.0304e+00]],
#
#           ...,
#
#           [[ 1.8519e-02,  2.6642e-02,  3.4775e-02,  ...,  1.0015e+00,
#              1.0066e+00,  1.0117e+00],
#            [ 1.9565e-02,  2.7965e-02,  3.6383e-02,  ...,  1.0015e+00,
#              1.0067e+00,  1.0118e+00],
#            [ 2.0631e-02,  2.9310e-02,  3.8014e-02,  ...,  1.0016e+00,
#              1.0068e+00,  1.0119e+00],
#            ...,
#            [ 2.0125e-02,  3.3435e-02,  4.6752e-02,  ...,  9.9466e-01,
#              1.0002e+00,  1.0059e+00],
#            [ 1.9950e-02,  3.3211e-02,  4.6477e-02,  ...,  9.9420e-01,
#              9.9979e-01,  1.0056e+00],
#            [ 1.9609e-02,  3.2793e-02,  4.5988e-02,  ...,  9.9378e-01,
#              9.9933e-01,  1.0051e+00]],
#
#           [[ 1.8711e-02,  2.6814e-02,  3.4928e-02,  ...,  1.0021e+00,
#              1.0072e+00,  1.0123e+00],
#            [ 1.9887e-02,  2.8237e-02,  3.6607e-02,  ...,  1.0022e+00,
#              1.0074e+00,  1.0124e+00],
#            [ 2.1084e-02,  2.9683e-02,  3.8310e-02,  ...,  1.0023e+00,
#              1.0075e+00,  1.0126e+00],
#            ...,
#            [ 2.1700e-02,  3.4994e-02,  4.8304e-02,  ...,  9.9446e-01,
#              1.0002e+00,  1.0059e+00],
#            [ 2.1523e-02,  3.4750e-02,  4.7995e-02,  ...,  9.9392e-01,
#              9.9962e-01,  1.0055e+00],
#            [ 2.1167e-02,  3.4351e-02,  4.7543e-02,  ...,  9.9350e-01,
#              9.9914e-01,  1.0050e+00]],
#
#           [[ 1.8801e-02,  2.6860e-02,  3.4933e-02,  ...,  1.0026e+00,
#              1.0077e+00,  1.0128e+00],
#            [ 1.9897e-02,  2.8234e-02,  3.6593e-02,  ...,  1.0028e+00,
#              1.0080e+00,  1.0130e+00],
#            [ 2.1016e-02,  2.9632e-02,  3.8279e-02,  ...,  1.0030e+00,
#              1.0082e+00,  1.0132e+00],
#            ...,
#            [ 2.1774e-02,  3.5163e-02,  4.8561e-02,  ...,  9.9436e-01,
#              1.0000e+00,  1.0057e+00],
#            [ 2.1600e-02,  3.4946e-02,  4.8302e-02,  ...,  9.9383e-01,
#              9.9951e-01,  1.0053e+00],
#            [ 2.1208e-02,  3.4496e-02,  4.7799e-02,  ...,  9.9337e-01,
#              9.9898e-01,  1.0048e+00]]]]], device='cuda:0',
#        grad_fn=<AddBackward0>)

# %%
plt.imshow(hires_Net.identityMap[0, 2, :, 0].cpu().numpy())
plt.colorbar()

# %%
plt.imshow(net.identityMap[0, 2, :, 0].cpu().numpy())
plt.colorbar()

# %%
import importlib
import mermaidlite
importlib.reload(mermaidlite)
# Out:
# <module 'mermaidlite' from '/playpen-raid1/tgreer/InverseConsistency/mermaidlite.py'>

# %%
dir(net)
# Out:
# ['T_destination',
#  '__annotations__',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_apply',
#  '_backward_hooks',
#  '_buffers',
#  '_call_impl',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_get_name',
#  '_load_from_state_dict',
#  '_load_state_dict_pre_hooks',
#  '_modules',
#  '_named_members',
#  '_non_persistent_buffers_set',
#  '_parameters',
#  '_register_load_state_dict_pre_hook',
#  '_register_state_dict_hook',
#  '_replicate_for_data_parallel',
#  '_save_to_state_dict',
#  '_slow_forward',
#  '_state_dict_hooks',
#  '_version',
#  'add_module',
#  'apply',
#  'bfloat16',
#  'buffers',
#  'children',
#  'cpu',
#  'cuda',
#  'double',
#  'dump_patches',
#  'eval',
#  'extra_repr',
#  'float',
#  'forward',
#  'half',
#  'identityMap',
#  'input_shape',
#  'lmbda',
#  'load_state_dict',
#  'modules',
#  'named_buffers',
#  'named_children',
#  'named_modules',
#  'named_parameters',
#  'parameters',
#  'regis_net',
#  'register_backward_hook',
#  'register_buffer',
#  'register_forward_hook',
#  'register_forward_pre_hook',
#  'register_parameter',
#  'requires_grad_',
#  'share_memory',
#  'similarity',
#  'spacing',
#  'state_dict',
#  'to',
#  'train',
#  'training',
#  'type',
#  'zero_grad']

# %%
net(fixed_image, moving_image)
# Out:
# (tensor(0.0225, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(2.4185e-05, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(0.0201, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(0.0022, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
weights_a = torch.load("../results/hires_continue_ramp_lambda3/knee_aligner_resi_net1200")
weights_b = torch.load("../results/hires_continue_ramp_lambda3/knee_aligner_resi_net9900")

# %%
weights_a["regis_net.netPsi.net.upConvs.2.weight"].shape
# Out:
# torch.Size([192, 64, 4, 4, 4])

# %%
# Out:
# tensor([-0.0072, -0.0064, -0.0167, -0.0075, -0.0135, -0.0068, -0.0109, -0.0210,
#         -0.0091,  0.0195, -0.0205, -0.0089,  0.0141,  0.0079, -0.0024, -0.0181,
#         -0.0125,  0.0085,  0.0196,  0.0138,  0.0020, -0.0112,  0.0030, -0.0125,
#          0.0145,  0.0118,  0.0001, -0.0132, -0.0191, -0.0011, -0.0219,  0.0162],
#        device='cuda:0')

# %%
weights_a.keys()
# Out:
# odict_keys(['identityMap', 'regis_net.identityMap', 'regis_net.netPsi.identityMap', 'regis_net.netPsi.net.identityMap', 'regis_net.netPsi.net.downConvs.0.weight', 'regis_net.netPsi.net.downConvs.0.bias', 'regis_net.netPsi.net.downConvs.1.weight', 'regis_net.netPsi.net.downConvs.1.bias', 'regis_net.netPsi.net.downConvs.2.weight', 'regis_net.netPsi.net.downConvs.2.bias', 'regis_net.netPsi.net.downConvs.3.weight', 'regis_net.netPsi.net.downConvs.3.bias', 'regis_net.netPsi.net.downConvs.4.weight', 'regis_net.netPsi.net.downConvs.4.bias', 'regis_net.netPsi.net.upConvs.0.weight', 'regis_net.netPsi.net.upConvs.0.bias', 'regis_net.netPsi.net.upConvs.1.weight', 'regis_net.netPsi.net.upConvs.1.bias', 'regis_net.netPsi.net.upConvs.2.weight', 'regis_net.netPsi.net.upConvs.2.bias', 'regis_net.netPsi.net.upConvs.3.weight', 'regis_net.netPsi.net.upConvs.3.bias', 'regis_net.netPsi.net.upConvs.4.weight', 'regis_net.netPsi.net.upConvs.4.bias', 'regis_net.netPsi.net.batchNorms.0.weight', 'regis_net.netPsi.net.batchNorms.0.bias', 'regis_net.netPsi.net.batchNorms.0.running_mean', 'regis_net.netPsi.net.batchNorms.0.running_var', 'regis_net.netPsi.net.batchNorms.0.num_batches_tracked', 'regis_net.netPsi.net.batchNorms.1.weight', 'regis_net.netPsi.net.batchNorms.1.bias', 'regis_net.netPsi.net.batchNorms.1.running_mean', 'regis_net.netPsi.net.batchNorms.1.running_var', 'regis_net.netPsi.net.batchNorms.1.num_batches_tracked', 'regis_net.netPsi.net.batchNorms.2.weight', 'regis_net.netPsi.net.batchNorms.2.bias', 'regis_net.netPsi.net.batchNorms.2.running_mean', 'regis_net.netPsi.net.batchNorms.2.running_var', 'regis_net.netPsi.net.batchNorms.2.num_batches_tracked', 'regis_net.netPsi.net.batchNorms.3.weight', 'regis_net.netPsi.net.batchNorms.3.bias', 'regis_net.netPsi.net.batchNorms.3.running_mean', 'regis_net.netPsi.net.batchNorms.3.running_var', 'regis_net.netPsi.net.batchNorms.3.num_batches_tracked', 'regis_net.netPsi.net.batchNorms.4.weight', 'regis_net.netPsi.net.batchNorms.4.bias', 'regis_net.netPsi.net.batchNorms.4.running_mean', 'regis_net.netPsi.net.batchNorms.4.running_var', 'regis_net.netPsi.net.batchNorms.4.num_batches_tracked', 'regis_net.netPsi.net.lastConv.weight', 'regis_net.netPsi.net.lastConv.bias', 'regis_net.netPhi.identityMap', 'regis_net.netPhi.net.identityMap', 'regis_net.netPhi.net.netPsi.identityMap', 'regis_net.netPhi.net.netPsi.net.identityMap', 'regis_net.netPhi.net.netPsi.net.downConvs.0.weight', 'regis_net.netPhi.net.netPsi.net.downConvs.0.bias', 'regis_net.netPhi.net.netPsi.net.downConvs.1.weight', 'regis_net.netPhi.net.netPsi.net.downConvs.1.bias', 'regis_net.netPhi.net.netPsi.net.downConvs.2.weight', 'regis_net.netPhi.net.netPsi.net.downConvs.2.bias', 'regis_net.netPhi.net.netPsi.net.downConvs.3.weight', 'regis_net.netPhi.net.netPsi.net.downConvs.3.bias', 'regis_net.netPhi.net.netPsi.net.downConvs.4.weight', 'regis_net.netPhi.net.netPsi.net.downConvs.4.bias', 'regis_net.netPhi.net.netPsi.net.upConvs.0.weight', 'regis_net.netPhi.net.netPsi.net.upConvs.0.bias', 'regis_net.netPhi.net.netPsi.net.upConvs.1.weight', 'regis_net.netPhi.net.netPsi.net.upConvs.1.bias', 'regis_net.netPhi.net.netPsi.net.upConvs.2.weight', 'regis_net.netPhi.net.netPsi.net.upConvs.2.bias', 'regis_net.netPhi.net.netPsi.net.upConvs.3.weight', 'regis_net.netPhi.net.netPsi.net.upConvs.3.bias', 'regis_net.netPhi.net.netPsi.net.upConvs.4.weight', 'regis_net.netPhi.net.netPsi.net.upConvs.4.bias', 'regis_net.netPhi.net.netPsi.net.batchNorms.0.weight', 'regis_net.netPhi.net.netPsi.net.batchNorms.0.bias', 'regis_net.netPhi.net.netPsi.net.batchNorms.0.running_mean', 'regis_net.netPhi.net.netPsi.net.batchNorms.0.running_var', 'regis_net.netPhi.net.netPsi.net.batchNorms.0.num_batches_tracked', 'regis_net.netPhi.net.netPsi.net.batchNorms.1.weight', 'regis_net.netPhi.net.netPsi.net.batchNorms.1.bias', 'regis_net.netPhi.net.netPsi.net.batchNorms.1.running_mean', 'regis_net.netPhi.net.netPsi.net.batchNorms.1.running_var', 'regis_net.netPhi.net.netPsi.net.batchNorms.1.nu ...

# %%
mkdir Roland_result

# %%
import importlib
importlib.reload(visualize)
for N in range(2):

    plt.rcParams["figure.figsize"] = (5, 5)
    def imshow(x):
        plt.xticks([])
        plt.yticks([])
        plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
    offset = 2
    slice_ = 20
    imshow(moving_image[N, 0, slice_].cpu().detach())
    plt.savefig(f"Roland_result/Pair{N + offset}ImageA.png")
    plt.clf()
    imshow(fixed_image[N, 0, slice_])
    plt.savefig(f"Roland_result/Pair{N + offset}ImageB.png")
    plt.clf()
    imshow(net.warped_image_A[N, 0, slice_])
    plt.savefig(f"Roland_result/Pair{N + offset}WarpedImageA.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach())
    plt.savefig(f"Roland_result/Pair{N + offset}WarpedImageB.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
    plt.savefig(f"Roland_result/Pair{N + offset}WarpedImageBGrid.png")
    plt.clf()
    imshow(net.warped_image_A[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 20])
    plt.savefig(f"Roland_result/Pair{N + offset}WarpedImageAGrid.png")
    plt.clf()

    
    plt.show()

# %%
import importlib
importlib.reload(visualize)
# Out:
# <module 'visualize' from '/playpen-raid1/tgreer/InverseConsistency/visualize.py'>

# %%
def flips2(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True) / np.product(net.spacing)
    return dV.detach().cpu()

dV = flips2(net.phi_AB_vectorfield)

# %%
plt.imshow(torch.min(dV[1, 0], axis=0).values)
plt.colorbar()

# %%
torch.sum(dV[1] < 0)
# Out:
# tensor(13)

# %%
dV.shape
# Out:
# torch.Size([2, 1, 79, 191, 191])

# %%
116 / (80 * 192 * 192), 1 / 25000
# Out:
# (3.9333767361111114e-05, 4e-05)

# %%
import matplotlib.colors as colors

plt.xticks([])
plt.yticks([])
query = dV[0, 0, 43]
plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice", 
         fontdict={'fontsize':13})
plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
#lt.show()
#plt.imshow(dV[1, 0, 40] < 0)


plt.savefig("dVslice0.pdf", bbox_inches="tight")

# %%
2 * np.sum(folds_list) / (np.product(list(dV.shape)) * len(r_ds))
# Out:
# 2.046440866760003e-05

# %%
print("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice")
from matplotlib import rc
rc('text', usetex=False)
np.min(query.numpy())
# Out:
# dV attains a minimum of $\bf{0.0613}$ in this slice
# 0.061257

# %%
adv = np.array(dV)
filteredDV = adv[adv < 0.05]
plt.hist(filteredDV, bins=100)
plt.show()

# %%
plt.hist(np.concatenate(filteredDV_list), bins=100)
plt.title("Distribution of negative dV voxels in test set")
plt.xlabel("dV (in voxels³)")
plt.ylabel("Count")
plt.savefig("DistributionNegativeJacobian.pdf")

# %%
np.mean(np.concatenate(filteredDV_list))
# Out:
# -0.09664285

# %%
np.median(np.concatenate(filteredDV_list))
# Out:
# -0.054298144

# %%
np.percentile(np.concatenate(filteredDV_list), 1)
# Out:
# -0.6120650005340577

# %%
# %time net.regis_net(moving_image, fixed_image)
# Out:
# CPU times: user 18.3 ms, sys: 66.2 ms, total: 84.5 ms
# Wall time: 58.8 ms
# <function network_wrappers.DoubleNet.forward.<locals>.<lambda>(input_)>

# %%
with torch.no_grad():
    x = batched_ds[0]
    x = list(zip(*x))
    x = [torch.cat(r, 0).cuda().float() for r in x]
    fixed_image, fixed_cartilage = x[0], x[2]
    moving_image, moving_cartilage = x[1], x[3]

# %%
# %%time
with torch.no_grad():
    phi = net.regis_net(moving_image, fixed_image)
    phi_AB_vectorfield = phi(net.identityMap).cpu()
# Out:
# CPU times: user 1.45 s, sys: 61 ms, total: 1.51 s
# Wall time: 1.48 s

# %%
# %%time 
net(moving_image, fixed_image)
# Out:
# CPU times: user 2.78 s, sys: 1.12 s, total: 3.9 s
# Wall time: 3.83 s
# (tensor(0.0624, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(5.5865e-05, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(6.9831e-06, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
dV.shape
# Out:
# torch.Size([2, 1, 79, 191, 191])

# %%
net.input_shape
# Out:
# array([  4,   1,  80, 192, 192])

# %%
torch.onnx.export(net.regis_net.,               # model being run
                  (moving_image, fixed_image),                         # model input (or a tuple for multiple inputs)
                  "hires_network.onnx",   # where to save the model (can be a file or file-like object)
                  export_params=True,        # store the trained parameter weights inside the model file
                  opset_version=12,          # the ONNX version to export the model to
                  do_constant_folding=True,  # whether to execute constant folding for optimization
                  input_names = ['image_a', 'image_b'],   # the model's input names
                  output_names = ['a', 'b', 'c', 'd'], # the model's output names
                  dynamic_axes={})
# Out:
# ---------------------------------------------------------------------------
# ModuleAttributeError                      Traceback (most recent call last)
# <ipython-input-13-c50255b64d86> in <module>
# ----> 1 torch.onnx.export(net.regis_net.psi,               # model being run
#       2                   (moving_image, fixed_image),                         # model input (or a tuple for multiple inputs)
#       3                   "hires_network.onnx",   # where to save the model (can be a file or file-like object)
#       4                   export_params=True,        # store the trained parameter weights inside the model file
#       5                   opset_version=12,          # the ONNX version to export the model to
#
# /playpen-raid1/tgreer/anaconda3/envs/mermaid5/lib/python3.7/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#     777                 return modules[name]
#     778         raise ModuleAttributeError("'{}' object has no attribute '{}'".format(
# --> 779             type(self).__name__, name))
#     780
#     781     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# ModuleAttributeError: 'DoubleNet' object has no attribute 'psi'

# %%
plt.hist(torch.cat(dices).cpu().detach().numpy(), bins=30)
# Out:
# (array([ 3.,  1.,  1.,  2.,  5.,  6.,  7., 10., 17., 22., 21., 26., 30.,
#         40., 41., 29., 20.,  8.,  4.,  4.,  0.,  0.,  1.,  1.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([0.45836532, 0.47490254, 0.4914398 , 0.507977  , 0.52451426,
#         0.54105145, 0.5575887 , 0.5741259 , 0.59066314, 0.6072004 ,
#         0.6237376 , 0.6402748 , 0.6568121 , 0.67334926, 0.6898865 ,
#         0.70642376, 0.72296095, 0.7394982 , 0.7560354 , 0.77257264,
#         0.7891099 , 0.8056471 , 0.8221843 , 0.8387216 , 0.85525876,
#         0.871796  , 0.8883332 , 0.90487045, 0.9214077 , 0.9379449 ,
#         0.95448214], dtype=float32),
#  <BarContainer object of 30 artists>)

# %%
torch.cat(dices).cpu().shape
# Out:
# torch.Size([300])

# %%
# %%sh
# scp biag-gpu0:/playpen/tgreer/knees_test_set_hires /playpen/tgreer/knees_test_set_hires
# Out:
# The Department of Computer Science at UNC Chapel Hill.
# This system is intended for use by department affiliates only.
# Unauthorized access to this system is prohibited.
#
# Permission denied, please try again.
# Permission denied, please try again.
# tgreer@biag-gpu0: Permission denied (publickey,gssapi-keyex,gssapi-with-mic,password).
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-10-8b0c243fa643> in <module>
# ----> 1 get_ipython().run_cell_magic('sh', '', 'scp biag-gpu0:/playpen/tgreer/knees_test_set_hires /playpen/tgreer/knees_test_set_hires \n')
#
# /playpen-raid1/tgreer/anaconda3/envs/mermaid5/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2380             with self.builtin_trap:
#    2381                 args = (magic_arg_s, cell)
# -> 2382                 result = fn(*args, **kwargs)
#    2383             return result
#    2384
#
# /playpen-raid1/tgreer/anaconda3/envs/mermaid5/lib/python3.7/site-packages/IPython/core/magics/script.py in named_script_magic(line, cell)
#     140             else:
#     141                 line = script
# --> 142             return self.shebang(line, cell)
#     143
#     144         # write a basic docstring:
#
# <decorator-gen-103> in shebang(self, line, cell)
#
# /playpen-raid1/tgreer/anaconda3/envs/mermaid5/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /playpen-raid1/tgreer/anaconda3/envs/mermaid5/lib/python3.7/site-packages/IPython/core/magics/script.py in shebang(self, line, cell)
#     243             sys.stderr.flush()
#     244         if args.raise_error and p.returncode!=0:
# --> 245             raise CalledProcessError(p.returncode, cell, output=out, stderr=err)
#     246
#     247     def _run_script(self, p, cell, to_close):
#
# CalledProcessError: Command 'b'scp biag-gpu0:/playpen/tgreer/knees_test_set_hires /playpen/tgreer/knees_test_set_hires \n'' returned non-zero exit status 1.

# %%
pixel_displacement = ((net.phi_AB_vectorfield.cpu() - net.identityMap.cpu()) 
    * torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None])
plt.imshow(pixel_displacement[0, 2, 40], cmap="rainbow")
plt.colorbar()

# %%
torch.max(torch.abs(pixel_displacement))
# Out:
# tensor(30.6417)

# %%
error = (net.phi_AB(net.phi_BA_vectorfield) - net.identityMap).cpu()* torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None]

# %%
plt.imshow((error)[0, 0, 40])
plt.colorbar()

# %%
torch.sqrt(torch.mean(error**2))
# Out:
# tensor(0.3200)

# %%
plt.rcParams["figure.figsize"]
# Out:
# [6.4, 4.8]

# %%
plt.hist(folds_list, bins=40)
plt.xlabel("number of folded pixels")
plt.ylabel("number of image pairs")
# Out:
# Text(0, 0.5, 'number of image pairs')
