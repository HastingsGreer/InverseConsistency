# %%
# !ntop
# Out:
# Tue Oct  4 03:48:20 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:3B:00.0 Off |                  N/A |
# | 30%   27C    P8     1W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:5E:00.0 Off |                  N/A |
# | 31%   27C    P8    19W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:B1:00.0 Off |                  N/A |
# | 32%   28C    P8    21W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  On   | 00000000:D9:00.0 Off |                  N/A |
# | 30%   27C    P8     3W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | No running processes found                                                  |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from collections import OrderedDict
import torch.nn.functional as F
from icon_registration.mermaidlite import compute_warped_image_multiNC, identity_map_multiN
import torch
import random
import icon_registration.inverseConsistentNet as inverseConsistentNet
import icon_registration.network_wrappers as network_wrappers
import icon_registration.data as data
import numpy as np
import matplotlib.pyplot as plt
import icon_registration.networks as networks


import itk
# Out:
# /playpen-raid1/tgreer/ICON/src/icon_registration/inverseConsistentNet.py:3: UserWarning: inverseConsistentNet.py is deprecated, its code has been moved to losses.py
#         In a future release this file may be deleted.
#   warnings.warn(

# %%
r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#batched_ds = list(zip(*[r_ds[i::4] for i in range(2)]))

# %%
batched_ds = list(zip(*[r_ds[i::2] for i in range(2)]))

# %%
import random
import torch

import footsteps

import icon_registration as icon
import icon_registration.networks as networks


SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [1, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

def make_network():
    inner_net = icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))

    for _ in range(2):
         inner_net = icon.TwoStepRegistration(
             icon.DownsampleRegistration(inner_net, dimension=3),
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )

    net = icon.GradientICON(inner_net, icon.ssd_only_interpolated, lmbda=.5)
    net.assign_identity_map(input_shape)
    return net

net = make_network()

trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/end2endlmbda.2/network_weights_68400")
#trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/q-9/network_weights_17700")


net.regis_net.load_state_dict(trained_weights)


0
# Out:
# 0

# %%
import random
import torch

import footsteps

import icon_registration as icon
import icon_registration.networks as networks


SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [1, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

def make_network():
    inner_net = icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))

    for _ in range(2):
         inner_net = icon.TwoStepRegistration(
             icon.DownsampleRegistration(inner_net, dimension=3),
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )
    inner_net = icon.TwoStepRegistration(
             inner_net,
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )

    net = icon.GradientICON(inner_net, icon.ssd_only_interpolated, lmbda=.2)
    net.assign_identity_map(input_shape)
    return net

net = make_network()

trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/ent2end_thenonemore-7/network_weights_14100")
#trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/q-9/network_weights_17700")


net.regis_net.load_state_dict(trained_weights)
# Out:
# <All keys matched successfully>

# %%
# !ntop
# Out:
# Tue Oct  4 08:08:28 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:3B:00.0 Off |                  N/A |
# | 30%   27C    P8     1W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:5E:00.0 Off |                  N/A |
# | 32%   32C    P2    63W / 250W |   9068MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:B1:00.0 Off |                  N/A |
# | 31%   28C    P8    21W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  On   | 00000000:D9:00.0 Off |                  N/A |
# | 30%   27C    P8     4W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# |  GPU   PID     USER    GPU MEM  %CPU  %MEM      TIME  COMMAND               |
# |    1 19808   tgreer    9065MiB   4.2  19.1  08:29:26  /playpen-raid1/tgree  |
# +-----------------------------------------------------------------------------+

# %%
BATCH_SIZE = 2
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [BATCH_SIZE, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

net.assign_identity_map(input_shape)

# %%
net.cuda()
net.eval()
# Out:
# GradientICON(
#   (regis_net): TwoStepRegistration(
#     (netPhi): TwoStepRegistration(
#       (netPhi): DownsampleRegistration(
#         (net): TwoStepRegistration(
#           (netPhi): DownsampleRegistration(
#             (net): FunctionFromVectorField(
#               (net): UNet2(
#                 (downConvs): ModuleList(
#                   (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 )
#                 (upConvs): ModuleList(
#                   (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 )
#                 (batchNorms): ModuleList(
#                   (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               )
#             )
#           )
#           (netPsi): FunctionFromVectorField(
#             (net): UNet2(
#               (downConvs): ModuleList(
#                 (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               )
#               (upConvs): ModuleList(
#                 (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#               )
#               (batchNorms): ModuleList(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             )
#           )
#         )
#       )
#       (netPsi): FunctionFromVectorField(
#         (net): UNet2(
#           (downConvs): ModuleList(
#             (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           )
#           (upConvs): ModuleList(
#             (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           )
#           (batchNorms): ModuleList(
#             (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         )
#       )
#     )
#     (netPsi): FunctionFromVectorField(
#       (net): UNet2(
#         (downConvs): ModuleList(
#           (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#         )
#         (upConvs): ModuleList(
#           (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#         )
#         (batchNorms): ModuleList(
#           (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       )
#     )
#   )
# )

# %%
import icon_registration

# %%
0
# Out:
# 0

# %%
def flips(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True)
    return torch.sum(dV < 0)# / BATCH_SIZE
def flips2(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True) / np.product(net.spacing)
    return dV.detach().cpu()
with torch.no_grad():
    dices = ([], [])
    folds_list = []
    
    filteredDV_list = []
    
    mag = []
    
    
    for x in batched_ds[:]:
        x = list(zip(*x))
        x = [torch.cat(r, 0).cuda().float() for r in x]
        fixed_image, fixed_cartilage = x[1], x[3]
        moving_image, moving_cartilage = x[0], x[2]

        l = icon_registration.losses.to_floats(net(moving_image, fixed_image))
        mag.append(l.transform_magnitude)
        phi_AB_vectorfield = net.phi_AB(net.identity_map)
        fat_phi = torch.nn.Upsample(size=moving_cartilage.size()[2:], mode="trilinear")(phi_AB_vectorfield[:, :3])
        sz = np.array(fat_phi.size())
        spacing = 1./(sz[2::]-1) 
        warped_moving_cartilage = compute_warped_image_multiNC(moving_cartilage.float(), fat_phi, spacing, 0)
        
        #fixed_cartilage = torch.nn.
        for label in range(2):
            wmb = torch.round(warped_moving_cartilage) == label + 1
            fb = torch.round(fixed_cartilage) == label + 1
            intersection = wmb * fb
            d = 2 * torch.sum(intersection, [1,2,3,4]).float() / (torch.sum(wmb, [1,2,3,4]) + torch.sum(fb, [1,2,3,4]))
            print(d)
            dices[label].append(d)
        f = flips(phi_AB_vectorfield[:1])
        print(f)
        folds_list.append(f.item())
        f = flips(phi_AB_vectorfield[1:])
        print(f)
        folds_list.append(f.item())
        
        dV = flips2(phi_AB_vectorfield)
        
        dV = np.array(dV).flatten()
        dV = dV[dV < 0]
        filteredDV_list.append(dV)
        
    dd = torch.mean(torch.cat(dices[0] + dices[1]).cpu())
    print(dd)
    ff = np.mean(folds_list)
    print(ff)
    
    print("mag", sum(mag) / len(mag))
# Out:
# tensor([0.6760, 0.7527], device='cuda:0')
# tensor([0.7386, 0.7546], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.7494, 0.6668], device='cuda:0')
# tensor([0.7207, 0.6535], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6704, 0.6776], device='cuda:0')
# tensor([0.6837, 0.5857], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.7488, 0.6877], device='cuda:0')
# tensor([0.8044, 0.7066], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6963, 0.7661], device='cuda:0')
# tensor([0.7112, 0.7182], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7359, 0.7779], device='cuda:0')
# tensor([0.6314, 0.7456], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7529, 0.5873], device='cuda:0')
# tensor([0.7194, 0.6673], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6478, 0.7657], device='cuda:0')
# tensor([0.7263, 0.7676], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7106, 0.7348], device='cuda:0')
# tensor([0.6681, 0.7098], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6732, 0.7261], device='cuda:0')
# tensor([0.7685, 0.7200], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6938, 0.7210], device='cuda:0')
# tensor([0.6252, 0.7578], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6807, 0.6346], device='cuda:0')
# tensor([0.7252, 0.6667], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7083, 0.6894], device='cuda:0')
# tensor([0.7158, 0.7571], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6690, 0.7028], device='cuda:0')
# tensor([0.7326, 0.7250], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7012, 0.7247], device='cuda:0')
# tensor([0.6813, 0.7438], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6791, 0.7865], device='cuda:0')
# tensor([0.6804, 0.7785], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7671, 0.7370], device='cuda:0')
# tensor([0.7372, 0.6573], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5661, 0.6876], device='cuda:0')
# tensor([0.6377, 0.6927], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7545, 0.6661], device='cuda:0')
# tensor([0.7466, 0.6039], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7827, 0.7843], device='cuda:0')
# tensor([0.7691, 0.7660], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7114, 0.7626], device='cuda:0')
# tensor([0.7760, 0.7236], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6181, 0.6638], device='cuda:0')
# tensor([0.6071, 0.7674], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6853, 0.6765], device='cuda:0')
# tensor([0.6958, 0.6674], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7411, 0.7491], device='cuda:0')
# tensor([0.6793, 0.7075], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7054, 0.6368], device='cuda:0')
# tensor([0.7103, 0.6880], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6216, 0.7957], device='cuda:0')
# tensor([0.5175, 0.7814], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7018, 0.6344], device='cuda:0')
# tensor([0.6514, 0.6604], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7287, 0.7063], device='cuda:0')
# tensor([0.7481, 0.6617], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6757, 0.7175], device='cuda:0')
# tensor([0.6732, 0.6835], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6655, 0.6792], device='cuda:0')
# tensor([0.6876, 0.6924], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7595, 0.7548], device='cuda:0')
# tensor([0.7856, 0.7596], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7368, 0.6181], device='cuda:0')
# tensor([0.6605, 0.7043], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7783, 0.7461], device='cuda:0')
# tensor([0.8129, 0.7535], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7011, 0.7391], device='cuda:0')
# tensor([0.7933, 0.7118], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6768, 0.7149], device='cuda:0')
# tensor([0.6645, 0.7036], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7136, 0.7444], device='cuda:0')
# tensor([0.7159, 0.6932], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7711, 0.7132], device='cuda:0')
# tensor([0.6984, 0.7135], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7112, 0.7059], device='cuda:0')
# tensor([0.7207, 0.7290], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7594, 0.7038], device='cuda:0')
# tensor([0.7424, 0.7252], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7818, 0.7068], device='cuda:0')
# tensor([0.7830, 0.7160], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7347, 0.7096], device='cuda:0')
# tensor([0.7398, 0.7431], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6374, 0.6625], device='cuda:0')
# tensor([0.5663, 0.6346], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6784, 0.6878], device='cuda:0')
# tensor([0.6263, 0.7160], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.7114, 0.6941], device='cuda:0')
# tensor([0.6313, 0.7649], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.6573, 0.7189], device='cuda:0')
# tensor([0.7462, 0.6829], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7702, 0.6962], device='cuda:0')
# tensor([0.7132, 0.6487], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7630, 0.7458], device='cuda:0')
# tensor([0.7158, 0.6491], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6669, 0.7076], device='cuda:0')
# tensor([0.6759, 0.7094], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6540, 0.7430], device='cuda:0')
# tensor([0.7129, 0.7740], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6197, 0.6835], device='cuda:0')
# tensor([0.6486, 0.7737], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7474, 0.7340], device='cuda:0')
# tensor([0.7169, 0.7401], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.7167, 0.7463], device='cuda:0')
# tensor([0.7458, 0.7365], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6975, 0.7488], device='cuda:0')
# tensor([0.7142, 0.6934], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7201, 0.7576], device='cuda:0')
# tensor([0.7324, 0.7156], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6267, 0.6907], device='cuda:0')
# tensor([0.4958, 0.7031], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7880, 0.7189], device='cuda:0')
# tensor([0.7273, 0.6829], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6576, 0.7315], device='cuda:0')
# tensor([0.6211, 0.7040], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7637, 0.7063], device='cuda:0')
# tensor([0.7358, 0.7620], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6443, 0.6058], device='cuda:0')
# tensor([0.6496, 0.5734], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7371, 0.6578], device='cuda:0')
# tensor([0.7496, 0.7729], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7548, 0.7612], device='cuda:0')
# tensor([0.6799, 0.7563], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6784, 0.6199], device='cuda:0')
# tensor([0.6894, 0.6188], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6695, 0.6972], device='cuda:0')
# tensor([0.7226, 0.7166], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5991, 0.7070], device='cuda:0')
# tensor([0.6238, 0.7118], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6978, 0.6649], device='cuda:0')
# tensor([0.6786, 0.6987], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6954, 0.6436], device='cuda:0')
# tensor([0.7216, 0.6508], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7396, 0.7522], device='cuda:0')
# tensor([0.6981, 0.7544], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7400, 0.7219], device='cuda:0')
# tensor([0.7181, 0.7475], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7350, 0.6927], device='cuda:0')
# tensor([0.7380, 0.7316], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7399, 0.6808], device='cuda:0')
# tensor([0.6616, 0.7158], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7271, 0.7179], device='cuda:0')
# tensor([0.7363, 0.7967], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7266, 0.7871], device='cuda:0')
# tensor([0.6349, 0.8088], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6953, 0.7149], device='cuda:0')
# tensor([0.7066, 0.7294], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7259, 0.6828], device='cuda:0')
# tensor([0.7101, 0.7310], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7383, 0.7485], device='cuda:0')
# tensor([0.7661, 0.7641], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6995, 0.7094], device='cuda:0')
# tensor([0.7347, 0.7310], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.7271, 0.7567], device='cuda:0')
# tensor([0.7088, 0.7844], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6330, 0.7034], device='cuda:0')
# tensor([0.7385, 0.7617], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7708, 0.7416], device='cuda:0')
# tensor([0.6768, 0.7468], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7345, 0.6741], device='cuda:0')
# tensor([0.7159, 0.6715], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6073, 0.6916], device='cuda:0')
# tensor([0.6531, 0.7270], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7242, 0.7500], device='cuda:0')
# tensor([0.7331, 0.7617], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7176, 0.7121], device='cuda:0')
# tensor([0.6732, 0.6692], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6459, 0.6293], device='cuda:0')
# tensor([0.6221, 0.6603], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7326, 0.7336], device='cuda:0')
# tensor([0.6818, 0.7331], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7170, 0.7236], device='cuda:0')
# tensor([0.7272, 0.7236], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.7309, 0.7734], device='cuda:0')
# tensor([0.8370, 0.6742], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6835, 0.7089], device='cuda:0')
# tensor([0.6254, 0.7796], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7355, 0.7370], device='cuda:0')
# tensor([0.6774, 0.6573], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7390, 0.7526], device='cuda:0')
# tensor([0.6450, 0.7584], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7172, 0.7318], device='cuda:0')
# tensor([0.6865, 0.6843], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6997, 0.7105], device='cuda:0')
# tensor([0.6574, 0.7149], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6714, 0.7487], device='cuda:0')
# tensor([0.6153, 0.7880], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6555, 0.7414], device='cuda:0')
# tensor([0.7207, 0.6329], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7398, 0.5819], device='cuda:0')
# tensor([0.7032, 0.5823], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7116, 0.7400], device='cuda:0')
# tensor([0.6918, 0.6690], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7771, 0.6804], device='cuda:0')
# tensor([0.7515, 0.6163], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7028, 0.6844], device='cuda:0')
# tensor([0.7579, 0.7017], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6700, 0.7616], device='cuda:0')
# tensor([0.6799, 0.6668], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7519, 0.6662], device='cuda:0')
# tensor([0.6803, 0.5904], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7446, 0.6918], device='cuda:0')
# tensor([0.6900, 0.7146], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6514, 0.6680], device='cuda:0')
# tensor([0.6743, 0.6210], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8395, 0.7914], device='cuda:0')
# tensor([0.8480, 0.8388], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6141, 0.7619], device='cuda:0')
# tensor([0.6301, 0.7273], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6607, 0.7656], device='cuda:0')
# tensor([0.7417, 0.7599], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8184, 0.7576], device='cuda:0')
# tensor([0.7932, 0.7214], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7459, 0.8625], device='cuda:0')
# tensor([0.7220, 0.8070], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7338, 0.5873], device='cuda:0')
# tensor([0.7494, 0.5865], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7405, 0.6537], device='cuda:0')
# tensor([0.7071, 0.6965], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6875, 0.6854], device='cuda:0')
# tensor([0.6164, 0.7078], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7198, 0.7497], device='cuda:0')
# tensor([0.7313, 0.7397], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6462, 0.7446], device='cuda:0')
# tensor([0.7068, 0.7358], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7552, 0.7321], device='cuda:0')
# tensor([0.7602, 0.7319], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7601, 0.7355], device='cuda:0')
# tensor([0.7416, 0.6479], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6500, 0.7594], device='cuda:0')
# tensor([0.5524, 0.7656], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.6722, 0.7205], device='cuda:0')
# tensor([0.6743, 0.6933], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7082, 0.7869], device='cuda:0')
# tensor([0.7006, 0.6701], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6724, 0.7408], device='cuda:0')
# tensor([0.6469, 0.6615], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7429, 0.7159], device='cuda:0')
# tensor([0.7020, 0.7093], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6233, 0.6077], device='cuda:0')
# tensor([0.6916, 0.7339], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7127, 0.7194], device='cuda:0')
# tensor([0.7661, 0.7541], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6744, 0.6723], device='cuda:0')
# tensor([0.6303, 0.5889], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6428, 0.7431], device='cuda:0')
# tensor([0.6353, 0.6951], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6490, 0.7343], device='cuda:0')
# tensor([0.6761, 0.7684], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.9571, 0.7324], device='cuda:0')
# tensor([0.9643, 0.7497], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7329, 0.6921], device='cuda:0')
# tensor([0.7426, 0.7509], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6775, 0.6119], device='cuda:0')
# tensor([0.7130, 0.7281], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7196, 0.7656], device='cuda:0')
# tensor([0.7598, 0.7839], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7456, 0.6675], device='cuda:0')
# tensor([0.7298, 0.6991], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7010, 0.7513], device='cuda:0')
# tensor([0.7971, 0.6809], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6919, 0.6634], device='cuda:0')
# tensor([0.6589, 0.6392], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7009, 0.6867], device='cuda:0')
# tensor([0.7020, 0.6302], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7521, 0.7591], device='cuda:0')
# tensor([0.7607, 0.6962], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6675, 0.7495], device='cuda:0')
# tensor([0.6763, 0.7052], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6793, 0.7185], device='cuda:0')
# tensor([0.7004, 0.6972], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6759, 0.6760], device='cuda:0')
# tensor([0.7592, 0.7386], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7429, 0.7333], device='cuda:0')
# tensor([0.7262, 0.7082], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7061, 0.6490], device='cuda:0')
# tensor([0.7684, 0.5986], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6867, 0.7268], device='cuda:0')
# tensor([0.7309, 0.7329], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7052, 0.6469], device='cuda:0')
# tensor([0.6050, 0.5966], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7193, 0.7461], device='cuda:0')
# tensor([0.7749, 0.7193], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7551, 0.7586], device='cuda:0')
# tensor([0.7093, 0.7107], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6562, 0.7558], device='cuda:0')
# tensor([0.7329, 0.7199], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7429, 0.7288], device='cuda:0')
# tensor([0.7469, 0.7486], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.7726, 0.6796], device='cuda:0')
# tensor([0.8209, 0.7669], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7069, 0.7009], device='cuda:0')
# tensor([0.7042, 0.7020], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8023, 0.6538], device='cuda:0')
# tensor([0.8122, 0.6504], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6772, 0.7190], device='cuda:0')
# tensor([0.6988, 0.7160], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7196, 0.6522], device='cuda:0')
# tensor([0.7325, 0.6707], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7045, 0.7165], device='cuda:0')
# tensor([0.6768, 0.7306], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0.7089)
# 0.17333333333333334
# mag 0.002947482823316629

# %%
dicesa = np.array(torch.cat(dices).cpu())
plt.hist(dicesa, 20)
plt.xlabel("DICE")
print(np.mean(dicesa))
ff = np.mean(folds_list)
print(ff)
# Out:
# 0.70750237
# 0.17333333333333334

# %%
net.cuda()
with torch.no_grad():
    print(net(moving_image, fixed_image))
# Out:
# ICONLoss(all_loss=tensor(0.0198, device='cuda:0'), inverse_consistency_loss=tensor(0.0174, device='cuda:0'), similarity_loss=tensor(0.0163, device='cuda:0'), transform_magnitude=tensor(0.0042, device='cuda:0'), flips=tensor(0., device='cuda:0'))

# %%
if not("N" in locals()):
    N = 0
N += 1
N %= 2
#N = 3
#plt.imshow(fixed_image[N, 0, 10].cpu() - net.warped_image_A[N, 0, 10].cpu().detach())
#plt.show()
plt.rcParams["figure.figsize"] = (5, 5)
def imshow(x):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
slice_ = 40
imshow(fixed_image[N, 0, slice_])
plt.show()
imshow(net.warped_image_A[N, 0, slice_])
plt.show()

plt.imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach() - moving_image[N, 0, slice_ ].cpu().detach())
plt.show()
#plt.imshow(net.regis_net.x_comp_phi[N, 0, slice_].cpu().detach() - moving_image[N, 0, slice_].cpu().detach())
#plt.show()
plt.imshow((fixed_image - moving_image)[N, 0, slice_].cpu().detach())
plt.show()

imshow(moving_image[N, 0, slice_].cpu().detach())
plt.show()

# %%
import matplotlib.pyplot as plt
S = 100
plt.imshow(moving_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(fixed_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(net.warped_image_A[N, 0, :, S].cpu().detach())
plt.show()
plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach())
plt.show()

plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach() - moving_image[N, 0, :, S].cpu())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 import matplotlib.pyplot as plt
#       2 S = 100
# ----> 3 plt.imshow(moving_image[N, 0, :, S].cpu())
#       4 plt.show()
#       5 plt.imshow(fixed_image[N, 0, :, S].cpu())
#
# NameError: name 'moving_image' is not defined

# %%
S = 49
plt.imshow(moving_cartilage[N, 0, :, S * 4].cpu())
plt.show() 
plt.imshow(warped_moving_cartilage[N, 0, :, S * 4].detach().cpu())
plt.show()

plt.imshow(fixed_cartilage[N, 0, :, S * 4].cpu())
plt.show()

plt.imshow((warped_moving_cartilage[N, 0, :, S * 4].detach().cpu() - fixed_cartilage[N, 0, :, S * 4].cpu()))
plt.show()

# %%
import icon_registration.visualize as visualize
N = (N + 1)% 2
#N = 1
plt.rcParams["figure.figsize"] = 10, 10
visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 40])
plt.show()
visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 40])

# %%
net.phi_AB.__closure__[0].cell_contents
# Out:
# <function icon_registration.network_wrappers.TwoStepRegistration.forward.<locals>.<lambda>(input_)>

# %%
N = (N + 1) % 2
visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identity_map))[N, [1, 2], 20])

# %%
import visualize
mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
import visualize
mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
mkdir supll_regis_figures

# %%
import importlib
importlib.reload(visualize)
import matplotlib.colors as colors

for N in range(2):

    plt.rcParams["figure.figsize"] = (5, 5)
    def imshow(x):
        plt.xticks([])
        plt.yticks([])
        plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
    offset = 0
    slice_ = 20
    
    for axis in ["Coronal", "Sagittal", "Axial"]:
        m_image = moving_image[N, 0].cpu().detach()
        f_image = fixed_image[N, 0].cpu().detach()
        m_warped_image_A = net.warped_image_A[N, 0].cpu().detach() 
        phi_BA = net.phi_BA_vectorfield[N]
        
        dV = flips2(net.phi_AB_vectorfield)[N, 0]
        
        if axis == "Sagittal":
            m_image_slice = m_image[slice_]
            f_image_slice = f_image[slice_]
            warped_image_A_slice = m_warped_image_A[slice_]
            phi_BA_slice = phi_BA[[1, 2], 20].clone()
            dV_slice = dV[slice_]
        if axis == "Coronal":
            m_image_slice = m_image[:, slice_].transpose(0, 1)
            f_image_slice = f_image[:, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[2, 0], :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, slice_].transpose(0, 1)
        if axis == "Axial":
            slice_ *= 2
            m_image_slice = m_image[:, :, slice_].transpose(0, 1)
            f_image_slice = f_image[:, :, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, :, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[1, 0], :, :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, :, slice_].transpose(0, 1)
            slice_ /= 2
            
            
        
        header = f"supll_regis_figures/{axis}Pair{N + offset}"
        imshow(m_image_slice)
        plt.savefig(header + "ImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(f_image_slice)
        plt.savefig(header + "ImageB.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        plt.savefig(header + "WarpedImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        visualize.show_as_grid(phi_BA_slice)
        plt.savefig(header + "WarpedImageAGrid.png", bbox_inches="tight")
        plt.clf()
        
        plt.xticks([])
        plt.yticks([])
        
        plt.imshow(dV_slice, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
        plt.title("min dV is $\\bf{" + f"{np.min(dV_slice.numpy()):.3}" + "}$ in this slice", 
                 fontdict={'fontsize':13})
        plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
        #lt.show()
        #plt.imshow(dV[1, 0, 40] < 0)


        plt.savefig(header + "dV.png", bbox_inches="tight")
        plt.clf()
    """
    imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach())
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageB.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageBGrid.png")
    plt.clf()
    """

    
    plt.show()

# %%
import importlib
importlib.reload(visualize)

# %%
plt.imshow(torch.min(dV[1, 0], axis=0).values)
plt.colorbar()

# %%
torch.sum(dV[1] < 0)

# %%
dV

# %%
116 / (80 * 192 * 192), 1 / 25000

# %%
import matplotlib.colors as colors

plt.xticks([])
plt.yticks([])
query = dV[0, 0, 43]
plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice", 
         fontdict={'fontsize':13})
plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
#lt.show()
#plt.imshow(dV[1, 0, 40] < 0)


plt.savefig("dVslice0.pdf", bbox_inches="tight")

# %%
2 * np.sum(folds_list) / (np.product(list(dV.shape)) * len(r_ds))

# %%
print("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice")
from matplotlib import rc
rc('text', usetex=False)
np.min(query.numpy())

# %%
adv = np.array(dV)
filteredDV = adv[adv < 0.05]
plt.hist(filteredDV, bins=100)
plt.show()

# %%
plt.hist(np.concatenate(filteredDV_list), bins=100)
plt.title("Distribution of negative dV voxels in test set")
plt.xlabel("dV (in voxels³)")
plt.ylabel("Count")
plt.savefig("DistributionNegativeJacobian.pdf")

# %%
np.mean(np.concatenate(filteredDV_list))

# %%
np.median(np.concatenate(filteredDV_list))

# %%
np.percentile(np.concatenate(filteredDV_list), 1)

# %%
# %time net.regis_net(moving_image, fixed_image)

# %%
with torch.no_grad():
    x = batched_ds[0]
    x = list(zip(*x))
    x = [torch.cat(r, 0).cuda().float() for r in x]
    fixed_image, fixed_cartilage = x[0], x[2]
    moving_image, moving_cartilage = x[1], x[3]

# %%
# %%time
with torch.no_grad():
    phi = net.regis_net(moving_image, fixed_image)
    phi_AB_vectorfield = phi(net.identityMap).cpu()

# %%
# %%time 
net(moving_image, fixed_image)

# %%
plt.hist(torch.cat(dices).cpu().detach().numpy(), bins=30)

# %%
pixel_displacement = ((net.phi_AB_vectorfield.cpu() - net.identityMap.cpu()) 
    * torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None])
plt.imshow(pixel_displacement[0, 2, 40], cmap="rainbow")
plt.colorbar()

# %%
torch.max(torch.abs(pixel_displacement))

# %%
error = (net.phi_AB(net.phi_BA_vectorfield) - net.identityMap).cpu()* torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None]

# %%
plt.imshow((error)[0, 0, 40])
plt.colorbar()

# %%
torch.sqrt(torch.mean(error**2))

# %%
plt.rcParams["figure.figsize"]

# %%
plt.hist(folds_list, bins=40)
plt.xlabel("number of folded pixels")
plt.ylabel("number of image pairs")

# %%
import pickle
with open("../results/grad_hires-1/loss_curve", "rb") as f:
    ncurve2 = pickle.load(f)
ncurve2 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in ncurve2]
ncurve2 = np.array(ncurve2)
plt.plot(ncurve2)


import pickle
with open("../../masked_similarity_InvCon/results/hires_smart_6/loss_curve", "rb") as f:
    curve = pickle.load(f)
curve = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve]
curve = np.array(curve)
plt.plot(curve)


import pickle
with open("../../masked_similarity_InvCon/results/fourth_net_frozen/loss_curve", "rb") as f:
    curve4 = pickle.load(f)
curve4 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve4]
curve4 = np.array(curve4)
plt.plot(curve4)

# %%
plt.plot(ncurve2[:, 2])

plt.plot(curve[:, 2])

plt.plot(curve4[:, 2])

# %%
plt.plot(ncurve2[:, 1])


plt.plot(curve[:, 1])

plt.plot(curve4[:, 1])

# %%
plt.plot(ncurve2[:, 3])


plt.plot(curve[:, 3])
