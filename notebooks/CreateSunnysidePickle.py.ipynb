# %%
import itk

# %%
import tqdm

# %%
import os
ars = []
folder = "../synthetic_example_out_kernel_weighting_type_sqrt_w_K_sqrt_w/label_affine_icbm/"
for fname in tqdm.tqdm(os.listdir(folder)):
    ars.append(itk.array_from_image(itk.imread(folder + fname)))
# Out:
# 100%|██████████| 20000/20000 [04:32<00:00, 73.41it/s]

# %%
ars2 = np.array(ars)

# %%
ars2.size
# Out:
# 327680000

# %%
ars2.shape
# Out:
# (20000, 128, 128, 1)

# %%
with open("/playpen/tgreer/sunnyside.pickle", "wb") as f:
    pickle.dump(ars2, f)

# %%
import pickle

# %%
with open("/playpen/tgreer/sunnyside.pickle", "rb") as f:
    pickle.load(f)

# %%
import data

# %%
d1, d2 = data.get_dataset_sunnyside()

# %%
import matplotlib.pyplot as plt
plt.imshow(ars2[0, :, :, 0])
plt.colorbar()
plt.show()

# %%
N += 1
plt.imshow(ars2[N, :, :, 0], interpolation=None)
plt.colorbar()
plt.show()

# %%
N = 0
