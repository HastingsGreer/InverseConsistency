# %%
import icon_registration.networks as networks
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
from collections import OrderedDict
import torch.nn.functional as F
from icon_registration.mermaidlite import compute_warped_image_multiNC, identity_map_multiN
import torch
import random
import icon_registration.inverseConsistentNet as inverseConsistentNet
import icon_registration.network_wrappers as network_wrappers
import icon_registration.data as data
import numpy as np
import matplotlib.pyplot as plt
import itk

# %%
r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#batched_ds = list(zip(*[r_ds[i::4] for i in range(2)]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#
# File /playpen-raid1/tgreer/anaconda3/envs/GradICON/lib/python3.9/site-packages/torch/serialization.py:607, in load(f, map_location, pickle_module, **pickle_load_args)
#     605             opened_file.seek(orig_position)
#     606             return torch.jit.load(opened_file)
# --> 607         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     608 return _legacy_load(opened_file, map_location, pickle_module, **pickle_load_args)
#
# File /playpen-raid1/tgreer/anaconda3/envs/GradICON/lib/python3.9/site-packages/torch/serialization.py:882, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#     880 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#     881 unpickler.persistent_load = persistent_load
# --> 882 result = unpickler.load()
#     884 torch._utils._validate_loaded_sparse_tensors()
#     886 return result
#
# File /playpen-raid1/tgreer/anaconda3/envs/GradICON/lib/python3.9/site-packages/torch/serialization.py:857, in _load.<locals>.persistent_load(saved_id)
#     855 data_type, key, location, size = data
#     856 if key not in loaded_storages:
# --> 857     load_tensor(data_type, size, key, _maybe_decode_ascii(location))
#     858 storage = loaded_storages[key]
#     859 return storage
#
# File /playpen-raid1/tgreer/anaconda3/envs/GradICON/lib/python3.9/site-packages/torch/serialization.py:845, in _load.<locals>.load_tensor(data_type, size, key, location)
#     842 name = f'data/{key}'
#     843 dtype = data_type(0).dtype
# --> 845 storage = zip_file.get_storage_from_record(name, size, dtype).storage()
#     846 loaded_storages[key] = restore_location(storage, location)
#
# KeyboardInterrupt:

# %%
# !ntop
# Out:
# Thu Mar 10 22:47:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.103.01   Driver Version: 470.103.01   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA RTX A6000    Off  | 00000000:3B:00.0 Off |                  Off |
# | 30%   28C    P2    65W / 300W |   3819MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  NVIDIA RTX A6000    Off  | 00000000:5E:00.0 Off |                  Off |
# | 30%   22C    P8     5W / 300W |      2MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  NVIDIA RTX A6000    Off  | 00000000:B1:00.0 Off |                  Off |
# | 30%   24C    P8     7W / 300W |      2MiB / 48685MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  NVIDIA RTX A6000    Off  | 00000000:D9:00.0 Off |                  Off |
# | 40%   68C    P2   243W / 300W |  41445MiB / 48685MiB |    100%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# |  GPU   PID     USER    GPU MEM  %CPU  %MEM      TIME  COMMAND               |
# |    0 1642974   tgreer    3817MiB  17.7  10.7     05:51  /playpen-raid1/tgree  |
# |    3 3747158   zyshen   41443MiB   105   2.0    4 days  python demo_for_easy  |
# +-----------------------------------------------------------------------------+

# %%
batched_ds = list(zip(*[r_ds[i::2] for i in range(2)]))

# %%
phi = network_wrappers.FunctionFromVectorField(
    networks.tallUNet(unet=networks.UNet2ChunkyMiddle, dimension=3)
)
psi = network_wrappers.FunctionFromVectorField(networks.tallUNet2(dimension=3))

pretrained_lowres_net = network_wrappers.DoubleNet(phi, psi)

regis_net = network_wrappers.DoubleNet(
    network_wrappers.DownsampleNet(pretrained_lowres_net, 3), 
    network_wrappers.FunctionFromVectorField(networks.tallUNet2(dimension=3)))

BATCH_SIZE = 8
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [BATCH_SIZE, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]
    
network_wrappers.assignIdentityMap(regis_net, input_shape)

trained_weights = torch.load("../results/grad_hires-1/knee_aligner_resi_net24300")
regis_net.load_state_dict(trained_weights)
# Out:
# <All keys matched successfully>

# %%
net = inverseConsistentNet.InverseConsistentNet(
    regis_net, 
    lambda x, y: (x - y) **2,
    3600,
)

# %%
BATCH_SIZE = 2
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [BATCH_SIZE, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

network_wrappers.assignIdentityMap(net, input_shape)

# %%
net.cuda()
net.eval()
0
# Out:
# 0

# %%
def flips(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True)
    return torch.sum(dV < 0)# / BATCH_SIZE
def flips2(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True) / np.product(net.spacing)
    return dV.detach().cpu()
with torch.no_grad():
    dices = []
    folds_list = []
    
    filteredDV_list = []
    
    
    for x in batched_ds[:]:
        x = list(zip(*x))
        x = [torch.cat(r, 0).cuda().float() for r in x]
        fixed_image, fixed_cartilage = x[0], x[2]
        moving_image, moving_cartilage = x[1], x[3]

        net(moving_image, fixed_image)
        phi_AB_vectorfield = net.phi_AB(net.identityMap)
        fat_phi = torch.nn.Upsample(size=moving_cartilage.size()[2:], mode="trilinear")(phi_AB_vectorfield[:, :3])
        sz = np.array(fat_phi.size())
        spacing = 1./(sz[2::]-1) 
        warped_moving_cartilage = compute_warped_image_multiNC(moving_cartilage.float(), fat_phi, spacing, 1)
        wmb = warped_moving_cartilage > .5
        fb = fixed_cartilage > .5
        intersection = wmb * fb
        d = 2 * torch.sum(intersection, [1,2,3,4]).float() / (torch.sum(wmb, [1,2,3,4]) + torch.sum(fb, [1,2,3,4]))
        print(d)
        dices.append(d)
        f = flips(phi_AB_vectorfield[:1])
        print(f)
        folds_list.append(f.item())
        f = flips(phi_AB_vectorfield[1:])
        print(f)
        folds_list.append(f.item())
        
        dV = flips2(phi_AB_vectorfield)
        
        dV = np.array(dV).flatten()
        dV = dV[dV < 0]
        filteredDV_list.append(dV)
        
    dd = torch.mean(torch.cat(dices).cpu())
    print(dd)
    ff = np.mean(folds_list)
    print(ff)
# Out:
# Default upsampling behavior when mode=trilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# tensor([0.7021, 0.7653], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7488, 0.6570], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6920, 0.6640], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7793, 0.6934], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7100, 0.7730], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7144, 0.7817], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7562, 0.6257], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6679, 0.7682], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6865, 0.7324], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6201, 0.7240], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7024, 0.7674], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6915, 0.6244], device='cuda:0')
# tensor(7, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6986, 0.7264], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7104, 0.7289], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7319, 0.7129], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.6718, 0.7911], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7815, 0.7376], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5852, 0.6794], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7759, 0.6377], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7819, 0.7723], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7542, 0.7466], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6569, 0.6906], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6773, 0.6805], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7400, 0.7361], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7343, 0.6441], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.5979, 0.7658], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7073, 0.6863], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7182, 0.6917], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6967, 0.7177], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6871, 0.6759], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7897, 0.7399], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7436, 0.6428], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7974, 0.7475], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7264, 0.7748], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6888, 0.7231], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7321, 0.7501], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7558, 0.7132], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7353, 0.7075], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7509, 0.7224], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor([0.7701, 0.6953], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7357, 0.7088], device='cuda:0')
# tensor(25, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6246, 0.6394], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.6686, 0.6801], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6799, 0.7016], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.6991, 0.7066], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7738, 0.7179], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7475, 0.7284], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6721, 0.7041], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6697, 0.7470], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.6680, 0.6994], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7386, 0.7681], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7362, 0.7384], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7193, 0.7516], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7381, 0.7662], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5924, 0.7014], device='cuda:0')
# tensor(30, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7538, 0.7066], device='cuda:0')
# tensor(5, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6559, 0.7381], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7439, 0.7212], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6454, 0.6280], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.7378, 0.6962], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6958, 0.7604], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6838, 0.6118], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6980, 0.7205], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5957, 0.6984], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6780, 0.6968], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7319, 0.6678], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7070, 0.7474], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7147, 0.7210], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7314, 0.7191], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7172, 0.7033], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7508, 0.7333], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6998, 0.7895], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6948, 0.7134], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7259, 0.7194], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7478, 0.7468], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7144, 0.7150], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6999, 0.7683], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6344, 0.7334], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7509, 0.7137], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7354, 0.6868], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(11, device='cuda:0')
# tensor([0.6390, 0.6792], device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(22, device='cuda:0')
# tensor([0.7444, 0.7775], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7230, 0.7198], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.6567, 0.6249], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.6956, 0.7120], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.7420, 0.7418], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7386, 0.7420], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6490, 0.7389], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.7308, 0.7376], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7221, 0.7423], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7230, 0.7351], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(21, device='cuda:0')
# tensor([0.6846, 0.7167], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6391, 0.7506], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6405, 0.7299], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7346, 0.6197], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7024, 0.7171], device='cuda:0')
# tensor(15, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7676, 0.6816], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(32, device='cuda:0')
# tensor([0.7286, 0.6920], device='cuda:0')
# tensor(73, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6786, 0.7537], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7570, 0.6720], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7245, 0.6784], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6801, 0.6779], device='cuda:0')
# tensor(64, device='cuda:0')
# tensor(10, device='cuda:0')
# tensor([0.8549, 0.7899], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6314, 0.7619], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6736, 0.7706], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8071, 0.7312], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7382, 0.8617], device='cuda:0')
# tensor(15, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7691, 0.5740], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(22, device='cuda:0')
# tensor([0.7287, 0.6649], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.6697, 0.7031], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7375, 0.7565], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.6744, 0.7634], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7627, 0.7133], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7787, 0.7231], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6146, 0.7702], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6680, 0.7095], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7205, 0.7382], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.6803, 0.7267], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7193, 0.7286], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6596, 0.6565], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7338, 0.7300], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6487, 0.6760], device='cuda:0')
# tensor(14, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6687, 0.7408], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6798, 0.7263], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.9615, 0.7648], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7397, 0.7060], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.6874, 0.6223], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7274, 0.7649], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7381, 0.6811], device='cuda:0')
# tensor(9, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7345, 0.7692], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7050, 0.6526], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(11, device='cuda:0')
# tensor([0.7060, 0.6550], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor([0.7561, 0.7967], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6447, 0.6945], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6999, 0.7268], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6994, 0.7021], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7387, 0.7352], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7190, 0.6102], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.7099, 0.7294], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7208, 0.6491], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7129, 0.7388], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7651, 0.7504], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6742, 0.7485], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7232, 0.7043], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.8101, 0.7203], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7113, 0.7060], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8077, 0.6384], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.6906, 0.7104], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7345, 0.6437], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6849, 0.7376], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0.7138)
# 1.71

# %%
dicesa = np.array(torch.cat(dices).cpu())
plt.hist(dicesa, 20)
plt.xlabel("DICE")
print(np.mean(dicesa))
ff = np.mean(folds_list)
print(ff)
# Out:
# 0.71381825
# 1.71

# %%
if not("N" in locals()):
    N = 0
N += 1
N %= 2
#N = 3
#plt.imshow(fixed_image[N, 0, 10].cpu() - net.warped_image_A[N, 0, 10].cpu().detach())
#plt.show()
plt.rcParams["figure.figsize"] = (5, 5)
def imshow(x):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
slice_ = 40
imshow(fixed_image[N, 0, slice_])
plt.show()
imshow(net.warped_image_A[N, 0, slice_])
plt.show()

plt.imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach() - moving_image[N, 0, slice_ ].cpu().detach())
plt.show()
#plt.imshow(net.regis_net.x_comp_phi[N, 0, slice_].cpu().detach() - moving_image[N, 0, slice_].cpu().detach())
#plt.show()
plt.imshow((fixed_image - moving_image)[N, 0, slice_].cpu().detach())
plt.show()

imshow(moving_image[N, 0, slice_].cpu().detach())
plt.show()

# %%
import matplotlib.pyplot as plt
S = 100
plt.imshow(moving_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(fixed_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(net.warped_image_A[N, 0, :, S].cpu().detach())
plt.show()
plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach())
plt.show()

plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach() - moving_image[N, 0, :, S].cpu())

# %%
S = 49
plt.imshow(moving_cartilage[N, 0, :, S * 4].cpu())
plt.show() 
plt.imshow(warped_moving_cartilage[N, 0, :, S * 4].detach().cpu())
plt.show()

plt.imshow(fixed_cartilage[N, 0, :, S * 4].cpu())
plt.show()

plt.imshow((warped_moving_cartilage[N, 0, :, S * 4].detach().cpu() - fixed_cartilage[N, 0, :, S * 4].cpu()))
plt.show()

# %%
import icon_registration.visualize as visualize
N = (N + 1)% 2
#N = 1
plt.rcParams["figure.figsize"] = 10, 10
visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
plt.show()
visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 20])

# %%
net.phi_AB.__closure__[0].cell_contents
# Out:
# <function icon_registration.network_wrappers.FunctionFromVectorField.forward.<locals>.ret(input_)>

# %%
N = (N + 1) % 2
visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identityMap))[N, [1, 2], 20])

# %%
import visualize
mp = hires_Net.phi_AB(hires_Net.regis_net.net.identityMap[:, :] + torch.tensor([[[[[0]]], [[[0]]], [[[0]]]]]).cuda())
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [29], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = hires_Net.phi_AB(hires_Net.regis_net.net.identityMap[:, :] + torch.tensor([[[[[0]]], [[[0]]], [[[0]]]]]).cuda())
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
import mermaidlite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [183], in <cell line: 1>()
# ----> 1 import mermaidlite
#
# ModuleNotFoundError: No module named 'mermaidlite'

# %%
import visualize
mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [184], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
import visualize
mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [185], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
mkdir supll_regis_figures

# %%
import importlib
importlib.reload(visualize)
import matplotlib.colors as colors

for N in range(2):

    plt.rcParams["figure.figsize"] = (5, 5)
    def imshow(x):
        plt.xticks([])
        plt.yticks([])
        plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
    offset = 0
    slice_ = 20
    
    for axis in ["Coronal", "Sagittal", "Axial"]:
        m_image = moving_image[N, 0].cpu().detach()
        f_image = fixed_image[N, 0].cpu().detach()
        m_warped_image_A = net.warped_image_A[N, 0].cpu().detach() 
        phi_BA = net.phi_BA_vectorfield[N]
        
        dV = flips2(net.phi_AB_vectorfield)[N, 0]
        
        if axis == "Sagittal":
            m_image_slice = m_image[slice_]
            f_image_slice = f_image[slice_]
            warped_image_A_slice = m_warped_image_A[slice_]
            phi_BA_slice = phi_BA[[1, 2], 20].clone()
            dV_slice = dV[slice_]
        if axis == "Coronal":
            m_image_slice = m_image[:, slice_].transpose(0, 1)
            f_image_slice = f_image[:, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[2, 0], :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, slice_].transpose(0, 1)
        if axis == "Axial":
            slice_ *= 2
            m_image_slice = m_image[:, :, slice_].transpose(0, 1)
            f_image_slice = f_image[:, :, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, :, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[1, 0], :, :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, :, slice_].transpose(0, 1)
            slice_ /= 2
            
            
        
        header = f"supll_regis_figures/{axis}Pair{N + offset}"
        imshow(m_image_slice)
        plt.savefig(header + "ImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(f_image_slice)
        plt.savefig(header + "ImageB.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        plt.savefig(header + "WarpedImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        visualize.show_as_grid(phi_BA_slice)
        plt.savefig(header + "WarpedImageAGrid.png", bbox_inches="tight")
        plt.clf()
        
        plt.xticks([])
        plt.yticks([])
        
        plt.imshow(dV_slice, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
        plt.title("min dV is $\\bf{" + f"{np.min(dV_slice.numpy()):.3}" + "}$ in this slice", 
                 fontdict={'fontsize':13})
        plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
        #lt.show()
        #plt.imshow(dV[1, 0, 40] < 0)


        plt.savefig(header + "dV.png", bbox_inches="tight")
        plt.clf()
    """
    imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach())
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageB.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageBGrid.png")
    plt.clf()
    """

    
    plt.show()

# %%
import importlib
importlib.reload(visualize)
# Out:
# <module 'visualize' from '/playpen-raid1/tgreer/InverseConsistency/visualize.py'>

# %%
plt.imshow(torch.min(dV[1, 0], axis=0).values)
plt.colorbar()

# %%
torch.sum(dV[1] < 0)
# Out:
# tensor(13)

# %%
dV
# Out:
# (0,)

# %%
116 / (80 * 192 * 192), 1 / 25000
# Out:
# (3.9333767361111114e-05, 4e-05)

# %%
import matplotlib.colors as colors

plt.xticks([])
plt.yticks([])
query = dV[0, 0, 43]
plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice", 
         fontdict={'fontsize':13})
plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
#lt.show()
#plt.imshow(dV[1, 0, 40] < 0)


plt.savefig("dVslice0.pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [104], in <cell line: 5>()
#       3 plt.xticks([])
#       4 plt.yticks([])
# ----> 5 query = dV[0, 0, 43]
#       6 plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
#       7 plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice",
#       8          fontdict={'fontsize':13})
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed

# %%
2 * np.sum(folds_list) / (np.product(list(dV.shape)) * len(r_ds))
# Out:
# 2.046440866760003e-05

# %%
print("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice")
from matplotlib import rc
rc('text', usetex=False)
np.min(query.numpy())
# Out:
# dV attains a minimum of $\bf{0.0613}$ in this slice
# 0.061257

# %%
adv = np.array(dV)
filteredDV = adv[adv < 0.05]
plt.hist(filteredDV, bins=100)
plt.show()

# %%
plt.hist(np.concatenate(filteredDV_list), bins=100)
plt.title("Distribution of negative dV voxels in test set")
plt.xlabel("dV (in voxels³)")
plt.ylabel("Count")
plt.savefig("DistributionNegativeJacobian.pdf")

# %%
np.mean(np.concatenate(filteredDV_list))
# Out:
# -0.09664285

# %%
np.median(np.concatenate(filteredDV_list))
# Out:
# -0.054298144

# %%
np.percentile(np.concatenate(filteredDV_list), 1)
# Out:
# -0.6120650005340577

# %%
# %time net.regis_net(moving_image, fixed_image)
# Out:
# CPU times: user 8.3 ms, sys: 20.2 ms, total: 28.5 ms
# Wall time: 21.4 ms
# <function icon_registration.network_wrappers.DoubleNet.forward.<locals>.<lambda>(input_)>

# %%
with torch.no_grad():
    x = batched_ds[0]
    x = list(zip(*x))
    x = [torch.cat(r, 0).cuda().float() for r in x]
    fixed_image, fixed_cartilage = x[0], x[2]
    moving_image, moving_cartilage = x[1], x[3]

# %%
# %%time
with torch.no_grad():
    phi = net.regis_net(moving_image, fixed_image)
    phi_AB_vectorfield = phi(net.identityMap).cpu()
# Out:
# CPU times: user 1.45 s, sys: 61 ms, total: 1.51 s
# Wall time: 1.48 s

# %%
# %%time 
net(moving_image, fixed_image)
# Out:
# CPU times: user 2.78 s, sys: 1.12 s, total: 3.9 s
# Wall time: 3.83 s
# (tensor(0.0624, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(5.5865e-05, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(6.9831e-06, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
plt.hist(torch.cat(dices).cpu().detach().numpy(), bins=30)
# Out:
# (array([ 3.,  1.,  1.,  2.,  5.,  6.,  7., 10., 17., 22., 21., 26., 30.,
#         40., 41., 29., 20.,  8.,  4.,  4.,  0.,  0.,  1.,  1.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([0.45836532, 0.47490254, 0.4914398 , 0.507977  , 0.52451426,
#         0.54105145, 0.5575887 , 0.5741259 , 0.59066314, 0.6072004 ,
#         0.6237376 , 0.6402748 , 0.6568121 , 0.67334926, 0.6898865 ,
#         0.70642376, 0.72296095, 0.7394982 , 0.7560354 , 0.77257264,
#         0.7891099 , 0.8056471 , 0.8221843 , 0.8387216 , 0.85525876,
#         0.871796  , 0.8883332 , 0.90487045, 0.9214077 , 0.9379449 ,
#         0.95448214], dtype=float32),
#  <BarContainer object of 30 artists>)

# %%
pixel_displacement = ((net.phi_AB_vectorfield.cpu() - net.identityMap.cpu()) 
    * torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None])
plt.imshow(pixel_displacement[0, 2, 40], cmap="rainbow")
plt.colorbar()

# %%
torch.max(torch.abs(pixel_displacement))
# Out:
# tensor(30.6417)

# %%
error = (net.phi_AB(net.phi_BA_vectorfield) - net.identityMap).cpu()* torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None]

# %%
plt.imshow((error)[0, 0, 40])
plt.colorbar()

# %%
torch.sqrt(torch.mean(error**2))
# Out:
# tensor(0.3200)

# %%
plt.rcParams["figure.figsize"]
# Out:
# [6.4, 4.8]

# %%
plt.hist(folds_list, bins=40)
plt.xlabel("number of folded pixels")
plt.ylabel("number of image pairs")
# Out:
# Text(0, 0.5, 'number of image pairs')

# %%
import pickle
with open("../results/grad_hires-1/loss_curve", "rb") as f:
    ncurve2 = pickle.load(f)
ncurve2 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in ncurve2]
ncurve2 = np.array(ncurve2)
plt.plot(ncurve2)


import pickle
with open("../../masked_similarity_InvCon/results/hires_smart_6/loss_curve", "rb") as f:
    curve = pickle.load(f)
curve = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve]
curve = np.array(curve)
plt.plot(curve)


import pickle
with open("../../masked_similarity_InvCon/results/fourth_net_frozen/loss_curve", "rb") as f:
    curve4 = pickle.load(f)
curve4 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve4]
curve4 = np.array(curve4)
plt.plot(curve4)
# Out:
# [<matplotlib.lines.Line2D at 0x7f85cd214220>,
#  <matplotlib.lines.Line2D at 0x7f86225ae430>,
#  <matplotlib.lines.Line2D at 0x7f8b4770c520>,
#  <matplotlib.lines.Line2D at 0x7f8b4770c970>,
#  <matplotlib.lines.Line2D at 0x7f8b4770ca00>]

# %%
plt.plot(ncurve2[:, 2])

plt.plot(curve[:, 2])

plt.plot(curve4[:, 2])

# %%
plt.plot(ncurve2[:, 1])


plt.plot(curve[:, 1])

plt.plot(curve4[:, 1])

# %%
plt.plot(ncurve2[:, 3])


plt.plot(curve[:, 3])
