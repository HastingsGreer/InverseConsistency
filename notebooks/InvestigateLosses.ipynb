# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "0"
import torch

# %%
import functools

@functools.lru_cache(50)
def losses(path):
    try:
        with open(path + "/loss_curve", "rb") as f:
            l = np.array(pickle.load(f))
        return l[:]
    except:
        with open(path + "/loss.pickle", "rb") as f:
            l = np.array(pickle.load(f ))
        return l[:]

# %%
ipmort torch
with open("../results/medrestrain_longtime_3090/loss_curve", "rb") as f:
    loss = pickle.load(f)
# Out:
#   File "<ipython-input-3-c1b0b89f4955>", line 1
#     ipmort torch
#                ^
# SyntaxError: invalid syntax

# %%
plt.plot(np.array(loss)[:, :2])

# %%
plt.plot(np.array(loss)[:, 2])

# %%
plt.plot(np.sum(np.reshape(np.array(loss)[:35700, 2], [-1, 20]), axis=1))

# %%
fnames = [
    "../results/BNE_parallel_batchnorm/",
    "../results/BNE_parallel_groupnorm/",
    "../results/BNE_parallel_none/",

    "../results/BNE_sequential_groupnorm_correct/",
    "../results/BNE_sequential_none_correct/",
        "../results/BNE_sequential_batchnorm_correct/",
    "../results/BNE_parallel_none_1x1s/",
    "../results/BNE_parallel_batchnorm_1x1s/",
   # "../results/BNE_parallel_none_3x3/"
    
]
curves = []
for f in fnames:
    with open(f + "loss.pickle", "rb") as ff:
        curves.append(pickle.load(ff))

# %%
for c, name in zip(curves, fnames):
    curve = c[:, 2]
    curve = curve.reshape(-1, 50)
    curve = np.sum(curve, axis=1) / 50
    plt.plot(curve, label=name[15:], alpha=.9)
plt.legend()

# %%
plt.rcParams["figure.figsize"] = (6,6)

# %%
c.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-d6049491b182> in <module>
# ----> 1 c.shape
#
# NameError: name 'c' is not defined

# %%
with open("../results/ttsplit_affine//loss_curve", "rb") as f:
    loss = np.array(pickle.load(f))
with open("../results/affine_knee_lambdaserver_2/loss_curve", "rb") as f:
    loss2 = np.array(pickle.load(f))

# %%
plt.plot(loss[170:, 1], label="new")
plt.plot(loss2[170:, 1], label="old")
plt.legend()
plt.show()
plt.plot(loss[170:, 2])
plt.plot(loss2[170:, 2])
plt.show()
plt.plot(loss[170:, 0])
plt.plot(loss2[170:, 0])
plt.show()

# %%
plt.plot(loss[170:, 1])
plt.show()
plt.plot(loss[170:, 2])
plt.show()
plt.plot(loss[170:, 0])
plt.show()

# %%
plt.scatter(loss[67000:, 1], loss[67000:, 2], s=.01)

# %%
with open("../results/aff_def_knee7//loss_curve", "rb") as f:
    loss = np.array(pickle.load(f))

# %%
plt.plot(loss[:, 1])
#plt.plot([0])

# %%
loss
# Out:
# array([[0.00425212, 0.03397997, 0.22389439],
#        [0.00083435, 0.03434465, 0.19692555],
#        [0.00100178, 0.03501555, 0.21627335],
#        ...,
#        [0.00209434, 0.02244991, 0.17105833],
#        [0.00188519, 0.02151021, 0.15152051],
#        [0.00198656, 0.02147093, 0.15798444]])

# %%
with open("../results/aff_aff_def_knee_frozen_affine/loss_curve", "rb") as f:
    loss2 = np.array(pickle.load(f))

# %%
plt.plot(loss[:, 1])
plt.plot(loss2[:, 1])

# %%
with open("../results/ttsplit_affine_deformable2/loss_curve", "rb") as f:
    l = np.array(pickle.load(f))

# %%
plt.plot(l[:, 1])

# %%
#losses("../results/ttsplit_affine4//")
j = 1

plt.plot(losses("../../results_InverseConsistency_pre_refactor/affine_knee_lambdaserver_2/")[:, j])
#plt.plot(losses("../../results_InverseConsistency_pre_refactor/ttsplit_affine/")[:, j])
#plt.plot(losses("../../results_InverseConsistency_pre_refactor/ttsplit_affine_lambda20/")[:, j])

plt.plot(losses("../../results_InverseConsistency_pre_refactor/affine_knee_double_stumpy10/")[:, j])

plt.plot(losses("../results/affine_knee_pretrain_2/")[:, j])
plt.grid()

# %%
j = 2

plt.plot(losses("../../results_InverseConsistency_pre_refactor/affine_knee_lambdaserver_2/")[:, j] / 100)
#plt.plot(losses("../../results_InverseConsistency_pre_refactor/ttsplit_affine/")[:, j])
#plt.plot(losses("../../results_InverseConsistency_pre_refactor/ttsplit_affine_lambda20/")[:, j])

plt.plot(losses("../../results_InverseConsistency_pre_refactor/affine_knee_double_stumpy10/")[:, j] / 100)

plt.plot(losses("../results/affine_knee_pretrain_2/")[:, j])
plt.grid()

# %%
j = 1

plt.plot(losses("../results/affine_knee_lambdaserver_2/")[:, j])

plt.plot(losses("../results/ttsplit_affine_lambda20/")[:, j])

plt.plot(losses("../results/tts_affine_centered2/")[:, j])

#plt.plot(losses("../results/tts_cropped_similarity/")[:, j])
plt.plot(losses("../results/affine_knee_double6/")[:, j])
plt.plot(losses("../results/affine_knee_double_shared2/")[:, j])

plt.plot(losses("../results/affine_knee_double_stumpy10/")[:, j])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e8167167cc4c> in losses(path)
#       2     try:
# ----> 3         with open(path + "/loss_curve", "rb") as f:
#       4             l = np.array(pickle.load(f ))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/affine_knee_lambdaserver_2//loss_curve'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-88-97899bf44fd2> in <module>
#       1 j = 1
#       2
# ----> 3 plt.plot(losses("../results/affine_knee_lambdaserver_2/")[:, j])
#       4
#       5 plt.plot(losses("../results/ttsplit_affine_lambda20/")[:, j])
#
# <ipython-input-3-e8167167cc4c> in losses(path)
#       5         return l[:]
#       6     except:
# ----> 7         with open(path + "/loss.pickle", "rb") as f:
# ...

# %%
j = 2

plt.plot(losses("../results/affine_knee_lambdaserver_2/")[:, j])

plt.plot(losses("../results/ttsplit_affine_lambda20/")[:, j] * 5)

plt.plot(losses("../results/tts_affine_centered/")[:, j] * 5)

plt.plot(losses("../results/affine_knee_double6/")[:, j])

plt.plot(losses("../results/affine_knee_double_shared2/")[:, j])

plt.plot(losses("../results/affine_knee_double_stumpy10/")[:, j])
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-e8167167cc4c> in losses(path)
#       2     try:
# ----> 3         with open(path + "/loss_curve", "rb") as f:
#       4             l = np.array(pickle.load(f ))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/affine_knee_lambdaserver_2//loss_curve'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c1a479a4b0e7> in <module>
#       1 j = 2
#       2
# ----> 3 plt.plot(losses("../results/affine_knee_lambdaserver_2/")[:, j])
#       4
#       5 plt.plot(losses("../results/ttsplit_affine_lambda20/")[:, j] * 5)
#
# <ipython-input-3-e8167167cc4c> in losses(path)
#       5         return l[:]
#       6     except:
# ----> 7         with open(path + "/loss.pickle", "rb") as f:
# ...

# %%
np.mean(losses("../results/affine_knee_double_stumpy10")[-60:, 1])
# Out:
# 0.03356411202500264

# %%
np.mean(losses("../results/affine_knee_lambdaserver_2")[-60:, 1])
# Out:
# 0.03318216459204753

# %%
np.mean(losses("../results/ttsplit_affine_lambda20")[-60:, 1])
# Out:
# 0.03544177530954282

# %%
j = 1
plt.plot(losses("../results/double_deformable_triangles/")[:, j], label="Double Step")
plt.plot(losses("../results/plain_hollow_deformable_triangles.py/")[:, j], label="Single Step")
#plt.plot(losses("../results/hollow_triangles_test/")[:9000, j])
plt.grid()
plt.legend()

# %%
j = 1

last = 3000000

plt.plot(losses("../../results_InverseConsistency_pre_refactor/aff_aff_def_knee_frozen_affine/")[:last, j] / (100 if j != 1 else 1))
plt.plot(losses("../results/affine_deformable_knee_nopretrain3/")[:last, j])
#plt.plot(losses("../../results_InverseConsistency_pre_refactor/knee_chunky_middle_7/")[:last, j])

plt.plot(losses("../results/double_deformable_knee3/")[:last, j])
plt.plot(losses("../results/dd_knee_l400_continue_smallbatch2/")[:last, j])
plt.plot(losses("../results/dd_l400_continue_rescalegrad2//")[:last, j])

plt.grid()

# %%
losses("../results/double_deformable_knee3/")[:, j]
# Out:
# array([3.95997886e-05, 5.13745872e-05, 3.77559627e-05, ...,
#        2.07334688e-05, 2.16208209e-05, 1.95909561e-05])

# %%
plt.plot(losses("../../results_InverseConsistency_pre_refactor/knee_chunky_middle_7/")[:last, j])

# %%
losses("../results/double_deformable_knee_lambda400/")
# Out:
# array([[8.53240199e-05, 4.50216830e-02, 1.06655025e-05]])

# %%
j = 1
plt.plot(losses("../results/dd_l400_continue_rescalegrad2//")[:, j])

# %%
plt.plot(losses("../results/hires_finetune7/")[:, 0])

# %%
for j in range(3):
    plt.plot(losses("../results/dd_l400_continue_rescalegrad2/")[:, j])
    plt.show()

# %%
for j in range(3):
    plt.plot(losses("../results/knees_l400_hires_ramp_lmbda4/")[:, j])
    plt.show()

# %%
for j in range(3):
    plt.plot(losses("../results/hires_rmplmbs5/")[:, j])
    plt.show()

# %%
8

# %%
9
# Out:
# 9

# %%
for j in range(3):
    plt.plot(losses("../results/just_upsample_3/")[200:, j])
    plt.show()

# %%
for j in range(3):
    plt.plot(losses("../results/hires_ncc_165k")[:, j])
    plt.scatter([1100], [0.0000043])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-eb65e53f5990> in losses(path)
#       2     try:
# ----> 3         with open(path + "/loss_curve", "rb") as f:
#       4             l = np.array(pickle.load(f))
#
# FileNotFoundError: [Errno 2] No such file or directory: '../results/hires_ncc_165k/loss_curve'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-73f47ce3a984> in <module>
#       1 for j in range(3):
# ----> 2     plt.plot(losses("../results/hires_ncc_165k")[:, j])
#       3     plt.scatter([1100], [0.0000043])
#       4     plt.show()
#
# <ipython-input-4-eb65e53f5990> in losses(path)
#       5         return l[:]
#       6     except:
# ----> 7         with open(path + "/loss.pickle", "rb") as f:
# ...

# %%
7
# Out:
# 7

# %%
8

# %%
for j in range(3):
    plt.plot(losses("../results/just_upsample_3/")[:, j])
    plt.show()

# %%
for j in range(3):
    plt.plot(losses("../results/hires_frozen_lowres_3/")[200:, j])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dcea85ef41cf> in <module>
#       1 for j in range(3):
# ----> 2     plt.plot(losses("../results/hires_frozen_lowres_3/")[200:, j])
#       3     plt.show()
#
# NameError: name 'plt' is not defined

# %%
for j in list(range(3)) + [4]:
    plt.plot(losses("../../masked_similarity_InvCon/results/smart_lmbda_4//")[:, j])
    plt.plot(losses("../../masked_similarity_InvCon/results/noisy_inverse_consistency.pyt//")[:, j])
    plt.plot(losses("../../masked_similarity_InvCon/results/blurred_input_ddk_lowres/")[:, j])
    plt.xlabel("Training Step")
    plt.ylabel(["Inverse Consistency Loss", "Similarity Loss", "Transform Magnitude", "Folds", "lambda"][j])
    #plt.plot(losses("../results/double_deformable_knee3/")[:15000, j])
    plt.yticks
    plt.grid()
    plt.show()

# %%
for j in list(range(3)) + [4]:
    plt.plot(losses("../../masked_similarity_InvCon/results/fourth_net_frozen/")[:, j])
    #plt.plot(losses("../results/hires_frozen_lowres_3/")[:6000, j])
    #plt.plot(losses("../../masked_similarity_InvCon/results/hires_smart_6/")[:, j])
    #plt.plot(losses("../../masked_similarity_InvCon/results/hires_blur3/")[:, j])
    plt.xlabel("Training Step")
    plt.ylabel(["Inverse Consistency Loss", "Similarity Loss", "Transform Magnitude", "Folds", "lambda"][j])
    #plt.plot(losses("../../masked_similarity_InvCon/results/hires_smartlmbda_5/")[:, j])

    plt.yticks
    plt.grid()
    plt.show()

# %%
plt.plot(losses("../../masked_similarity_InvCon/results/hires_smart_6/")[:, 4])

# %%
net.input_shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-9ddde98f6c0a> in <module>
# ----> 1 net.input_shape
#
# NameError: name 'net' is not defined

# %%
plt.plot(losses("../results/fc_knee_12/")[:,1])

# %%
plt.plot(losses("../results/fc_knee_1gpu//")[:,2])

# %%
plt.plot(losses("../results/fc_smol_knee/")[:,2])
plt.plot(losses("../results/fc_smol_l70_2//")[:,2])
plt.grid()

# %%
plt.plot(losses("../results/fc_smol_4gpu/")[:,1])
plt.grid()

# %%
import os
os.popen("ntop")

# %%
import parent
import torch

#volume = torch.load("/playpen/tgreer/knees_big_train_set")
volume = torch.load("/playpen/tgreer/knees_big_2xdownsample_train_set")

# %%
volume[0].shape
# Out:
# torch.Size([1, 1, 80, 192, 192])

# %%
x = torch.nn.Conv3d(1, 1, 3, padding=1, padding_mode="replicate")



torch.nn.init.zeros_(x.bias)

with torch.no_grad():
    x.weight[:] = torch.tensor(np.array(
              [[[[[1, 2, 1],
                  [2, 4, 2],
                  [1, 2, 1]],
                 [[2, 4, 2],
                  [4, 8, 4],
                  [2, 4, 2]],
                 [[1, 2, 1],
                  [2, 4, 2],
                  [1, 2, 1]]]]], dtype=np.float32)) / 64

# %%
x(volume[0]).shape
# Out:
# torch.Size([1, 1, 80, 192, 192])

# %%
volume[0].shape
# Out:
# torch.Size([1, 1, 40, 96, 96])

# %%
import matplotlib.pyplot as plt
plt.imshow(volume[0][0, 0, 20])

# %%
plt.imshow(x(volume[0]).detach()[0, 0, 20])

# %%
blurred = [x(v).detach() for v in volume]

# %%
torch.save(blurred, "/playpen/tgreer/blurred_med_knees")

# %%
# Out:
# tensor([[[[[ 0.0029,  0.0049,  0.0062,  ...,  0.0067,  0.0053,  0.0031],
#            [ 0.0166,  0.0192,  0.0189,  ...,  0.0185,  0.0164,  0.0141],
#            [ 0.0337,  0.0331,  0.0259,  ...,  0.0218,  0.0220,  0.0255],
#            ...,
#            [ 0.0348,  0.0287,  0.0278,  ...,  0.1189,  0.0705,  0.0345],
#            [ 0.0246,  0.0278,  0.0326,  ...,  0.0936,  0.0666,  0.0336],
#            [ 0.0079,  0.0114,  0.0144,  ...,  0.0283,  0.0226,  0.0119]],
#
#           [[ 0.0038,  0.0056,  0.0065,  ...,  0.0064,  0.0056,  0.0038],
#            [ 0.0189,  0.0206,  0.0198,  ...,  0.0180,  0.0179,  0.0180],
#            [ 0.0379,  0.0344,  0.0271,  ...,  0.0216,  0.0247,  0.0323],
#            ...,
#            [ 0.0395,  0.0317,  0.0290,  ...,  0.1350,  0.1115,  0.0694],
#            [ 0.0329,  0.0351,  0.0378,  ...,  0.0930,  0.0908,  0.0601],
#            [ 0.0118,  0.0150,  0.0171,  ...,  0.0274,  0.0283,  0.0193]],
#
# ...
