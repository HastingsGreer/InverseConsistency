# %%
# !ntop
# Out:
# Tue Oct  4 12:14:10 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:3B:00.0 Off |                  N/A |
# | 30%   27C    P8     1W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:5E:00.0 Off |                  N/A |
# | 31%   38C    P8    20W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:B1:00.0 Off |                  N/A |
# | 32%   28C    P8    21W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  On   | 00000000:D9:00.0 Off |                  N/A |
# | 30%   27C    P8     3W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | No running processes found                                                  |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

# %%
from collections import OrderedDict
import torch.nn.functional as F
from icon_registration.mermaidlite import compute_warped_image_multiNC, identity_map_multiN
import torch
import random
import icon_registration.inverseConsistentNet as inverseConsistentNet
import icon_registration.network_wrappers as network_wrappers
import icon_registration.data as data
import numpy as np
import matplotlib.pyplot as plt
import icon_registration.networks as networks


import itk
# Out:
# /playpen-raid1/tgreer/ICON/src/icon_registration/inverseConsistentNet.py:3: UserWarning: inverseConsistentNet.py is deprecated, its code has been moved to losses.py
#         In a future release this file may be deleted.
#   warnings.warn(

# %%
r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#batched_ds = list(zip(*[r_ds[i::4] for i in range(2)]))

# %%
batched_ds = list(zip(*[r_ds[i::2] for i in range(2)]))

# %%
import random
import torch

import footsteps

import icon_registration as icon
import icon_registration.networks as networks


SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [1, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

def make_network():
    inner_net = icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))

    for _ in range(2):
         inner_net = icon.TwoStepRegistration(
             icon.DownsampleRegistration(inner_net, dimension=3),
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )

    net = icon.GradientICON(inner_net, icon.ssd_only_interpolated, lmbda=.5)
    net.assign_identity_map(input_shape)
    return net

net = make_network()

trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/end2endlmbda.2/network_weights_68400")
#trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/q-9/network_weights_17700")


net.regis_net.load_state_dict(trained_weights)


0
# Out:
# 0

# %%
import random
import torch

import footsteps

import icon_registration as icon
import icon_registration.networks as networks


SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [1, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

def make_network():
    inner_net = icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))

    for _ in range(2):
         inner_net = icon.TwoStepRegistration(
             icon.DownsampleRegistration(inner_net, dimension=3),
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )
    inner_net = icon.TwoStepRegistration(
             inner_net,
             icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))
         )

    net = icon.GradientICON(inner_net, icon.ssd_only_interpolated, lmbda=.2)
    net.assign_identity_map(input_shape)
    return net

net = make_network()

trained_weights = torch.load(
    "/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/ent2end_thenonemore-7/network_weights_25200")
#trained_weights = torch.load("/playpen-raid1/tgreer/ICON/training_scripts/gradICON/results/q-9/network_weights_17700")


net.regis_net.load_state_dict(trained_weights)
# Out:
# <All keys matched successfully>

# %%
# !ntop
# Out:
# Tue Oct  4 14:17:17 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 208...  On   | 00000000:3B:00.0 Off |                  N/A |
# | 30%   25C    P8     1W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 208...  On   | 00000000:5E:00.0 Off |                  N/A |
# | 32%   31C    P2    63W / 250W |   7118MiB / 11019MiB |      4%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 208...  On   | 00000000:B1:00.0 Off |                  N/A |
# | 31%   27C    P8    20W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 208...  On   | 00000000:D9:00.0 Off |                  N/A |
# | 30%   26C    P8     3W / 250W |      1MiB / 11019MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# |  GPU   PID     USER    GPU MEM  %CPU  %MEM      TIME  COMMAND               |
# |    1 25034   tgreer    7115MiB   4.7  18.9  02:03:20  /playpen-raid1/tgree  |
# +-----------------------------------------------------------------------------+

# %%
BATCH_SIZE = 2
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [BATCH_SIZE, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

net.assign_identity_map(input_shape)

# %%
net.cuda()
net.eval()
# Out:
# GradientICON(
#   (regis_net): TwoStepRegistration(
#     (netPhi): TwoStepRegistration(
#       (netPhi): DownsampleRegistration(
#         (net): TwoStepRegistration(
#           (netPhi): DownsampleRegistration(
#             (net): FunctionFromVectorField(
#               (net): UNet2(
#                 (downConvs): ModuleList(
#                   (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 )
#                 (upConvs): ModuleList(
#                   (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                   (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 )
#                 (batchNorms): ModuleList(
#                   (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                   (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 )
#                 (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#               )
#             )
#           )
#           (netPsi): FunctionFromVectorField(
#             (net): UNet2(
#               (downConvs): ModuleList(
#                 (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#               )
#               (upConvs): ModuleList(
#                 (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#                 (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#               )
#               (batchNorms): ModuleList(
#                 (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#                 (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#               )
#               (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#             )
#           )
#         )
#       )
#       (netPsi): FunctionFromVectorField(
#         (net): UNet2(
#           (downConvs): ModuleList(
#             (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#             (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           )
#           (upConvs): ModuleList(
#             (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#             (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           )
#           (batchNorms): ModuleList(
#             (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           )
#           (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#         )
#       )
#     )
#     (netPsi): FunctionFromVectorField(
#       (net): UNet2(
#         (downConvs): ModuleList(
#           (0): Conv3d(2, 16, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (1): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (2): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (3): Conv3d(64, 256, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#           (4): Conv3d(256, 512, kernel_size=(3, 3, 3), stride=(2, 2, 2), padding=(1, 1, 1))
#         )
#         (upConvs): ModuleList(
#           (0): ConvTranspose3d(48, 16, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (1): ConvTranspose3d(96, 32, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (2): ConvTranspose3d(192, 64, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (3): ConvTranspose3d(512, 128, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#           (4): ConvTranspose3d(512, 256, kernel_size=(4, 4, 4), stride=(2, 2, 2), padding=(1, 1, 1))
#         )
#         (batchNorms): ModuleList(
#           (0): BatchNorm3d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (1): BatchNorm3d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (3): BatchNorm3d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (4): BatchNorm3d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#         (lastConv): Conv3d(18, 3, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#       )
#     )
#   )
# )

# %%
import icon_registration

# %%
0
# Out:
# 0

# %%
def flips(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True)
    return torch.sum(dV < 0)# / BATCH_SIZE
def flips2(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True) / np.product(net.spacing)
    return dV.detach().cpu()
with torch.no_grad():
    dices = ([], [])
    folds_list = []
    
    filteredDV_list = []
    
    mag = []
    
    
    for x in batched_ds[:]:
        x = list(zip(*x))
        x = [torch.cat(r, 0).cuda().float() for r in x]
        fixed_image, fixed_cartilage = x[1], x[3]
        moving_image, moving_cartilage = x[0], x[2]

        l = icon_registration.losses.to_floats(net(moving_image, fixed_image))
        mag.append(l.transform_magnitude)
        phi_AB_vectorfield = net.phi_AB(net.identity_map)
        fat_phi = torch.nn.Upsample(size=moving_cartilage.size()[2:], mode="trilinear")(phi_AB_vectorfield[:, :3])
        sz = np.array(fat_phi.size())
        spacing = 1./(sz[2::]-1) 
        warped_moving_cartilage = compute_warped_image_multiNC(moving_cartilage.float(), fat_phi, spacing, 0)
        
        #fixed_cartilage = torch.nn.
        for label in range(2):
            wmb = torch.round(warped_moving_cartilage) == label + 1
            fb = torch.round(fixed_cartilage) == label + 1
            intersection = wmb * fb
            d = 2 * torch.sum(intersection, [1,2,3,4]).float() / (torch.sum(wmb, [1,2,3,4]) + torch.sum(fb, [1,2,3,4]))
            print(d)
            dices[label].append(d)
        f = flips(phi_AB_vectorfield[:1])
        print(f)
        folds_list.append(f.item())
        f = flips(phi_AB_vectorfield[1:])
        print(f)
        folds_list.append(f.item())
        
        dV = flips2(phi_AB_vectorfield)
        
        dV = np.array(dV).flatten()
        dV = dV[dV < 0]
        filteredDV_list.append(dV)
        
    dd = torch.mean(torch.cat(dices[0] + dices[1]).cpu())
    print(dd)
    ff = np.mean(folds_list)
    print(ff)
    
    print("mag", sum(mag) / len(mag))
# Out:
# tensor([0.6810, 0.7556], device='cuda:0')
# tensor([0.7414, 0.7531], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(14, device='cuda:0')
# tensor([0.7490, 0.6648], device='cuda:0')
# tensor([0.7254, 0.6445], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6737, 0.6742], device='cuda:0')
# tensor([0.6763, 0.5922], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7492, 0.6903], device='cuda:0')
# tensor([0.8089, 0.7077], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6944, 0.7673], device='cuda:0')
# tensor([0.7094, 0.7235], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7347, 0.7779], device='cuda:0')
# tensor([0.6345, 0.7498], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(17, device='cuda:0')
# tensor([0.7522, 0.5874], device='cuda:0')
# tensor([0.7217, 0.6732], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6482, 0.7644], device='cuda:0')
# tensor([0.7279, 0.7699], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7155, 0.7360], device='cuda:0')
# tensor([0.6734, 0.7172], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6773, 0.7242], device='cuda:0')
# tensor([0.7636, 0.7338], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7048, 0.7211], device='cuda:0')
# tensor([0.6444, 0.7598], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6828, 0.6523], device='cuda:0')
# tensor([0.7266, 0.6655], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7052, 0.6886], device='cuda:0')
# tensor([0.7213, 0.7464], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6661, 0.7017], device='cuda:0')
# tensor([0.7326, 0.7252], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7103, 0.7213], device='cuda:0')
# tensor([0.6837, 0.7485], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6861, 0.7856], device='cuda:0')
# tensor([0.6923, 0.7791], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7688, 0.7370], device='cuda:0')
# tensor([0.7660, 0.6590], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.5735, 0.6857], device='cuda:0')
# tensor([0.6453, 0.6880], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7610, 0.6705], device='cuda:0')
# tensor([0.7434, 0.6120], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7822, 0.7896], device='cuda:0')
# tensor([0.7739, 0.7650], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7203, 0.7643], device='cuda:0')
# tensor([0.7742, 0.7238], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6271, 0.6683], device='cuda:0')
# tensor([0.6111, 0.7659], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6857, 0.6745], device='cuda:0')
# tensor([0.7003, 0.6796], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7388, 0.7490], device='cuda:0')
# tensor([0.6904, 0.7029], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7070, 0.6466], device='cuda:0')
# tensor([0.7144, 0.6893], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6247, 0.7983], device='cuda:0')
# tensor([0.5141, 0.7805], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7018, 0.6381], device='cuda:0')
# tensor([0.6559, 0.6550], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7320, 0.7044], device='cuda:0')
# tensor([0.7481, 0.6600], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6769, 0.7172], device='cuda:0')
# tensor([0.6818, 0.6880], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6642, 0.6774], device='cuda:0')
# tensor([0.6845, 0.6953], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7591, 0.7529], device='cuda:0')
# tensor([0.7892, 0.7679], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7410, 0.6221], device='cuda:0')
# tensor([0.6729, 0.7049], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7789, 0.7473], device='cuda:0')
# tensor([0.8130, 0.7580], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7048, 0.7509], device='cuda:0')
# tensor([0.7957, 0.7222], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6774, 0.7197], device='cuda:0')
# tensor([0.6698, 0.7142], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7176, 0.7442], device='cuda:0')
# tensor([0.6998, 0.7018], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7698, 0.7195], device='cuda:0')
# tensor([0.7071, 0.7160], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7075, 0.7046], device='cuda:0')
# tensor([0.7246, 0.7355], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7618, 0.7023], device='cuda:0')
# tensor([0.7498, 0.7237], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7816, 0.7101], device='cuda:0')
# tensor([0.7822, 0.7254], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7367, 0.7164], device='cuda:0')
# tensor([0.7365, 0.7605], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6376, 0.6644], device='cuda:0')
# tensor([0.5670, 0.6282], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6750, 0.6939], device='cuda:0')
# tensor([0.6298, 0.7215], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7180, 0.6961], device='cuda:0')
# tensor([0.6317, 0.7642], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.6627, 0.7187], device='cuda:0')
# tensor([0.7450, 0.6816], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7735, 0.7004], device='cuda:0')
# tensor([0.7188, 0.6501], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7619, 0.7493], device='cuda:0')
# tensor([0.7254, 0.6572], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6686, 0.7102], device='cuda:0')
# tensor([0.6798, 0.7098], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6522, 0.7455], device='cuda:0')
# tensor([0.7125, 0.7794], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6245, 0.6867], device='cuda:0')
# tensor([0.6481, 0.7756], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7446, 0.7391], device='cuda:0')
# tensor([0.7172, 0.7442], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(5, device='cuda:0')
# tensor([0.7170, 0.7446], device='cuda:0')
# tensor([0.7454, 0.7409], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7022, 0.7512], device='cuda:0')
# tensor([0.7171, 0.6992], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7206, 0.7594], device='cuda:0')
# tensor([0.7305, 0.7191], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6309, 0.6915], device='cuda:0')
# tensor([0.5077, 0.6943], device='cuda:0')
# tensor(8, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7914, 0.7187], device='cuda:0')
# tensor([0.7317, 0.6816], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6594, 0.7422], device='cuda:0')
# tensor([0.6420, 0.7214], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7633, 0.7106], device='cuda:0')
# tensor([0.7304, 0.7716], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6480, 0.6032], device='cuda:0')
# tensor([0.6635, 0.5708], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7365, 0.6607], device='cuda:0')
# tensor([0.7482, 0.7848], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7547, 0.7622], device='cuda:0')
# tensor([0.6847, 0.7614], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6819, 0.6265], device='cuda:0')
# tensor([0.6833, 0.6248], device='cuda:0')
# tensor(42, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6717, 0.7017], device='cuda:0')
# tensor([0.7172, 0.7213], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6160, 0.7103], device='cuda:0')
# tensor([0.6375, 0.7098], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(1, device='cuda:0')
# tensor([0.6962, 0.6668], device='cuda:0')
# tensor([0.6775, 0.7095], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.6955, 0.6451], device='cuda:0')
# tensor([0.7302, 0.6427], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7437, 0.7497], device='cuda:0')
# tensor([0.7129, 0.7573], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7367, 0.7191], device='cuda:0')
# tensor([0.7242, 0.7469], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7358, 0.6916], device='cuda:0')
# tensor([0.7351, 0.7343], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7439, 0.6797], device='cuda:0')
# tensor([0.6626, 0.7168], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7210, 0.7148], device='cuda:0')
# tensor([0.7466, 0.7938], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7305, 0.7855], device='cuda:0')
# tensor([0.6412, 0.8108], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6937, 0.7119], device='cuda:0')
# tensor([0.6972, 0.7301], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(2, device='cuda:0')
# tensor([0.7273, 0.6870], device='cuda:0')
# tensor([0.7136, 0.7291], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7362, 0.7502], device='cuda:0')
# tensor([0.7650, 0.7641], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7006, 0.7059], device='cuda:0')
# tensor([0.7376, 0.7338], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7282, 0.7580], device='cuda:0')
# tensor([0.7041, 0.7833], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6398, 0.7047], device='cuda:0')
# tensor([0.7381, 0.7581], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7697, 0.7395], device='cuda:0')
# tensor([0.6789, 0.7423], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7328, 0.6737], device='cuda:0')
# tensor([0.7122, 0.6640], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6136, 0.6967], device='cuda:0')
# tensor([0.6527, 0.7331], device='cuda:0')
# tensor(21, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7264, 0.7532], device='cuda:0')
# tensor([0.7382, 0.7627], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7231, 0.7217], device='cuda:0')
# tensor([0.6749, 0.7095], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6487, 0.6269], device='cuda:0')
# tensor([0.6383, 0.6569], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7342, 0.7354], device='cuda:0')
# tensor([0.6848, 0.7284], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7185, 0.7320], device='cuda:0')
# tensor([0.7254, 0.7223], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7334, 0.7759], device='cuda:0')
# tensor([0.8310, 0.6768], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6836, 0.7076], device='cuda:0')
# tensor([0.6341, 0.7869], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7399, 0.7370], device='cuda:0')
# tensor([0.6728, 0.6590], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7400, 0.7497], device='cuda:0')
# tensor([0.6436, 0.7537], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7174, 0.7390], device='cuda:0')
# tensor([0.6895, 0.6712], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6993, 0.7137], device='cuda:0')
# tensor([0.6748, 0.7096], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6721, 0.7501], device='cuda:0')
# tensor([0.6161, 0.7893], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6680, 0.7411], device='cuda:0')
# tensor([0.7242, 0.6421], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7410, 0.5791], device='cuda:0')
# tensor([0.7140, 0.5940], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7100, 0.7399], device='cuda:0')
# tensor([0.6958, 0.6768], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7771, 0.6831], device='cuda:0')
# tensor([0.7531, 0.6188], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7054, 0.6860], device='cuda:0')
# tensor([0.7592, 0.6993], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6761, 0.7678], device='cuda:0')
# tensor([0.6810, 0.6738], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7539, 0.6683], device='cuda:0')
# tensor([0.6753, 0.5754], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7464, 0.6938], device='cuda:0')
# tensor([0.6908, 0.7095], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6489, 0.6660], device='cuda:0')
# tensor([0.6810, 0.6319], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8421, 0.7951], device='cuda:0')
# tensor([0.8501, 0.8367], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6247, 0.7666], device='cuda:0')
# tensor([0.6229, 0.7265], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6644, 0.7653], device='cuda:0')
# tensor([0.7400, 0.7604], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8217, 0.7557], device='cuda:0')
# tensor([0.7975, 0.7210], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7451, 0.8607], device='cuda:0')
# tensor([0.7302, 0.8058], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7328, 0.5930], device='cuda:0')
# tensor([0.7659, 0.6121], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7400, 0.6559], device='cuda:0')
# tensor([0.7080, 0.6941], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6924, 0.6869], device='cuda:0')
# tensor([0.6090, 0.7034], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7232, 0.7533], device='cuda:0')
# tensor([0.7286, 0.7426], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6415, 0.7434], device='cuda:0')
# tensor([0.7080, 0.7375], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7530, 0.7352], device='cuda:0')
# tensor([0.7597, 0.7456], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7609, 0.7370], device='cuda:0')
# tensor([0.7495, 0.6493], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6528, 0.7589], device='cuda:0')
# tensor([0.5620, 0.7719], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.6774, 0.7220], device='cuda:0')
# tensor([0.6680, 0.6988], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7031, 0.7865], device='cuda:0')
# tensor([0.7035, 0.6602], device='cuda:0')
# tensor(2, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6777, 0.7423], device='cuda:0')
# tensor([0.6519, 0.6708], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7446, 0.7113], device='cuda:0')
# tensor([0.7100, 0.7136], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6240, 0.6111], device='cuda:0')
# tensor([0.6829, 0.7298], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7142, 0.7198], device='cuda:0')
# tensor([0.7673, 0.7546], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6794, 0.6739], device='cuda:0')
# tensor([0.6586, 0.5944], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6440, 0.7419], device='cuda:0')
# tensor([0.6299, 0.6971], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6468, 0.7366], device='cuda:0')
# tensor([0.6686, 0.7713], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.9725, 0.7345], device='cuda:0')
# tensor([0.9752, 0.7521], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7370, 0.6896], device='cuda:0')
# tensor([0.7422, 0.7511], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6785, 0.6130], device='cuda:0')
# tensor([0.7191, 0.7233], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7259, 0.7684], device='cuda:0')
# tensor([0.7608, 0.7848], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7489, 0.6679], device='cuda:0')
# tensor([0.7342, 0.6955], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7017, 0.7559], device='cuda:0')
# tensor([0.7946, 0.6863], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6956, 0.6612], device='cuda:0')
# tensor([0.6584, 0.6365], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.7012, 0.6927], device='cuda:0')
# tensor([0.7005, 0.6428], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7529, 0.7616], device='cuda:0')
# tensor([0.7602, 0.6983], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6666, 0.7462], device='cuda:0')
# tensor([0.6761, 0.7005], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6746, 0.7232], device='cuda:0')
# tensor([0.7002, 0.7051], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6816, 0.6810], device='cuda:0')
# tensor([0.7579, 0.7414], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7407, 0.7383], device='cuda:0')
# tensor([0.7274, 0.7007], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7079, 0.6444], device='cuda:0')
# tensor([0.7714, 0.5885], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6890, 0.7309], device='cuda:0')
# tensor([0.7296, 0.7338], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7060, 0.6453], device='cuda:0')
# tensor([0.5973, 0.6035], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7215, 0.7419], device='cuda:0')
# tensor([0.7847, 0.7214], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7559, 0.7590], device='cuda:0')
# tensor([0.7028, 0.7201], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6592, 0.7565], device='cuda:0')
# tensor([0.7323, 0.7234], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7459, 0.7272], device='cuda:0')
# tensor([0.7504, 0.7430], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(6, device='cuda:0')
# tensor([0.7731, 0.6813], device='cuda:0')
# tensor([0.8210, 0.7632], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7086, 0.7012], device='cuda:0')
# tensor([0.7090, 0.7005], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.8059, 0.6615], device='cuda:0')
# tensor([0.8106, 0.6589], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.6770, 0.7226], device='cuda:0')
# tensor([0.7001, 0.7202], device='cuda:0')
# tensor(4, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7189, 0.6556], device='cuda:0')
# tensor([0.7349, 0.6774], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor([0.7066, 0.7253], device='cuda:0')
# tensor([0.6865, 0.7359], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(0.7110)
# 0.5033333333333333
# mag 0.0029779560293536635

# %%
dicesa = np.array(torch.cat(dices[0] + dices[1]).cpu())
plt.hist(dicesa, 20)
plt.xlabel("DICE")
print(np.mean(dicesa))
ff = np.mean(folds_list)
print(ff)
# Out:
# 0.710977
# 0.5033333333333333

# %%
net.cuda()
with torch.no_grad():
    print(net(moving_image, fixed_image))

# %%
if not("N" in locals()):
    N = 0
N += 1
N %= 2
#N = 3
#plt.imshow(fixed_image[N, 0, 10].cpu() - net.warped_image_A[N, 0, 10].cpu().detach())
#plt.show()
plt.rcParams["figure.figsize"] = (5, 5)
def imshow(x):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
slice_ = 40
imshow(fixed_image[N, 0, slice_])
plt.show()
imshow(net.warped_image_A[N, 0, slice_])
plt.show()

plt.imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach() - moving_image[N, 0, slice_ ].cpu().detach())
plt.show()
#plt.imshow(net.regis_net.x_comp_phi[N, 0, slice_].cpu().detach() - moving_image[N, 0, slice_].cpu().detach())
#plt.show()
plt.imshow((fixed_image - moving_image)[N, 0, slice_].cpu().detach())
plt.show()

imshow(moving_image[N, 0, slice_].cpu().detach())
plt.show()

# %%
import matplotlib.pyplot as plt
S = 100
plt.imshow(moving_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(fixed_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(net.warped_image_A[N, 0, :, S].cpu().detach())
plt.show()
plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach())
plt.show()

plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach() - moving_image[N, 0, :, S].cpu())

# %%
S = 49
plt.imshow(moving_cartilage[N, 0, :, S * 4].cpu())
plt.show() 
plt.imshow(warped_moving_cartilage[N, 0, :, S * 4].detach().cpu())
plt.show()

plt.imshow(fixed_cartilage[N, 0, :, S * 4].cpu())
plt.show()

plt.imshow((warped_moving_cartilage[N, 0, :, S * 4].detach().cpu() - fixed_cartilage[N, 0, :, S * 4].cpu()))
plt.show()

# %%
import icon_registration.visualize as visualize
N = (N + 1)% 2
#N = 1
plt.rcParams["figure.figsize"] = 10, 10
visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 40])
plt.show()
visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 40])

# %%
net.phi_AB.__closure__[0].cell_contents

# %%
N = (N + 1) % 2
visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identity_map))[N, [1, 2], 20])

# %%
import visualize
mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
import visualize
mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
visualize.show_as_grid(mp[N, [1, 2], 20])

# %%
mkdir supll_regis_figures

# %%
import importlib
importlib.reload(visualize)
import matplotlib.colors as colors

for N in range(2):

    plt.rcParams["figure.figsize"] = (5, 5)
    def imshow(x):
        plt.xticks([])
        plt.yticks([])
        plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
    offset = 0
    slice_ = 20
    
    for axis in ["Coronal", "Sagittal", "Axial"]:
        m_image = moving_image[N, 0].cpu().detach()
        f_image = fixed_image[N, 0].cpu().detach()
        m_warped_image_A = net.warped_image_A[N, 0].cpu().detach() 
        phi_BA = net.phi_BA_vectorfield[N]
        
        dV = flips2(net.phi_AB_vectorfield)[N, 0]
        
        if axis == "Sagittal":
            m_image_slice = m_image[slice_]
            f_image_slice = f_image[slice_]
            warped_image_A_slice = m_warped_image_A[slice_]
            phi_BA_slice = phi_BA[[1, 2], 20].clone()
            dV_slice = dV[slice_]
        if axis == "Coronal":
            m_image_slice = m_image[:, slice_].transpose(0, 1)
            f_image_slice = f_image[:, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[2, 0], :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, slice_].transpose(0, 1)
        if axis == "Axial":
            slice_ *= 2
            m_image_slice = m_image[:, :, slice_].transpose(0, 1)
            f_image_slice = f_image[:, :, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, :, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[1, 0], :, :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, :, slice_].transpose(0, 1)
            slice_ /= 2
            
            
        
        header = f"supll_regis_figures/{axis}Pair{N + offset}"
        imshow(m_image_slice)
        plt.savefig(header + "ImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(f_image_slice)
        plt.savefig(header + "ImageB.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        plt.savefig(header + "WarpedImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        visualize.show_as_grid(phi_BA_slice)
        plt.savefig(header + "WarpedImageAGrid.png", bbox_inches="tight")
        plt.clf()
        
        plt.xticks([])
        plt.yticks([])
        
        plt.imshow(dV_slice, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
        plt.title("min dV is $\\bf{" + f"{np.min(dV_slice.numpy()):.3}" + "}$ in this slice", 
                 fontdict={'fontsize':13})
        plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
        #lt.show()
        #plt.imshow(dV[1, 0, 40] < 0)


        plt.savefig(header + "dV.png", bbox_inches="tight")
        plt.clf()
    """
    imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach())
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageB.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageBGrid.png")
    plt.clf()
    """

    
    plt.show()

# %%
import importlib
importlib.reload(visualize)

# %%
plt.imshow(torch.min(dV[1, 0], axis=0).values)
plt.colorbar()

# %%
torch.sum(dV[1] < 0)

# %%
dV

# %%
116 / (80 * 192 * 192), 1 / 25000

# %%
import matplotlib.colors as colors

plt.xticks([])
plt.yticks([])
query = dV[0, 0, 43]
plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice", 
         fontdict={'fontsize':13})
plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
#lt.show()
#plt.imshow(dV[1, 0, 40] < 0)


plt.savefig("dVslice0.pdf", bbox_inches="tight")

# %%
2 * np.sum(folds_list) / (np.product(list(dV.shape)) * len(r_ds))

# %%
print("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice")
from matplotlib import rc
rc('text', usetex=False)
np.min(query.numpy())

# %%
adv = np.array(dV)
filteredDV = adv[adv < 0.05]
plt.hist(filteredDV, bins=100)
plt.show()

# %%
plt.hist(np.concatenate(filteredDV_list), bins=100)
plt.title("Distribution of negative dV voxels in test set")
plt.xlabel("dV (in voxels³)")
plt.ylabel("Count")
plt.savefig("DistributionNegativeJacobian.pdf")

# %%
np.mean(np.concatenate(filteredDV_list))

# %%
np.median(np.concatenate(filteredDV_list))

# %%
np.percentile(np.concatenate(filteredDV_list), 1)

# %%
# %time net.regis_net(moving_image, fixed_image)

# %%
with torch.no_grad():
    x = batched_ds[0]
    x = list(zip(*x))
    x = [torch.cat(r, 0).cuda().float() for r in x]
    fixed_image, fixed_cartilage = x[0], x[2]
    moving_image, moving_cartilage = x[1], x[3]

# %%
# %%time
with torch.no_grad():
    phi = net.regis_net(moving_image, fixed_image)
    phi_AB_vectorfield = phi(net.identityMap).cpu()

# %%
# %%time 
net(moving_image, fixed_image)

# %%
plt.hist(torch.cat(dices).cpu().detach().numpy(), bins=30)

# %%
pixel_displacement = ((net.phi_AB_vectorfield.cpu() - net.identityMap.cpu()) 
    * torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None])
plt.imshow(pixel_displacement[0, 2, 40], cmap="rainbow")
plt.colorbar()

# %%
torch.max(torch.abs(pixel_displacement))

# %%
error = (net.phi_AB(net.phi_BA_vectorfield) - net.identityMap).cpu()* torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None]

# %%
plt.imshow((error)[0, 0, 40])
plt.colorbar()

# %%
torch.sqrt(torch.mean(error**2))

# %%
plt.rcParams["figure.figsize"]

# %%
plt.hist(folds_list, bins=40)
plt.xlabel("number of folded pixels")
plt.ylabel("number of image pairs")

# %%
import pickle
with open("../results/grad_hires-1/loss_curve", "rb") as f:
    ncurve2 = pickle.load(f)
ncurve2 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in ncurve2]
ncurve2 = np.array(ncurve2)
plt.plot(ncurve2)


import pickle
with open("../../masked_similarity_InvCon/results/hires_smart_6/loss_curve", "rb") as f:
    curve = pickle.load(f)
curve = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve]
curve = np.array(curve)
plt.plot(curve)


import pickle
with open("../../masked_similarity_InvCon/results/fourth_net_frozen/loss_curve", "rb") as f:
    curve4 = pickle.load(f)
curve4 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve4]
curve4 = np.array(curve4)
plt.plot(curve4)

# %%
plt.plot(ncurve2[:, 2])

plt.plot(curve[:, 2])

plt.plot(curve4[:, 2])

# %%
plt.plot(ncurve2[:, 1])


plt.plot(curve[:, 1])

plt.plot(curve4[:, 1])

# %%
plt.plot(ncurve2[:, 3])


plt.plot(curve[:, 3])
