# %%
import icon_registration.networks as networks
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "3"

# %%
import torch.nn.functional as F
from icon_registration.mermaidlite import compute_warped_image_multiNC
import torch
import random
import icon_registration as icon
import icon_registration.networks as networks

import numpy as np
import matplotlib.pyplot as plt
import itk

# %%
r_ds = torch.load("/playpen/tgreer/knees_test_set_hires")
#batched_ds = list(zip(*[r_ds[i::4] for i in range(2)]))

# %%
batched_ds = list(zip(*[r_ds[i::2] for i in range(2)]))

# %%
phi = icon.FunctionFromVectorField(
    networks.tallUNet(unet=networks.UNet2ChunkyMiddle, dimension=3)
)
psi = icon.FunctionFromVectorField(networks.tallUNet2(dimension=3))

net = icon.TwoStepRegistration(phi, psi)

regis_net = icon.TwoStepRegistration(
    icon.DownsampleRegistration(net, 3), 
    icon.FunctionFromVectorField(networks.tallUNet2(dimension=3)))

BATCH_SIZE = 8
SCALE = 2  # 1 IS QUARTER RES, 2 IS HALF RES, 4 IS FULL RES
input_shape = [1, 1, 40 * SCALE, 96 * SCALE, 96 * SCALE]

net = icon.InverseConsistentNet(
    regis_net, 
    lambda x, y: (x - y) **2,
    3600,
)
    
net.assign_identity_map(input_shape)

trained_weights = torch.load("../training_scripts/gradICON/results/lncc_knees_only_interpolated-2/knee_aligner_resi_net15300")
regis_net.load_state_dict(trained_weights)
# Out:
# <All keys matched successfully>

# %%
net.cuda()
net.eval()
0
# Out:
# 0

# %%
def flips(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True)
    return torch.sum(dV < 0)# / BATCH_SIZE
def flips2(phi):
    a = phi[:, :, 1:, 1:, 1:] - phi[:, :, :-1, 1:, 1:]
    b = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, :-1, 1:]
    c = phi[:, :, 1:, 1:, 1:] - phi[:, :, 1:, 1:, :-1]

    dV = torch.sum(torch.cross(a, b, 1) * c, axis=1, keepdims=True) / np.product(net.spacing)
    return dV.detach().cpu()
with torch.no_grad():
    dices = []
    folds_list = []
    
    filteredDV_list = []
    
    
    for x in batched_ds[:]:
        x = list(zip(*x))
        x = [torch.cat(r, 0).cuda().float() for r in x]
        fixed_image, fixed_cartilage = x[0], x[2]
        moving_image, moving_cartilage = x[1], x[3]

        net(moving_image, fixed_image)
        phi_AB_vectorfield = net.phi_AB(net.identity_map)
        fat_phi = torch.nn.Upsample(size=moving_cartilage.size()[2:], mode="trilinear")(phi_AB_vectorfield[:, :3])
        sz = np.array(fat_phi.size())
        spacing = 1./(sz[2::]-1) 
        warped_moving_cartilage = compute_warped_image_multiNC(moving_cartilage.float(), fat_phi, spacing, 1)
        wmb = warped_moving_cartilage > .5
        fb = fixed_cartilage > .5
        intersection = wmb * fb
        d = 2 * torch.sum(intersection, [1,2,3,4]).float() / (torch.sum(wmb, [1,2,3,4]) + torch.sum(fb, [1,2,3,4]))
        print(d)
        dices.append(d)
        f = flips(phi_AB_vectorfield[:1])
        print(f)
        folds_list.append(f.item())
        f = flips(phi_AB_vectorfield[1:])
        print(f)
        folds_list.append(f.item())
        
        dV = flips2(phi_AB_vectorfield)
        
        dV = np.array(dV).flatten()
        dV = dV[dV < 0]
        filteredDV_list.append(dV)
        
    dd = torch.mean(torch.cat(dices).cpu())
    print(dd)
    ff = np.mean(folds_list)
    print(ff)
# Out:
# Default upsampling behavior when mode=trilinear is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
# tensor([0.7161, 0.7325], device='cuda:0')
# tensor(109, device='cuda:0')
# tensor(147, device='cuda:0')
# tensor([0.7331, 0.6623], device='cuda:0')
# tensor(199, device='cuda:0')
# tensor(54, device='cuda:0')
# tensor([0.6885, 0.6489], device='cuda:0')
# tensor(128, device='cuda:0')
# tensor(42, device='cuda:0')
# tensor([0.7755, 0.6732], device='cuda:0')
# tensor(36, device='cuda:0')
# tensor(100, device='cuda:0')
# tensor([0.7241, 0.7657], device='cuda:0')
# tensor(44, device='cuda:0')
# tensor(36, device='cuda:0')
# tensor([0.7095, 0.7789], device='cuda:0')
# tensor(68, device='cuda:0')
# tensor(83, device='cuda:0')
# tensor([0.7288, 0.6303], device='cuda:0')
# tensor(63, device='cuda:0')
# tensor(57, device='cuda:0')
# tensor([0.6719, 0.7503], device='cuda:0')
# tensor(99, device='cuda:0')
# tensor(102, device='cuda:0')
# tensor([0.6864, 0.7253], device='cuda:0')
# tensor(109, device='cuda:0')
# tensor(120, device='cuda:0')
# tensor([0.6277, 0.7152], device='cuda:0')
# tensor(134, device='cuda:0')
# tensor(108, device='cuda:0')
# tensor([0.6859, 0.7683], device='cuda:0')
# tensor(389, device='cuda:0')
# tensor(9, device='cuda:0')
# tensor([0.6592, 0.5901], device='cuda:0')
# tensor(21, device='cuda:0')
# tensor(254, device='cuda:0')
# tensor([0.6787, 0.7902], device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(118, device='cuda:0')
# tensor([0.7265, 0.7340], device='cuda:0')
# tensor(114, device='cuda:0')
# tensor(50, device='cuda:0')
# tensor([0.7240, 0.7146], device='cuda:0')
# tensor(175, device='cuda:0')
# tensor(77, device='cuda:0')
# tensor([0.6825, 0.7686], device='cuda:0')
# tensor(91, device='cuda:0')
# tensor(33, device='cuda:0')
# tensor([0.7498, 0.7366], device='cuda:0')
# tensor(143, device='cuda:0')
# tensor(238, device='cuda:0')
# tensor([0.5597, 0.6840], device='cuda:0')
# tensor(108, device='cuda:0')
# tensor(181, device='cuda:0')
# tensor([0.7118, 0.6187], device='cuda:0')
# tensor(124, device='cuda:0')
# tensor(195, device='cuda:0')
# tensor([0.7734, 0.7610], device='cuda:0')
# tensor(86, device='cuda:0')
# tensor(25, device='cuda:0')
# tensor([0.6970, 0.7360], device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(180, device='cuda:0')
# tensor([0.6612, 0.6743], device='cuda:0')
# tensor(293, device='cuda:0')
# tensor(158, device='cuda:0')
# tensor([0.6684, 0.6697], device='cuda:0')
# tensor(204, device='cuda:0')
# tensor(241, device='cuda:0')
# tensor([0.7513, 0.7280], device='cuda:0')
# tensor(15, device='cuda:0')
# tensor(144, device='cuda:0')
# tensor([0.7274, 0.5956], device='cuda:0')
# tensor(71, device='cuda:0')
# tensor(125, device='cuda:0')
# tensor([0.5790, 0.7308], device='cuda:0')
# tensor(144, device='cuda:0')
# tensor(187, device='cuda:0')
# tensor([0.6860, 0.6658], device='cuda:0')
# tensor(103, device='cuda:0')
# tensor(164, device='cuda:0')
# tensor([0.7122, 0.7041], device='cuda:0')
# tensor(60, device='cuda:0')
# tensor(269, device='cuda:0')
# tensor([0.6813, 0.7391], device='cuda:0')
# tensor(127, device='cuda:0')
# tensor(100, device='cuda:0')
# tensor([0.6829, 0.6589], device='cuda:0')
# tensor(157, device='cuda:0')
# tensor(160, device='cuda:0')
# tensor([0.7979, 0.7597], device='cuda:0')
# tensor(146, device='cuda:0')
# tensor(24, device='cuda:0')
# tensor([0.7208, 0.6350], device='cuda:0')
# tensor(360, device='cuda:0')
# tensor(61, device='cuda:0')
# tensor([0.7840, 0.7347], device='cuda:0')
# tensor(64, device='cuda:0')
# tensor(122, device='cuda:0')
# tensor([0.7100, 0.7472], device='cuda:0')
# tensor(204, device='cuda:0')
# tensor(137, device='cuda:0')
# tensor([0.6708, 0.7162], device='cuda:0')
# tensor(283, device='cuda:0')
# tensor(194, device='cuda:0')
# tensor([0.7454, 0.7559], device='cuda:0')
# tensor(53, device='cuda:0')
# tensor(108, device='cuda:0')
# tensor([0.7530, 0.6915], device='cuda:0')
# tensor(213, device='cuda:0')
# tensor(70, device='cuda:0')
# tensor([0.7107, 0.6971], device='cuda:0')
# tensor(261, device='cuda:0')
# tensor(121, device='cuda:0')
# tensor([0.7315, 0.7099], device='cuda:0')
# tensor(142, device='cuda:0')
# tensor(95, device='cuda:0')
# tensor([0.7560, 0.6956], device='cuda:0')
# tensor(113, device='cuda:0')
# tensor(120, device='cuda:0')
# tensor([0.7351, 0.6696], device='cuda:0')
# tensor(308, device='cuda:0')
# tensor(7, device='cuda:0')
# tensor([0.6444, 0.6392], device='cuda:0')
# tensor(37, device='cuda:0')
# tensor(128, device='cuda:0')
# tensor([0.6563, 0.6974], device='cuda:0')
# tensor(60, device='cuda:0')
# tensor(208, device='cuda:0')
# tensor([0.6766, 0.7154], device='cuda:0')
# tensor(248, device='cuda:0')
# tensor(12, device='cuda:0')
# tensor([0.6960, 0.6950], device='cuda:0')
# tensor(231, device='cuda:0')
# tensor(36, device='cuda:0')
# tensor([0.7562, 0.6939], device='cuda:0')
# tensor(148, device='cuda:0')
# tensor(20, device='cuda:0')
# tensor([0.7550, 0.7382], device='cuda:0')
# tensor(59, device='cuda:0')
# tensor(57, device='cuda:0')
# tensor([0.6580, 0.7007], device='cuda:0')
# tensor(425, device='cuda:0')
# tensor(196, device='cuda:0')
# tensor([0.6536, 0.7545], device='cuda:0')
# tensor(82, device='cuda:0')
# tensor(192, device='cuda:0')
# tensor([0.6666, 0.7049], device='cuda:0')
# tensor(70, device='cuda:0')
# tensor(17, device='cuda:0')
# tensor([0.7400, 0.7532], device='cuda:0')
# tensor(129, device='cuda:0')
# tensor(91, device='cuda:0')
# tensor([0.7201, 0.7178], device='cuda:0')
# tensor(116, device='cuda:0')
# tensor(142, device='cuda:0')
# tensor([0.7160, 0.7551], device='cuda:0')
# tensor(81, device='cuda:0')
# tensor(47, device='cuda:0')
# tensor([0.7149, 0.7524], device='cuda:0')
# tensor(23, device='cuda:0')
# tensor(104, device='cuda:0')
# tensor([0.5730, 0.6874], device='cuda:0')
# tensor(265, device='cuda:0')
# tensor(123, device='cuda:0')
# tensor([0.7603, 0.6950], device='cuda:0')
# tensor(150, device='cuda:0')
# tensor(36, device='cuda:0')
# tensor([0.6765, 0.7282], device='cuda:0')
# tensor(94, device='cuda:0')
# tensor(29, device='cuda:0')
# tensor([0.7515, 0.7141], device='cuda:0')
# tensor(29, device='cuda:0')
# tensor(57, device='cuda:0')
# tensor([0.6384, 0.6130], device='cuda:0')
# tensor(224, device='cuda:0')
# tensor(71, device='cuda:0')
# tensor([0.7216, 0.6874], device='cuda:0')
# tensor(75, device='cuda:0')
# tensor(83, device='cuda:0')
# tensor([0.7005, 0.7482], device='cuda:0')
# tensor(113, device='cuda:0')
# tensor(62, device='cuda:0')
# tensor([0.6683, 0.6052], device='cuda:0')
# tensor(276, device='cuda:0')
# tensor(199, device='cuda:0')
# tensor([0.7210, 0.6839], device='cuda:0')
# tensor(68, device='cuda:0')
# tensor(155, device='cuda:0')
# tensor([0.5804, 0.6905], device='cuda:0')
# tensor(227, device='cuda:0')
# tensor(132, device='cuda:0')
# tensor([0.7162, 0.6844], device='cuda:0')
# tensor(13, device='cuda:0')
# tensor(63, device='cuda:0')
# tensor([0.7211, 0.6588], device='cuda:0')
# tensor(117, device='cuda:0')
# tensor(79, device='cuda:0')
# tensor([0.7077, 0.7405], device='cuda:0')
# tensor(110, device='cuda:0')
# tensor(115, device='cuda:0')
# tensor([0.7088, 0.7114], device='cuda:0')
# tensor(116, device='cuda:0')
# tensor(202, device='cuda:0')
# tensor([0.7302, 0.7372], device='cuda:0')
# tensor(79, device='cuda:0')
# tensor(199, device='cuda:0')
# tensor([0.7105, 0.7056], device='cuda:0')
# tensor(46, device='cuda:0')
# tensor(43, device='cuda:0')
# tensor([0.6731, 0.7365], device='cuda:0')
# tensor(17, device='cuda:0')
# tensor(302, device='cuda:0')
# tensor([0.6933, 0.7609], device='cuda:0')
# tensor(85, device='cuda:0')
# tensor(65, device='cuda:0')
# tensor([0.6495, 0.5850], device='cuda:0')
# tensor(169, device='cuda:0')
# tensor(168, device='cuda:0')
# tensor([0.6986, 0.7288], device='cuda:0')
# tensor(60, device='cuda:0')
# tensor(61, device='cuda:0')
# tensor([0.7380, 0.7348], device='cuda:0')
# tensor(71, device='cuda:0')
# tensor(196, device='cuda:0')
# tensor([0.6685, 0.7188], device='cuda:0')
# tensor(27, device='cuda:0')
# tensor(91, device='cuda:0')
# tensor([0.6649, 0.7507], device='cuda:0')
# tensor(55, device='cuda:0')
# tensor(43, device='cuda:0')
# tensor([0.6190, 0.7313], device='cuda:0')
# tensor(127, device='cuda:0')
# tensor(225, device='cuda:0')
# tensor([0.7506, 0.7246], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(127, device='cuda:0')
# tensor([0.7304, 0.6893], device='cuda:0')
# tensor(24, device='cuda:0')
# tensor(131, device='cuda:0')
# tensor([0.6010, 0.6039], device='cuda:0')
# tensor(185, device='cuda:0')
# tensor(150, device='cuda:0')
# tensor([0.7306, 0.7723], device='cuda:0')
# tensor(188, device='cuda:0')
# tensor(51, device='cuda:0')
# tensor([0.7201, 0.7096], device='cuda:0')
# tensor(140, device='cuda:0')
# tensor(134, device='cuda:0')
# tensor([0.6517, 0.6463], device='cuda:0')
# tensor(194, device='cuda:0')
# tensor(282, device='cuda:0')
# tensor([0.6859, 0.7166], device='cuda:0')
# tensor(125, device='cuda:0')
# tensor(66, device='cuda:0')
# tensor([0.7378, 0.7398], device='cuda:0')
# tensor(44, device='cuda:0')
# tensor(50, device='cuda:0')
# tensor([0.7379, 0.7275], device='cuda:0')
# tensor(146, device='cuda:0')
# tensor(69, device='cuda:0')
# tensor([0.6691, 0.7259], device='cuda:0')
# tensor(23, device='cuda:0')
# tensor(120, device='cuda:0')
# tensor([0.7206, 0.7366], device='cuda:0')
# tensor(100, device='cuda:0')
# tensor(238, device='cuda:0')
# tensor([0.7317, 0.7374], device='cuda:0')
# tensor(308, device='cuda:0')
# tensor(94, device='cuda:0')
# tensor([0.7265, 0.7238], device='cuda:0')
# tensor(93, device='cuda:0')
# tensor(165, device='cuda:0')
# tensor([0.6785, 0.7127], device='cuda:0')
# tensor(179, device='cuda:0')
# tensor(478, device='cuda:0')
# tensor([0.5955, 0.7514], device='cuda:0')
# tensor(59, device='cuda:0')
# tensor(52, device='cuda:0')
# tensor([0.6077, 0.7185], device='cuda:0')
# tensor(92, device='cuda:0')
# tensor(166, device='cuda:0')
# tensor([0.7467, 0.6272], device='cuda:0')
# tensor(53, device='cuda:0')
# tensor(120, device='cuda:0')
# tensor([0.4836, 0.7294], device='cuda:0')
# tensor(279, device='cuda:0')
# tensor(141, device='cuda:0')
# tensor([0.7609, 0.6845], device='cuda:0')
# tensor(165, device='cuda:0')
# tensor(76, device='cuda:0')
# tensor([0.6311, 0.6837], device='cuda:0')
# tensor(225, device='cuda:0')
# tensor(141, device='cuda:0')
# tensor([0.6700, 0.7374], device='cuda:0')
# tensor(119, device='cuda:0')
# tensor(4, device='cuda:0')
# tensor([0.7538, 0.7084], device='cuda:0')
# tensor(93, device='cuda:0')
# tensor(228, device='cuda:0')
# tensor([0.7227, 0.6738], device='cuda:0')
# tensor(115, device='cuda:0')
# tensor(355, device='cuda:0')
# tensor([0.6872, 0.6599], device='cuda:0')
# tensor(115, device='cuda:0')
# tensor(109, device='cuda:0')
# tensor([0.8419, 0.8006], device='cuda:0')
# tensor(1, device='cuda:0')
# tensor(51, device='cuda:0')
# tensor([0.6514, 0.7358], device='cuda:0')
# tensor(28, device='cuda:0')
# tensor(50, device='cuda:0')
# tensor([0.6818, 0.7614], device='cuda:0')
# tensor(133, device='cuda:0')
# tensor(173, device='cuda:0')
# tensor([0.8080, 0.7403], device='cuda:0')
# tensor(70, device='cuda:0')
# tensor(43, device='cuda:0')
# tensor([0.4355, 0.8605], device='cuda:0')
# tensor(168, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor([0.7576, 0.5821], device='cuda:0')
# tensor(113, device='cuda:0')
# tensor(143, device='cuda:0')
# tensor([0.7120, 0.6453], device='cuda:0')
# tensor(96, device='cuda:0')
# tensor(136, device='cuda:0')
# tensor([0.6788, 0.6835], device='cuda:0')
# tensor(158, device='cuda:0')
# tensor(110, device='cuda:0')
# tensor([0.7212, 0.7616], device='cuda:0')
# tensor(25, device='cuda:0')
# tensor(208, device='cuda:0')
# tensor([0.6184, 0.7554], device='cuda:0')
# tensor(267, device='cuda:0')
# tensor(57, device='cuda:0')
# tensor([0.7303, 0.7148], device='cuda:0')
# tensor(48, device='cuda:0')
# tensor(51, device='cuda:0')
# tensor([0.7582, 0.7132], device='cuda:0')
# tensor(30, device='cuda:0')
# tensor(123, device='cuda:0')
# tensor([0.5912, 0.7569], device='cuda:0')
# tensor(350, device='cuda:0')
# tensor(39, device='cuda:0')
# tensor([0.6716, 0.6906], device='cuda:0')
# tensor(106, device='cuda:0')
# tensor(22, device='cuda:0')
# tensor([0.7174, 0.7183], device='cuda:0')
# tensor(138, device='cuda:0')
# tensor(50, device='cuda:0')
# tensor([0.6640, 0.7219], device='cuda:0')
# tensor(71, device='cuda:0')
# tensor(136, device='cuda:0')
# tensor([0.7203, 0.7325], device='cuda:0')
# tensor(210, device='cuda:0')
# tensor(192, device='cuda:0')
# tensor([0.6707, 0.6657], device='cuda:0')
# tensor(284, device='cuda:0')
# tensor(209, device='cuda:0')
# tensor([0.7333, 0.7135], device='cuda:0')
# tensor(30, device='cuda:0')
# tensor(44, device='cuda:0')
# tensor([0.6800, 0.6870], device='cuda:0')
# tensor(33, device='cuda:0')
# tensor(35, device='cuda:0')
# tensor([0.6642, 0.7348], device='cuda:0')
# tensor(294, device='cuda:0')
# tensor(29, device='cuda:0')
# tensor([0.6956, 0.7122], device='cuda:0')
# tensor(162, device='cuda:0')
# tensor(142, device='cuda:0')
# tensor([0.9381, 0.7563], device='cuda:0')
# tensor(0, device='cuda:0')
# tensor(88, device='cuda:0')
# tensor([0.7517, 0.6955], device='cuda:0')
# tensor(59, device='cuda:0')
# tensor(18, device='cuda:0')
# tensor([0.7113, 0.6345], device='cuda:0')
# tensor(284, device='cuda:0')
# tensor(21, device='cuda:0')
# tensor([0.6734, 0.7541], device='cuda:0')
# tensor(112, device='cuda:0')
# tensor(160, device='cuda:0')
# tensor([0.7381, 0.6819], device='cuda:0')
# tensor(43, device='cuda:0')
# tensor(413, device='cuda:0')
# tensor([0.7388, 0.7404], device='cuda:0')
# tensor(76, device='cuda:0')
# tensor(31, device='cuda:0')
# tensor([0.6856, 0.5388], device='cuda:0')
# tensor(91, device='cuda:0')
# tensor(267, device='cuda:0')
# tensor([0.7006, 0.6934], device='cuda:0')
# tensor(24, device='cuda:0')
# tensor(129, device='cuda:0')
# tensor([0.7669, 0.7868], device='cuda:0')
# tensor(90, device='cuda:0')
# tensor(46, device='cuda:0')
# tensor([0.6172, 0.6893], device='cuda:0')
# tensor(66, device='cuda:0')
# tensor(91, device='cuda:0')
# tensor([0.7064, 0.6898], device='cuda:0')
# tensor(353, device='cuda:0')
# tensor(105, device='cuda:0')
# tensor([0.6913, 0.7161], device='cuda:0')
# tensor(211, device='cuda:0')
# tensor(109, device='cuda:0')
# tensor([0.7467, 0.7572], device='cuda:0')
# tensor(131, device='cuda:0')
# tensor(41, device='cuda:0')
# tensor([0.7086, 0.6298], device='cuda:0')
# tensor(85, device='cuda:0')
# tensor(142, device='cuda:0')
# tensor([0.7240, 0.7199], device='cuda:0')
# tensor(87, device='cuda:0')
# tensor(202, device='cuda:0')
# tensor([0.7035, 0.6735], device='cuda:0')
# tensor(28, device='cuda:0')
# tensor(63, device='cuda:0')
# tensor([0.6936, 0.7457], device='cuda:0')
# tensor(54, device='cuda:0')
# tensor(59, device='cuda:0')
# tensor([0.7483, 0.7306], device='cuda:0')
# tensor(268, device='cuda:0')
# tensor(217, device='cuda:0')
# tensor([0.6694, 0.7444], device='cuda:0')
# tensor(55, device='cuda:0')
# tensor(13, device='cuda:0')
# tensor([0.7147, 0.5576], device='cuda:0')
# tensor(66, device='cuda:0')
# tensor(126, device='cuda:0')
# tensor([0.8033, 0.7381], device='cuda:0')
# tensor(102, device='cuda:0')
# tensor(226, device='cuda:0')
# tensor([0.6967, 0.7006], device='cuda:0')
# tensor(89, device='cuda:0')
# tensor(24, device='cuda:0')
# tensor([0.7808, 0.6317], device='cuda:0')
# tensor(119, device='cuda:0')
# tensor(294, device='cuda:0')
# tensor([0.6779, 0.7168], device='cuda:0')
# tensor(223, device='cuda:0')
# tensor(75, device='cuda:0')
# tensor([0.7291, 0.6735], device='cuda:0')
# tensor(71, device='cuda:0')
# tensor(341, device='cuda:0')
# tensor([0.6997, 0.7348], device='cuda:0')
# tensor(183, device='cuda:0')
# tensor(3, device='cuda:0')
# tensor(0.7038)
# 121.70333333333333

# %%
dicesa = np.array(torch.cat(dices).cpu())
plt.hist(dicesa, 20)
plt.xlabel("DICE")
print(np.mean(dicesa))
ff = np.mean(folds_list)
print(ff)
# Out:
# 0.70349264
# 125.65333333333334

# %%
if not("N" in locals()):
    N = 0
N += 1
N %= 2
#N = 3
#plt.imshow(fixed_image[N, 0, 10].cpu() - net.warped_image_A[N, 0, 10].cpu().detach())
#plt.show()
plt.rcParams["figure.figsize"] = (5, 5)
def imshow(x):
    plt.xticks([])
    plt.yticks([])
    plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
slice_ = 40
imshow(fixed_image[N, 0, slice_])
plt.show()
imshow(net.warped_image_A[N, 0, slice_])
plt.show()

plt.imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach() - moving_image[N, 0, slice_ ].cpu().detach())
plt.show()
#plt.imshow(net.regis_net.x_comp_phi[N, 0, slice_].cpu().detach() - moving_image[N, 0, slice_].cpu().detach())
#plt.show()
plt.imshow((fixed_image - moving_image)[N, 0, slice_].cpu().detach())
plt.show()

imshow(moving_image[N, 0, slice_].cpu().detach())
plt.show()

# %%
import matplotlib.pyplot as plt
S = 100
plt.imshow(moving_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(fixed_image[N, 0, :, S].cpu())
plt.show()
plt.imshow(net.warped_image_A[N, 0, :, S].cpu().detach())
plt.show()
plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach())
plt.show()

plt.imshow(net.warped_image_B[N, 0, :, S].cpu().detach() - moving_image[N, 0, :, S].cpu())

# %%
S = 49
plt.imshow(moving_cartilage[N, 0, :, S * 4].cpu())
plt.show() 
plt.imshow(warped_moving_cartilage[N, 0, :, S * 4].detach().cpu())
plt.show()

plt.imshow(fixed_cartilage[N, 0, :, S * 4].cpu())
plt.show()

plt.imshow((warped_moving_cartilage[N, 0, :, S * 4].detach().cpu() - fixed_cartilage[N, 0, :, S * 4].cpu()))
plt.show()

# %%
import icon_registration.visualize as visualize
N = (N + 1)% 2
#N = 1
plt.rcParams["figure.figsize"] = 10, 10
visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
plt.show()
visualize.show_as_grid(net.phi_BA_vectorfield[N, [1, 2], 20])

# %%
net.phi_AB.__closure__[0].cell_contents
# Out:
# <function icon_registration.network_wrappers.TwoStepRegistration.forward.<locals>.<lambda>(input_)>

# %%
N = (N + 1) % 2
visualize.show_as_grid(net.phi_BA(net.phi_AB(net.identity_map))[N, [1, 2], 20])

# %%
import visualize
mp = hires_Net.phi_AB(hires_Net.regis_net.net.identityMap[:, :] + torch.tensor([[[[[0]]], [[[0]]], [[[0]]]]]).cuda())
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = hires_Net.phi_AB(hires_Net.regis_net.net.identityMap[:, :] + torch.tensor([[[[[0]]], [[[0]]], [[[0]]]]]).cuda())
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
import mermaidlite
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [183], in <cell line: 1>()
# ----> 1 import mermaidlite
#
# ModuleNotFoundError: No module named 'mermaidlite'

# %%
import visualize
mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [184], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = pretrained_lowres_net.phi_AB(hires_Net.identityMap[:, :, ::2, ::2, ::2])
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
import visualize
mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
visualize.show_as_grid(mp[N, [1, 2], 20])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [185], in <cell line: 1>()
# ----> 1 import visualize
#       2 mp = hires_Net.phi_BA(hires_Net.regis_net.net.identityMap)
#       3 visualize.show_as_grid(mp[N, [1, 2], 20])
#
# ModuleNotFoundError: No module named 'visualize'

# %%
mkdir supll_regis_figures

# %%
import importlib
importlib.reload(visualize)
import matplotlib.colors as colors

for N in range(2):

    plt.rcParams["figure.figsize"] = (5, 5)
    def imshow(x):
        plt.xticks([])
        plt.yticks([])
        plt.imshow(np.abs(x.cpu().detach()), vmin=0, vmax=1, cmap="gray")
    offset = 0
    slice_ = 20
    
    for axis in ["Coronal", "Sagittal", "Axial"]:
        m_image = moving_image[N, 0].cpu().detach()
        f_image = fixed_image[N, 0].cpu().detach()
        m_warped_image_A = net.warped_image_A[N, 0].cpu().detach() 
        phi_BA = net.phi_BA_vectorfield[N]
        
        dV = flips2(net.phi_AB_vectorfield)[N, 0]
        
        if axis == "Sagittal":
            m_image_slice = m_image[slice_]
            f_image_slice = f_image[slice_]
            warped_image_A_slice = m_warped_image_A[slice_]
            phi_BA_slice = phi_BA[[1, 2], 20].clone()
            dV_slice = dV[slice_]
        if axis == "Coronal":
            m_image_slice = m_image[:, slice_].transpose(0, 1)
            f_image_slice = f_image[:, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[2, 0], :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, slice_].transpose(0, 1)
        if axis == "Axial":
            slice_ *= 2
            m_image_slice = m_image[:, :, slice_].transpose(0, 1)
            f_image_slice = f_image[:, :, slice_].transpose(0, 1)
            warped_image_A_slice = m_warped_image_A[:, :, slice_].transpose(0, 1)
            phi_BA_slice = phi_BA[[1, 0], :, :, slice_].clone()
            phi_BA_slice[1] *= (79 / 181)
            dV_slice = dV[:, :, slice_].transpose(0, 1)
            slice_ /= 2
            
            
        
        header = f"supll_regis_figures/{axis}Pair{N + offset}"
        imshow(m_image_slice)
        plt.savefig(header + "ImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(f_image_slice)
        plt.savefig(header + "ImageB.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        plt.savefig(header + "WarpedImageA.png", bbox_inches="tight")
        plt.clf()
        imshow(warped_image_A_slice)
        visualize.show_as_grid(phi_BA_slice)
        plt.savefig(header + "WarpedImageAGrid.png", bbox_inches="tight")
        plt.clf()
        
        plt.xticks([])
        plt.yticks([])
        
        plt.imshow(dV_slice, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
        plt.title("min dV is $\\bf{" + f"{np.min(dV_slice.numpy()):.3}" + "}$ in this slice", 
                 fontdict={'fontsize':13})
        plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
        #lt.show()
        #plt.imshow(dV[1, 0, 40] < 0)


        plt.savefig(header + "dV.png", bbox_inches="tight")
        plt.clf()
    """
    imshow(net.warped_image_B[N, 0, slice_ ].cpu().detach())
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageB.png")
    plt.clf()
    imshow(net.warped_image_B[N, 0, slice_].cpu().detach())
    visualize.show_as_grid(net.phi_AB_vectorfield[N, [1, 2], 20])
    plt.savefig(f"supll_regis_figures/Pair{N + offset}WarpedImageBGrid.png")
    plt.clf()
    """

    
    plt.show()

# %%
import importlib
importlib.reload(visualize)
# Out:
# <module 'visualize' from '/playpen-raid1/tgreer/InverseConsistency/visualize.py'>

# %%
plt.imshow(torch.min(dV[1, 0], axis=0).values)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 plt.imshow(torch.min(dV[1, 0], axis=0).values)
#       2 plt.colorbar()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
torch.sum(dV[1] < 0)
# Out:
# tensor(13)

# %%
dV
# Out:
# (0,)

# %%
116 / (80 * 192 * 192), 1 / 25000
# Out:
# (3.9333767361111114e-05, 4e-05)

# %%
import matplotlib.colors as colors

plt.xticks([])
plt.yticks([])
query = dV[0, 0, 43]
plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice", 
         fontdict={'fontsize':13})
plt.colorbar(label="dV")#, fraction=0.046, pad=0.04)
#lt.show()
#plt.imshow(dV[1, 0, 40] < 0)


plt.savefig("dVslice0.pdf", bbox_inches="tight")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Input In [104], in <cell line: 5>()
#       3 plt.xticks([])
#       4 plt.yticks([])
# ----> 5 query = dV[0, 0, 43]
#       6 plt.imshow(query, norm=colors.LogNorm(vmin=torch.min(dV[dV > 0]), vmax=torch.max(dV)))
#       7 plt.title("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice",
#       8          fontdict={'fontsize':13})
#
# IndexError: too many indices for array: array is 1-dimensional, but 3 were indexed

# %%
2 * np.sum(folds_list) / (np.product(list(dV.shape)) * len(r_ds))
# Out:
# 2.046440866760003e-05

# %%
print("dV attains a minimum of $\\bf{" + f"{np.min(query.numpy()):.3}" + "}$ in this slice")
from matplotlib import rc
rc('text', usetex=False)
np.min(query.numpy())
# Out:
# dV attains a minimum of $\bf{0.0613}$ in this slice
# 0.061257

# %%
adv = np.array(dV)
filteredDV = adv[adv < 0.05]
plt.hist(filteredDV, bins=100)
plt.show()

# %%
plt.hist(np.concatenate(filteredDV_list), bins=100)
plt.title("Distribution of negative dV voxels in test set")
plt.xlabel("dV (in voxels³)")
plt.ylabel("Count")
plt.savefig("DistributionNegativeJacobian.pdf")

# %%
np.mean(np.concatenate(filteredDV_list))
# Out:
# -0.09664285

# %%
np.median(np.concatenate(filteredDV_list))
# Out:
# -0.054298144

# %%
np.percentile(np.concatenate(filteredDV_list), 1)
# Out:
# -0.6120650005340577

# %%
# %time net.regis_net(moving_image, fixed_image)
# Out:
# CPU times: user 8.3 ms, sys: 20.2 ms, total: 28.5 ms
# Wall time: 21.4 ms
# <function icon_registration.network_wrappers.DoubleNet.forward.<locals>.<lambda>(input_)>

# %%
with torch.no_grad():
    x = batched_ds[0]
    x = list(zip(*x))
    x = [torch.cat(r, 0).cuda().float() for r in x]
    fixed_image, fixed_cartilage = x[0], x[2]
    moving_image, moving_cartilage = x[1], x[3]

# %%
# %%time
with torch.no_grad():
    phi = net.regis_net(moving_image, fixed_image)
    phi_AB_vectorfield = phi(net.identityMap).cpu()
# Out:
# CPU times: user 1.45 s, sys: 61 ms, total: 1.51 s
# Wall time: 1.48 s

# %%
# %%time 
net(moving_image, fixed_image)
# Out:
# CPU times: user 2.78 s, sys: 1.12 s, total: 3.9 s
# Wall time: 3.83 s
# (tensor(0.0624, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(5.5865e-05, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(0.0568, device='cuda:0', grad_fn=<AddBackward0>),
#  tensor(6.9831e-06, device='cuda:0', grad_fn=<MeanBackward0>))

# %%
plt.hist(torch.cat(dices).cpu().detach().numpy(), bins=30)
# Out:
# (array([ 3.,  1.,  1.,  2.,  5.,  6.,  7., 10., 17., 22., 21., 26., 30.,
#         40., 41., 29., 20.,  8.,  4.,  4.,  0.,  0.,  1.,  1.,  0.,  0.,
#          0.,  0.,  0.,  1.]),
#  array([0.45836532, 0.47490254, 0.4914398 , 0.507977  , 0.52451426,
#         0.54105145, 0.5575887 , 0.5741259 , 0.59066314, 0.6072004 ,
#         0.6237376 , 0.6402748 , 0.6568121 , 0.67334926, 0.6898865 ,
#         0.70642376, 0.72296095, 0.7394982 , 0.7560354 , 0.77257264,
#         0.7891099 , 0.8056471 , 0.8221843 , 0.8387216 , 0.85525876,
#         0.871796  , 0.8883332 , 0.90487045, 0.9214077 , 0.9379449 ,
#         0.95448214], dtype=float32),
#  <BarContainer object of 30 artists>)

# %%
pixel_displacement = ((net.phi_AB_vectorfield.cpu() - net.identityMap.cpu()) 
    * torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None])
plt.imshow(pixel_displacement[0, 2, 40], cmap="rainbow")
plt.colorbar()

# %%
torch.max(torch.abs(pixel_displacement))
# Out:
# tensor(30.6417)

# %%
error = (net.phi_AB(net.phi_BA_vectorfield) - net.identityMap).cpu()* torch.tensor(net.phi_AB_vectorfield.shape)[None, 2:, None, None, None]

# %%
plt.imshow((error)[0, 0, 40])
plt.colorbar()

# %%
torch.sqrt(torch.mean(error**2))
# Out:
# tensor(0.3200)

# %%
plt.rcParams["figure.figsize"]
# Out:
# [6.4, 4.8]

# %%
plt.hist(folds_list, bins=40)
plt.xlabel("number of folded pixels")
plt.ylabel("number of image pairs")
# Out:
# Text(0, 0.5, 'number of image pairs')

# %%
import pickle
with open("../results/grad_hires-1/loss_curve", "rb") as f:
    ncurve2 = pickle.load(f)
ncurve2 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in ncurve2]
ncurve2 = np.array(ncurve2)
plt.plot(ncurve2)


import pickle
with open("../../masked_similarity_InvCon/results/hires_smart_6/loss_curve", "rb") as f:
    curve = pickle.load(f)
curve = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve]
curve = np.array(curve)
plt.plot(curve)


import pickle
with open("../../masked_similarity_InvCon/results/fourth_net_frozen/loss_curve", "rb") as f:
    curve4 = pickle.load(f)
curve4 = [[a, b, c, torch.mean(d).item(), e] for (a, b, c, d, e) in curve4]
curve4 = np.array(curve4)
plt.plot(curve4)
# Out:
# [<matplotlib.lines.Line2D at 0x7f85cd214220>,
#  <matplotlib.lines.Line2D at 0x7f86225ae430>,
#  <matplotlib.lines.Line2D at 0x7f8b4770c520>,
#  <matplotlib.lines.Line2D at 0x7f8b4770c970>,
#  <matplotlib.lines.Line2D at 0x7f8b4770ca00>]

# %%
plt.plot(ncurve2[:, 2])

plt.plot(curve[:, 2])

plt.plot(curve4[:, 2])

# %%
plt.plot(ncurve2[:, 1])


plt.plot(curve[:, 1])

plt.plot(curve4[:, 1])

# %%
plt.plot(ncurve2[:, 3])


plt.plot(curve[:, 3])
